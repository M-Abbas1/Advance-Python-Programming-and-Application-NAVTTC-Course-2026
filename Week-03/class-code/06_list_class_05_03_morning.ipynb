# %%
stu_info = ["name", 30, 4]

# %%
prices = [390, 490, 200, 100, 500]

# %%
prices
# Out:
# [390, 490, 200, 100, 500]

# %%
type(prices)
# Out:
# list

# %%
len(prices)
# Out:
# 5

# %%
prices
# Out:
# [390, 490, 200, 100, 500]

# %%
# indexing

prices[3] = 300

# %%
prices
# Out:
# [390, 490, 200, 300, 500]

# %%
prices[-1] = 600

# %%
prices
# Out:
# [390, 490, 200, 300, 600]

# %%
prices[5] = 200
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 prices[5] = 200
#
# IndexError: list assignment index out of range

# %%
prices[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 prices[5]
#
# IndexError: list index out of range

# %%
## slicing

# %%
prices
# Out:
# [390, 490, 200, 300, 600]

# %%
prices[:3]
# Out:
# [390, 490, 200]

# %%
prices[:2] = [400, 500]

# %%
prices
# Out:
# [400, 500, 200, 300, 600]

# %%
prices = [400, 500, 200, 300, 600]
prices
# Out:
# [400, 500, 200, 300, 600]

# %%
prices[:5] = [250, 330]

# %%
prices
# Out:
# [250, 330]

# %%
prices = [400, 500, 200, 300, 600]
print(prices)
# Out:
# [400, 500, 200, 300, 600]

# %%
prices[0:2] = [240, 530, 260]

# %%
prices
# Out:
# [240, 530, 260, 200, 300, 600]

# %%
prices
# Out:
# [240, 530, 260, 200, 300, 600]

# %%
prices[5] = [240, 660]

# %%
prices
# Out:
# [240, 530, 260, 200, 300, [240, 660]]

# %%
len(prices)
# Out:
# 6

# %%
prices[5]
# Out:
# [240, 660]

# %%
# using built-in function/methods

# %%
names = ["salman", 'kamran', 'mudassir', 'naseem', 'babar']

# %%
names
# Out:
# ['salman', 'kamran', 'mudassir', 'naseem', 'babar']

# %%
names.append('salman ali aga')

# %%
names
# Out:
# ['salman', 'kamran', 'mudassir', 'naseem', 'babar', 'salman ali aga']

# %%
names.extend(['Nawaz', 'Farhan', 'Saim'])

# %%
names
# Out:
# ['salman',
#  'kamran',
#  'mudassir',
#  'naseem',
#  'babar',
#  'salman ali aga',
#  'Nawaz',
#  'Farhan',
#  'Saim']

# %%
names.extend(["tariq"])

# %%
names
# Out:
# ['salman',
#  'kamran',
#  'mudassir',
#  'naseem',
#  'babar',
#  'salman ali aga',
#  'Nawaz',
#  'Farhan',
#  'Saim',
#  'tariq',
#  't',
#  'a',
#  'r',
#  'i',
#  'q',
#  'tariq']

# %%
len(names)
# Out:
# 16

# %%
prices
# Out:
# [240, 530, 260, 200, 300, [240, 660]]

# %%
prices[5] = 400

# %%
prices
# Out:
# [240, 530, 260, 200, 300, 400]

# %%
prices.insert(3, 540)

# %%
prices
# Out:
# [240, 530, 260, 540, 200, 300, 400]

# %%
prices.insert(760, 1)

# %%
prices
# Out:
# [240, 530, 260, 540, 200, 300, 400, 1]

# %%
prices.insert(7, 220)

# %%
prices
# Out:
# [240, 530, 260, 540, 200, 300, 400, 220, 1]

# %%
prices.insert(8, 440)

# %%
prices
# Out:
# [240, 530, 260, 540, 200, 300, 400, 220, 440, 1]

# %%
prices.insert(10, 110)

# %%
prices
# Out:
# [240, 530, 260, 540, 200, 300, 400, 220, 440, 1, 110]

# %%
len(prices)
# Out:
# 11

# %%
prices
# Out:
# [240, 530, 260, 540, 200, 300, 400, 220, 440, 1, 110]

# %%
prices.extend([240, 340, 804])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 prices.extend(240, 340, 804)
#
# TypeError: list.extend() takes exactly one argument (3 given)

# %%
## Removing items from list

# %%
temp = [39.6, 37.5, 29.0, 30.6, 40.6]

# %%
len(temp)
# Out:
# 5

# %%
## remove
temp.remove(30.6)

# %%
temp
# Out:
# [39.6, 37.5, 29.0, 40.6]

# %%
temp.pop()
# Out:
# 40.6

# %%
temp
# Out:
# [39.6, 37.5, 29.0]

# %%
print(temp.remove(37.5))
# Out:
# None

# %%
temp
# Out:
# [39.6, 29.0]

# %%
print(temp.pop())
temp
# Out:
# 29.0
# [39.6]

# %%
temp
# Out:
# [39.6]

# %%
temp[:] = [39.6, 40.5, 46.7, 50.6]

# %%
temp
# Out:
# [39.6, 40.5, 46.7, 50.6]

# %%
temp.pop()
# Out:
# 50.6

# %%
temp
# Out:
# [39.6, 40.5, 46.7]

# %%
temp
# Out:
# [39.6, 40.5, 46.7]

# %%
temp
# Out:
# [39.6, 40.5, 46.7]

# %%
temp[:] = [49]

# %%
temp
# Out:
# [49]

# %%
temp
# Out:
# [49]

# %%
temp[:] = [30.5, 41.5, 39.1, 40.5, 23]

# %%
temp
# Out:
# [30.5, 41.5, 39.1, 40.5, 23]

# %%
temp.pop(1)    # []
# Out:
# 39.1

# %%
temp
# Out:
# [30.5, 40.5, 23]

# %%
temp
# Out:
# [30.5, 40.5, 23]

# %%
temp.clear()

# %%
temp
# Out:
# []

# %%
temp
# Out:
# []

# %%
temp = [30.5, 41.5, 39.1, 40.5, 23]

# %%
temp
# Out:
# [30.5, 41.5, 39.1, 40.5, 23]

# %%
del temp[0]

# %%
temp
# Out:
# [41.5, 39.1, 40.5, 23]

# %%
del temp[-1]

# %%
temp
# Out:
# [41.5, 39.1, 40.5]

# %%
del temp

# %%
temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 temp
#
# NameError: name 'temp' is not defined

# %%
temp = [41.5, 39.1, 40.5, 23]

# %%
del temp[:2]

# %%
temp
# Out:
# [40.5, 23]
