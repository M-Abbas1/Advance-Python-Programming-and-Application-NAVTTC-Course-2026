# %%
## Mutable

# %%
price = 780

print(type(price))
print(id(price))
# Out:
# <class 'int'>
# 2377110648784

# %%
price = 1000

print(type(price))
print(id(price))
# Out:
# <class 'int'>
# 2377110649456

# %%
temp = 37.6

print("First Time creation")
print(type(temp))
print(id(temp))


# change the value
temp = 40.5
print(type(temp))
print(id(temp))
# Out:
# First Time creation
# <class 'float'>
# 2377107374224
# <class 'float'>
# 2377107374640

# %%
# list 

l = [23, 53, 24, 563, 64]  #elements or items

# %%
l
# Out:
# [23, 53, 24, 563, 64]

# %%
l2 = []

# %%
l2
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
info = ["usman", 20, 5.8, False]

# %%
list_python = list("python")

# %%
print(list_python)
len(list_python)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']
# 6

# %%
empty = list()

# %%
empty
# Out:
# []

# %%
tuple_to_list = list((437, 55, "khan"))

# %%
tuple_to_list
# Out:
# [437, 55, 'khan']

# %%
names = ["usman", "kamran", "kaleem", "wahab", "akram"]

print(len(names))
# Out:
# 5

# %%
# indexing
names[1]
# Out:
# 'kamran'

# %%
names[-2]
# Out:
# 'wahab'

# %%
for i in range(len(names)):
    print(f"Name {i+1}: ",names[i])
# Out:
# Name 1:  usman
# Name 2:  kamran
# Name 3:  kaleem
# Name 4:  wahab
# Name 5:  akram

# %%
names[3]
# Out:
# 'wahab'

# %%
names.index('wahab')
# Out:
# 3

# %%
# Slicing

# %%
ages = [23, 42, 23, 43, 64, 12, 53, 64]

# %%
type(ages)
# Out:
# list

# %%
ages[:3]
# Out:
# [23, 42, 23]

# %%
print(ages[-1:-4:-1])
# Out:
# [64, 53, 12]

# %%
print(ages[::-1])

# %%
ages = [23, 42, 23, 43, 64, 12, 53, 64]

start: 7       ## 7-> 64, 7-1=6 -> 53, 6-1=5 --> 12
end  : 0
steps: -1              64, 53, 12, 64,  43, 23, 42, 23

# %%
ages[-3:]      # start=-3, end=8, step=1
# Out:
# [12, 53, 64]

# %%
[23, 53, 24][-2::-1]
# Out:
# [53, 23]

# %%
-2->53,    -2-1=-3 -> 23

# %%
-2 > -3
# Out:
# True

# %%
ages
# Out:
# [23, 42, 23, 43, 64, 12, 53, 64]

# %%
ages[::-1]
# Out:
# [64, 53, 12, 64, 43, 23, 42, 23]

# %%
p = "programming"

# %%
# condition

# if step is negative then start must be start > end
# if step is positive then start must be less than end

# %%
p[3:11:-1]   # 3 > 11   3+1
# Out:
# ''

# %%
# modification in list

# %%
ages
# Out:
# [23, 42, 23, 43, 64, 12, 53, 64]

# %%
ages[0] = 28

# %%
print(ages)
# Out:
# [28, 42, 23, 43, 64, 12, 53, 64]

# %%
ages[-1] = 70

# %%
ages
# Out:
# [28, 42, 23, 43, 64, 12, 53, 70]

# %%
id(ages)
# Out:
# 2377086027968

# %%
ages[2] = 48

# %%
id(ages) #2377086027968
# Out:
# 2377086027968

# %%
ages = [42, 53, 13, 53, 12, 56, 76]
id(ages)
# Out:
# 2377118523840

# %%
names
# Out:
# ['usman', 'kamran', 'kaleem', 'wahab', 'akram']

# %%
names[0] = 3432

# %%
names
# Out:
# [3432, 'kamran', 'kaleem', 'wahab', 'akram']

# %%
names_str = "3432, 'kamran', 'kaleem', 'wahab', 'akram'"

# %%
len(names_str)
# Out:
# 42

# %%
names
# Out:
# [3432, 'kamran', 'kaleem', 'wahab', 'akram']

# %%
names[4] = "Akram"

# %%
names
# Out:
# [3432, 'kamran', 'kaleem', 'wahab', 'Akram']

# %%
names[5] = 'sofi'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 names[5] = 'sofi'
#
# IndexError: list assignment index out of range

# %%
## append

names.append('Sofi')

# %%
names
# Out:
# [3432, 'kamran', 'kaleem', 'wahab', 'Akram', 'Sofi']

# %%
### insert

names.insert(1, "qadir")

# %%
names
# Out:
# [3432, 'qadir', 'qadir', 'kamran', 'kaleem', 'wahab', 'Akram', 'Sofi']

# %%
names.append('abdullah, zakir')

# %%
names
# Out:
# [3432,
#  'qadir',
#  'qadir',
#  'kamran',
#  'kaleem',
#  'wahab',
#  'Akram',
#  'Sofi',
#  'abdullah, zakir']

# %%
## extend

names.extend(["zoha", 'parveen'])
names
# Out:
# [3432,
#  'qadir',
#  'qadir',
#  'kamran',
#  'kaleem',
#  'wahab',
#  'Akram',
#  'Sofi',
#  'abdullah, zakir',
#  'zoha',
#  'parveen']

# %%
len(names)
# Out:
# 11

# %%
marks = [39, 58, 35, 24]
len(marks)
# Out:
# 4

# %%
marks.append([50, 60])

# %%
marks
# Out:
# [39, 58, 35, 24, [50, 60]]

# %%
len(marks)
# Out:
# 5

# %%
marks[-1][0]
# Out:
# 50

# %%
marks[-1][1]
# Out:
# 60

# %%
marks.append("jo bhi hai")

# %%
marks
# Out:
# [39, 58, 35, 24, [50, 60], 'jo bhi hai']

# %%
marks.extend([53, 23, 64])

# %%
marks
# Out:
# [39, 58, 35, 24, [50, 60], 'jo bhi hai', 53, 23, 64]

# %%
len(marks)
# Out:
# 9

# %%
marks.extend('the')

# %%
marks
# Out:
# [39, 58, 35, 24, [50, 60], 'jo bhi hai', 53, 23, 64, 't', 'h', 'e']

# %%
marks.insert(2, [20, 30])

# %%
marks
# Out:
# [39, 58, [20, 30], 35, 24, [50, 60], 'jo bhi hai', 53, 23, 64, 't', 'h', 'e']

# %%
m = [42, 53, 23]
new_m = [90, 60, 50]

ind = 0

for i in range(2, 5):
     m.insert(i, new_m[ind])
     ind += 1

# %%
m
# Out:
# [42, 53, 90, 60, 50, 23]

# %%
m.insert(3, 40)
m

# %%
# mutable immutable

# %%
marks = [50, 40, 30, 59]

# %%
id(marks)  # 2516590330304
# Out:
# 2516590330304

# %%
marks[0] = 60

# %%
marks
# Out:
# [60, 40, 30, 59]

# %%
id(marks)
# Out:
# 2516590330304

# %%
marks.append(69)

# %%
marks
# Out:
# [60, 40, 30, 59, 69]

# %%
id(marks) #2516590330304
# Out:
# 2516590330304

# %%
#sting

# %%
name = "khalid"

# %%
name[0] = 'K'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 name[0] = 'K'
#
# TypeError: 'str' object does not support item assignment

# %%
id(name)
# Out:
# 2516590317232

# %%
name = name + "khan"

# %%
name
# Out:
# 'khalidkhan'

# %%
id(name)  #2516590317232
# Out:
# 2516596374960
