# %% [markdown]
# # Python Fundamentals - MCQ Assessment
#
# ## Topics Covered:
# 1. Print Function
# 2. Variables and Basic Data Types
# 3. Operators and Expressions
# 4. Conditional Statements
#
# **Total Questions: 60**
#
# **Instructions:**
# - Read each question carefully
# - Select the best answer from the given options
# - Answers are provided at the end
#
# ---

# %% [markdown]
# ## Section 1: Print Function (Questions 1-15)

# %% [markdown]
# **1. What is the output of: `print("Hello", "World")`**
#
# a) HelloWorld
# b) Hello World
# c) Hello,World
# d) Error

# %% [markdown]
# **2. What is the default separator in the print function?**
#
# a) Comma
# b) Space
# c) Tab
# d) Nothing

# %% [markdown]
# **3. What is the output of: `print("Python", end="***")`**
#
# a) Python***
# b) ***Python
# c) Python (with newline)
# d) ***Python***

# %% [markdown]
# **4. What does `\n` represent in a string?**
#
# a) Tab
# b) Newline
# c) Backslash
# d) Nothing special

# %% [markdown]
# **5. What is the output of: `print("A", "B", "C", sep="-")`**
#
# a) A B C
# b) A-B-C
# c) ABC
# d) A,B,C

# %% [markdown]
# **6. Which escape sequence represents a tab?**
#
# a) \n
# b) \t
# c) \b
# d) \r

# %% [markdown]
# **7. What is the output of: `print(r"C:\new\test")`**
#
# a) C:newtest
# b) C:\new\test
# c) Error
# d) C:\n\t

# %% [markdown]
# **8. How do you print a variable `name` using f-strings?**
#
# a) print("Name: {name}")
# b) print(f"Name: {name}")
# c) print("Name: " + name)
# d) Both b and c

# %% [markdown]
# **9. What is the output of: `print("Hello\nWorld")`**
#
# a) Hello\nWorld
# b) HelloWorld
# c) Hello
#    World
# d) Error

# %% [markdown]
# **10. Which is the correct way to format a float to 2 decimal places?**
#
# a) print(f"{3.14159:.2f}")
# b) print("%.2f" % 3.14159)
# c) print("{:.2f}".format(3.14159))
# d) All of the above

# %% [markdown]
# **11. What does `\\` represent in a string?**
#
# a) Double backslash
# b) Single backslash
# c) Escape character
# d) Error

# %% [markdown]
# **12. What is the default value of the `end` parameter in print()?**
#
# a) Space
# b) Tab
# c) Newline (\n)
# d) Nothing

# %% [markdown]
# **13. What is the output of: `print(10, 20, 30, sep="", end="!")`**
#
# a) 10 20 30!
# b) 102030!
# c) 10-20-30!
# d) 102030

# %% [markdown]
# **14. How do you print quotes inside a string?**
#
# a) print("He said \"Hello\"")
# b) print('He said "Hello"')
# c) Both a and b
# d) None of the above

# %% [markdown]
# **15. What is the output of: `print("*" * 5)`**
#
# a) *****
# b) * * * * *
# c) *5
# d) Error

# %% [markdown]
# ---
# ## Section 2: Variables and Data Types (Questions 16-30)

# %% [markdown]
# **16. Which of the following is a valid variable name?**
#
# a) 2variable
# b) variable_2
# c) variable-2
# d) for

# %% [markdown]
# **17. What is the data type of: `x = 5.0`**
#
# a) int
# b) float
# c) str
# d) bool

# %% [markdown]
# **18. What is the output of: `type(True)`**
#
# a) <class 'int'>
# b) <class 'bool'>
# c) <class 'str'>
# d) <class 'boolean'>

# %% [markdown]
# **19. What is the result of: `int("100")`**
#
# a) "100"
# b) 100
# c) 100.0
# d) Error

# %% [markdown]
# **20. What is the output of: `str(123) + str(456)`**
#
# a) 579
# b) "579"
# c) "123456"
# d) Error

# %% [markdown]
# **21. Which method converts a string to uppercase?**
#
# a) .uppercase()
# b) .upper()
# c) .toUpper()
# d) .capitalize()

# %% [markdown]
# **22. What is the output of: `len("Python")`**
#
# a) 5
# b) 6
# c) 7
# d) Error

# %% [markdown]
# **23. What is the value of: `bool(0)`**
#
# a) True
# b) False
# c) 0
# d) Error

# %% [markdown]
# **24. What does the following code output: `x, y = 5, 10; x, y = y, x; print(x)`**
#
# a) 5
# b) 10
# c) 15
# d) Error

# %% [markdown]
# **25. What is the output of: `"Python"[0]`**
#
# a) P
# b) y
# c) 0
# d) Error

# %% [markdown]
# **26. What is the output of: `"Hello"[-1]`**
#
# a) H
# b) o
# c) Error
# d) -1

# %% [markdown]
# **27. What is the result of: `float(10)`**
#
# a) 10
# b) 10.0
# c) "10.0"
# d) Error

# %% [markdown]
# **28. Which of the following is NOT a valid string method?**
#
# a) .strip()
# b) .replace()
# c) .remove()
# d) .split()

# %% [markdown]
# **29. What is the output of: `"apple" + "pie"`**
#
# a) applepie
# b) apple pie
# c) Error
# d) None

# %% [markdown]
# **30. What is the value of: `bool("")`**
#
# a) True
# b) False
# c) ""
# d) Error

# %% [markdown]
# ---
# ## Section 3: Operators and Expressions (Questions 31-45)

# %% [markdown]
# **31. What is the output of: `10 // 3`**
#
# a) 3.33
# b) 3
# c) 4
# d) 3.0

# %% [markdown]
# **32. What is the output of: `10 % 3`**
#
# a) 0
# b) 1
# c) 2
# d) 3

# %% [markdown]
# **33. What is the result of: `2 ** 3`**
#
# a) 5
# b) 6
# c) 8
# d) 9

# %% [markdown]
# **34. What is the output of: `10 == 10.0`**
#
# a) True
# b) False
# c) Error
# d) None

# %% [markdown]
# **35. What is the output of: `True and False`**
#
# a) True
# b) False
# c) 1
# d) 0

# %% [markdown]
# **36. What is the output of: `True or False`**
#
# a) True
# b) False
# c) 1
# d) Error

# %% [markdown]
# **37. What is the output of: `not True`**
#
# a) True
# b) False
# c) 0
# d) Error

# %% [markdown]
# **38. What is the output of: `"a" in "apple"`**
#
# a) True
# b) False
# c) 1
# d) Error

# %% [markdown]
# **39. What is the output of: `5 not in [1, 2, 3]`**
#
# a) True
# b) False
# c) Error
# d) None

# %% [markdown]
# **40. What is the output of: `x = [1, 2]; y = x; x is y`**
#
# a) True
# b) False
# c) Error
# d) None

# %% [markdown]
# **41. What is the output of: `5 & 3` (bitwise AND)**
#
# a) 0
# b) 1
# c) 2
# d) 3

# %% [markdown]
# **42. What is the output of: `5 | 3` (bitwise OR)**
#
# a) 5
# b) 6
# c) 7
# d) 8

# %% [markdown]
# **43. What is the output of: `x = 10; x += 5; print(x)`**
#
# a) 10
# b) 15
# c) 5
# d) Error

# %% [markdown]
# **44. What is the output of: `2 + 3 * 4`**
#
# a) 20
# b) 14
# c) 12
# d) 24

# %% [markdown]
# **45. What is the output of: `8 >> 2` (right shift)**
#
# a) 1
# b) 2
# c) 4
# d) 16

# %% [markdown]
# ---
# ## Section 4: Conditional Statements (Questions 46-60)

# %% [markdown]
# **46. What is the output of the following code?**
# ```python
# x = 10
# if x > 5:
#     print("A")
# print("B")
# ```
#
# a) A
# b) B
# c) A B
# d) Error

# %% [markdown]
# **47. What is the output of the following code?**
# ```python
# x = 3
# if x > 5:
#     print("A")
# else:
#     print("B")
# ```
#
# a) A
# b) B
# c) A B
# d) Nothing

# %% [markdown]
# **48. What is the output of the following code?**
# ```python
# score = 85
# if score >= 90:
#     print("A")
# elif score >= 80:
#     print("B")
# elif score >= 70:
#     print("C")
# else:
#     print("F")
# ```
#
# a) A
# b) B
# c) C
# d) F

# %% [markdown]
# **49. Which of the following is a falsy value?**
#
# a) 1
# b) "Hello"
# c) []
# d) True

# %% [markdown]
# **50. What is the output of: `print("Adult" if 20 >= 18 else "Minor")`**
#
# a) Adult
# b) Minor
# c) True
# d) Error

# %% [markdown]
# **51. What is the output of the following code?**
# ```python
# x = 5
# if x:
#     print("True")
# else:
#     print("False")
# ```
#
# a) True
# b) False
# c) 5
# d) Error

# %% [markdown]
# **52. What is the output of the following code?**
# ```python
# x = 10
# if x > 5:
#     if x > 15:
#         print("A")
#     else:
#         print("B")
# ```
#
# a) A
# b) B
# c) Nothing
# d) Error

# %% [markdown]
# **53. What is the correct syntax for a ternary operator?**
#
# a) condition ? true_value : false_value
# b) true_value if condition else false_value
# c) if condition then true_value else false_value
# d) condition ? true_value else false_value

# %% [markdown]
# **54. Which value is truthy?**
#
# a) 0
# b) None
# c) ""
# d) "0"

# %% [markdown]
# **55. What is the output of the following code?**
# ```python
# x = 15
# if x > 10:
#     print("A")
# if x > 20:
#     print("B")
# else:
#     print("C")
# ```
#
# a) A
# b) A C
# c) A B
# d) C

# %% [markdown]
# **56. What is the output of the following code?**
# ```python
# age = 25
# if age >= 18 and age <= 30:
#     print("Young Adult")
# ```
#
# a) Young Adult
# b) Nothing
# c) True
# d) Error

# %% [markdown]
# **57. What is the output of the following code?**
# ```python
# x = 0
# if not x:
#     print("Zero")
# ```
#
# a) Zero
# b) 0
# c) Nothing
# d) Error

# %% [markdown]
# **58. What is the output of the following code?**
# ```python
# num = 15
# if num % 2 == 0:
#     print("Even")
# else:
#     print("Odd")
# ```
#
# a) Even
# b) Odd
# c) 15
# d) Error

# %% [markdown]
# **59. Which operator is used to check if two values are NOT equal?**
#
# a) !=
# b) <>
# c) =/=
# d) !==

# %% [markdown]
# **60. What is the output of the following code?**
# ```python
# x = 5
# result = "Positive" if x > 0 else "Negative" if x < 0 else "Zero"
# print(result)
# ```
#
# a) Positive
# b) Negative
# c) Zero
# d) Error

# %% [markdown]
# ---
# ---
# # ANSWER KEY

# %% [markdown]
# ## Section 1: Print Function (1-15)
#
# 1. **b** - Hello World (default separator is space)
# 2. **b** - Space
# 3. **a** - Python*** (end parameter replaces newline)
# 4. **b** - Newline
# 5. **b** - A-B-C (sep="-" separates with dash)
# 6. **b** - \t (tab)
# 7. **b** - C:\new\test (r prefix makes it raw string)
# 8. **d** - Both b and c work
# 9. **c** - Hello (newline) World
# 10. **d** - All of the above
# 11. **b** - Single backslash (escaped)
# 12. **c** - Newline (\n)
# 13. **b** - 102030! (no separator, custom end)
# 14. **c** - Both a and b
# 15. **a** - ***** (string repetition)

# %% [markdown]
# ## Section 2: Variables and Data Types (16-30)
#
# 16. **b** - variable_2 (valid identifier)
# 17. **b** - float (decimal point makes it float)
# 18. **b** - <class 'bool'>
# 19. **b** - 100 (string to integer conversion)
# 20. **c** - "123456" (string concatenation)
# 21. **b** - .upper()
# 22. **b** - 6 (length of string)
# 23. **b** - False (0 is falsy)
# 24. **b** - 10 (values swapped)
# 25. **a** - P (first character, index 0)
# 26. **b** - o (last character, index -1)
# 27. **b** - 10.0 (integer to float)
# 28. **c** - .remove() (not a string method)
# 29. **a** - applepie (string concatenation)
# 30. **b** - False (empty string is falsy)

# %% [markdown]
# ## Section 3: Operators and Expressions (31-45)
#
# 31. **b** - 3 (floor division)
# 32. **b** - 1 (remainder/modulus)
# 33. **c** - 8 (2 to the power of 3)
# 34. **a** - True (values are equal)
# 35. **b** - False (both must be True)
# 36. **a** - True (at least one is True)
# 37. **b** - False (not inverts)
# 38. **a** - True ('a' is in 'apple')
# 39. **a** - True (5 is not in the list)
# 40. **a** - True (same object reference)
# 41. **b** - 1 (binary: 0101 & 0011 = 0001)
# 42. **c** - 7 (binary: 0101 | 0011 = 0111)
# 43. **b** - 15 (10 + 5)
# 44. **b** - 14 (multiplication before addition)
# 45. **b** - 2 (8 >> 2 = 8/4 = 2)

# %% [markdown]
# ## Section 4: Conditional Statements (46-60)
#
# 46. **c** - A B (condition true, then B always prints)
# 47. **b** - B (condition false, else executes)
# 48. **b** - B (score >= 80 is true)
# 49. **c** - [] (empty list is falsy)
# 50. **a** - Adult (condition is true)
# 51. **a** - True (5 is truthy)
# 52. **b** - B (x > 5 true, but x > 15 false)
# 53. **b** - true_value if condition else false_value
# 54. **d** - "0" (non-empty string is truthy)
# 55. **b** - A C (first if true prints A, second if false so else prints C)
# 56. **a** - Young Adult (condition is true)
# 57. **a** - Zero (not 0 is True)
# 58. **b** - Odd (15 % 2 = 1, not 0)
# 59. **a** - != (not equal operator)
# 60. **a** - Positive (5 > 0 is true)
