# %%
### type conversion to integer from other data types

# %%
## int()

int(10.5)
# Out:
# 10

# %%
int(10.9)
# Out:
# 10

# %%
price = 340.5
print(int(price))
# Out:
# 340

# %%
# sting to integer

# if the sting contain only a number then it is possible to convert it to integer

# %%
age = "19"
age = int(age)
print(age)
print(type(age))
# Out:
# 19
# <class 'int'>

# %%
price = "100PKR"

price = int(price)

print(price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 price = "100PKR"
# ----> 3 price = int(price)
#       5 print(price)
#
# ValueError: invalid literal for int() with base 10: '100PKR'

# %%
price = "10.5"

price = int(price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 price = "10.5"
# ----> 3 price = int(price)
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
int(False)
# Out:
# 0

# %%
price = "-10"

price = int(price)
price
# Out:
# -10

# %%
int("%399")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 int("%399")
#
# ValueError: invalid literal for int() with base 10: '%399'

# %%
## conversion to float data type

# %%
print(float(10))
# Out:
# 10.0

# %%
print(float(1948797474))
# Out:
# 1948797474.0

# %%
price = "*40.7"

print(float(price))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 price = "*40.7"
# ----> 3 print(float(price))
#
# ValueError: could not convert string to float: '*40.7'

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
age = 328992
age = str(age)
print(age)
print(type(age))
# Out:
# 328992
# <class 'str'>

# %%
length = 328992.37488
length = str(length)
print(length)
print(type(length))
# Out:
# 328992.37488
# <class 'str'>

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
# conversion to boolean data type

# %%
bool(20)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool(-398)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool(1.0)
# Out:
# True

# %%
bool(0.0000000001)
# Out:
# True

# %%
bool(13891.482938292)
# Out:
# True

# %%
bool(-2892398.453)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
# sting to boolean

# %%
bool(' ')
# Out:
# True

# %%
bool(',')
# Out:
# True

# %%
bool('*')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
actual_username = "kamran"
actual_password = "secret123"

username = input("Enter username : ")
password = input("enter password ; ");

if username and password:
    if actual_username == username and actual_password == password:
        print("Successfull login")
    else:
        print("login failed")
else:
    print("Please enter username and password")
# Out:
# login failed

# %%
age = 47

age_status = "Minor" if age < 18 else "Adult" if age <60 else "Senior"

print(age_status)
# Out:
# Adult

# %%
age_status = print("Minor") if age<18 else print("Adult") if age < 60 else print("Senior")

print(age_status)
# Out:
# Adult
# None

# %%
print(print())
# Out:
# None

# %%
# Minor -> discount = 40%
# adult -> discount = 10%
# Senior -> discount = 30%

age = 10

discount = 0.40 if age<18 else 0.10 if age<60 else 0.30

print(discount)
# Out:
# 0.4

# %%
age = 75

discount = input("Enter Discount for Minors : ") if age<18 else input("Enter discount for Adults : ") if age<60 else input("Enter Discount for Seniors : ")

print(discount)
# Out:
# 0.60

# %%
dis = input("Enter Discount for Minors : ")
# Out:
# '0.40'

# %%
day = input("Enter the first two characters of a day : ")

if day == 'mo':
    print("Monday")
# Out:
#   Cell In[66], line 3
#     if day == 'mo'
#                   ^
# SyntaxError: expected ':'

# %%
mo -> monday
Mo -> monday
mO -> monday
MO -> monday
