# %%
# conditioanl statements
# if statement

# %%
# if condition:
    # statements
    # statemtns

# %%
if True:
    print("hellow rodld")
# Out:
# hellow rodld

# %%
age = 20

if age<18:
    print("minor age")
print("heello")
# Out:
# heello

# %%
age<18
# Out:
# False

# %%
score = int(input("Enter score : "));

if score>90:
    print("Grade A")

if score>80:
    print("Grade B")

if score>70:
    print("Grade C")

if score>60:
    print("Grade D")

if score>50:
    print("Grade F")
# Out:
# Grade C
# Grade D
# Grade F

# %%
if condition:
    print
else:
    print

# %%
age = 46

if age< 18:
    print("minor")
else:
    print("adult")
# Out:
# adult

# %%
## elif:

if True:
    print("first one")
    print("second line of if body")
elif True:
    print("body of elif")
else:
    print("body of else")
# Out:
# first one
# second line of if body

# %%
number = int(input("enter a number: "));

if number>10:
    print("number is greater than 10");
elif number>20:
    print("number is greater than 20");
else:
    print("less than 10")
# Out:
# number is greater than 10

# %%
score = int(input("Enter score : "));

if score>90:
    print("Grade A")
elif score>80:
    print("Grade B")
elif score>70:
    print("Grade C")
elif score>60:
    print("Grade D")
else:
    print("Grade F")
# Out:
# Grade C

# %%
age = 29;
has_licence = False

if age>=18:
   if has_licence:
      print('YOu can drive')
   else:
      print("your are old enough but need licence")
else:
   print("you are under 18")
# Out:
# your are old enough but need licence

# %%
has_licence == True
# Out:
# False

# %%
## even or odd

number = int(input("enter a number to check whether it odd or even :"));

if number%2 == 0:
    print("Number is even")
else:
    print("number is odd")
# Out:
# number is odd

# %%
light = input("Enter the light status").lower()

if light == 'red':
    print("stop! don't cross")
elif light == 'green':
    print("you can go")
elif light == 'yellow':
    print("ready to go")
else:
    print("something bad happended")
# Out:
# something bad happended

# %%
age = 38
has_licence = True

if age>=18 or has_licence:
    print("you can drive")
# Out:
# you can drive

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
c = int(input("enter third number: "))

# %%
print("a  ",a)
print("b  ",b)
print("c  ",c)
# Out:
# a   34
# b   56
# c   687

# %%
if c < a > b:
    print("A is greater")
elif c < b > a:
    print("B is greater")
else:
    print("C is greater")
# Out:
# C is greater

# %%
bool('')
# Out:
# False

# %%
True and bool('is_raining')
# Out:
# True

# %%
actual_name = 'haseeb'
actual_pass = 'secret123'

name = input("enter your name: ");
password = input("enter your pass: ");
if name and password:
    print("the string is not empty, it's mean user has enter his name and password")
    if name==actual_name and actual_pass==password:
        print("successful login!")
    else:
        print("please enter a valid user name or password")
else:
    print("please enter your name and password first!")
# Out:
# the string is not empty, it's mean user has enter his name and password
# please enter a valid user name or password

# %%
score  = int(input("Enter student marks : "))

if score >= 50: print("pass")
else: print("Fail")
# Out:
# Fail

# %%
score = int(input("enter student marks ; "))

is_passed = True if score>=50 else False

# %%
print(is_passed)
# Out:
# True

# %%
tem = 37

print("hot") if tem>27 else print('cold')
# Out:
# hot

# %%
print(print("hot") if tem>27 else print('cold'))
# Out:
# hot
# None

# %%
print("hot") if tem>27 else print('cold')
# Out:
# hot

# %%
print(None)
# Out:
# None

# %%
a = int(input("Enter first number :  "))
b = int(input("Enter seconed number :  "))
c = int(input("Enter third number :  "))
d = int(input("Enter fourth number :  "))

if a>b:
    if a>c:
        if a>d:
            print(f"{a} is greater! in the numbers list {a, b, c}")
        else:
            print(f"{d} is greater! in the numbers list {a, b, c})
    elif c>d:
    
        print(f"{c} is greater! in the numbers list {a, b, c}")
elif b>c:
    print(f"{b} is greater! in the numbers list {a, b, c} ")
else:
    print(f"{c} is greater! in the numbers list {a, b, c}")
# Out:
# 97 is greater! in the numbers list (23, 56, 97)
