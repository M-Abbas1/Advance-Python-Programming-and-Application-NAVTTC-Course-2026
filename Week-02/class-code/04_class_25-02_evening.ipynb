# %%
a = 10
b = 10

if a != b:
    print(f"{a} is euqal to {b}")
    print("will this line be executed")

# %%
a != b
# Out:
# False

# %%
fruits = "apple, orange, mango"

if 'apple' in fruits:
    print("apples are available")
# Out:
# apples are available

# %%
'apple' in fruits
# Out:
# True

# %%
a = 10
b = 10
c = 16

if a is b is c:
    print("Both a b, and c has same memory locations")
print(id(a))
print(id(b))
print(id(c))
# Out:
# 140706334692424
# 140706334692424
# 140706334692616

# %%
a is b
# Out:
# True

# %%
a is b is c
# Out:
# False

# %%
username = 'tariq'
password = 'pass123'

input_username = input("Enter username : ")
input_password = input("Enter Password : ")

if username == input_username:
    print("access allowed for username")

if password == input_password:
    print("access allowed for")
# Out:
# access allowed for password

# %%
username = 'tariq'
password = 'pass123'

input_username = input("Enter username : ")
input_password = input("Enter Password : ")

if username == input_username  and  password==input_password:
    print("Full access allowed")

# %%
print("Hello", "world")
# Out:
# Hello world

# %%
print("200\\t")
# Out:
# 200

# %%
print("hi", end='======')
print('HI')
# Out:
# hi======HI

# %%
p = "python"

"python"[0]
# Out:
# 'p'

# %%
name = 'khalid'
age = 30


print(f"my name is {name} and my age is {age}")
# Out:
# my name is khalid and my age is 30

# %%
print("my name is {} and my age is {}".format(age, name))
# Out:
# my name is 30 and my age is khalid

# %%
print("my name is {1} and my age is {0}".format(age, name))
# Out:
# my name is khalid and my age is 30

# %%
print("my name is {n} and my age is {a}".format(n=name, a=age))
# Out:
# my name is khalid and my age is 30

# %%
print("my name is {} and my age is".format(30+46+4))
# Out:
# my name is 80 and my age is

# %%
print(name)
print(age)
# Out:
# khalid
# 30

# %%
print(f"my name is {'Muhammad '+name} and my age is {age+5}")
# Out:
# my name is Muhammad khalid and my age is 35

# %%
# if-else statement

# %%
age  = int(input("Enter your age : "))

if age < 18:
    print("you can't drive")
else:
    print("you can drive")
# Out:
# you can drive

# %%
username = input("enter your name  : ")
password = input("Enter your password : ")

if username and password:
    print("username and password are not empty")
    print("so you can proceed for comparison")
else:
    print("you entered an empty username and password")
# Out:
# you entered an empty username and password

# %%
actual_username = "john"
actual_password = "secret123"

username = input("enter your name ")
password = input("enter your password")


if actual_username == username and actual_password == password:
    print("access allowed")
    print(f"welcome back {username} to our app")
    


else:
    print("ERROR: Access denied!")
# Out:
# access allowed
# welcome back john to our app

# %%
marks = int(input("Enter student marks : "))

if marks >= 90:
    print("Grade A")

if marks >= 80:
    print("Grade B")

if marks >= 70:
    print("Grade C")

if marks >= 60:
    print("Grade D")

else:
    print("Grade F Fail")
# Out:
# Grade A
# Grade B
# Grade C
# Grade D

# %%
marks = int(input("Enter student marks : "))

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
else:
    print("Grade F Fail")
# Out:
# Grade F Fail

# %%
age = 20
has_licence = False

if age >= 18:
    if has_licence:
        print("you can drive!")
    else:
        print("you don't have a licence")
else:
    print("you are under 18")

print('ihi')
# Out:
# you don't have a licence
# ihi

# %%
username = 'tariq'
password = 'pass123'

input_username = input("Enter username : ")
input_password = input("Enter Password : ")

print("username : ",input_username)
print("password : ", input_password)

if input_username and input_password:
    if input_username==username and input_password==password:
        print("Login Successfull")
    else:
        print("Error: Invalid username or password")
else:
    print("Please enter something in username and password")
# Out:
# username :  tariq
# password :  pass123
# Login Successfull

# %%
if 0:
    print("zero")

# %%
if 'False':
    print("false")
# Out:
# false

# %%
if 'usman' in "usman, khalid, kamran, akram":
    print("yes usman is present in class")
# Out:
# yes usman is present in class

# %%
num = int(input("Enter a numbre : "))

if num>0:
    print(f"{num} is possitive")
elif num<0:
    print(f"{num } is negative ")
else:
    print(f"{num} is zero")
# Out:
# -78 is negative

# %% [markdown]
# ### Simple Calculator

# %%
# 1. Addition +
# 2. Subtraction -
# 3. Multiplication *
# 4. Division /
# 5. Modulus %
# 6. Floor Div //
# 7. Power **
# 8. Exit

# %%
print(f"{'Simple Calculator'.upper():^40}")
print("*"*40)
print("1. Addition +")
print("2. Subtraction -")
print("3. Multiplication *")
print("4. Division /")
print("5. Modulus %")
print("6. Floor Division //")
print("7. Power **")
print("8. Exit")

choice = input("Choose an Operation (1-8) : ")
print("*"*40)
# Out:
#            SIMPLE CALCULATOR
# ****************************************
# 1. Addition +
# 2. Subtraction -
# 3. Multiplication *
# 4. Division /
# 5. Modulus %
# 6. Floor Division //
# 7. Power **
# 8. Exit
# ****************************************

# %%
print(f"{'Simple Calculator'.upper():^40}")
print("*"*40)
print("1. Addition +")
print("2. Subtraction -")
print("3. Multiplication *")
print("4. Division /")
print("5. Modulus %")
print("6. Floor Division //")
print("7. Power **")
print("8. Exit")

choice = input("Choose an Operation (1-8) : ")
print("*"*40)


print(f"{'USER INPUT':^40}")
num1 = float(input("Enter First Number : "))
num2 = float(input("Enter Second Number : "))
print("*"*40)


if choice == '1':
    op_result = num1 + num2
elif choice == '2':
    op_result = num1 - num2
elif choice == '3':
    op_result = num1 * num2
elif choice == '4':
    if num2 == 0:
        print("Can't Divide a number by zero")
    else:
        op_result = num1 / num2
elif choice == '5':
    op_result = num1 % num2
elif choice == '6':
    op_result = num1 // num2
elif choice == '7':
    op_result = num1 ** num2
elif choice == '8':
    print("THANK YOU")
else:
    print("Choose a valid operation")


print(f"{'OUPUT':^40}")
print(f"Result : {op_result}")
# Out:
#            SIMPLE CALCULATOR
# ****************************************
# 1. Addition +
# 2. Subtraction -
# 3. Multiplication *
# 4. Division /
# 5. Modulus %
# 6. Floor Division //
# 7. Power **
# 8. Exit
# ****************************************
#                USER INPUT
# ****************************************
#                  OUPUT
# Result : 10.0
