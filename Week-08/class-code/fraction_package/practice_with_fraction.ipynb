# %%
from fraction import Fraction

# %%
frac = Fraction(10, 2)

# %%
print(type(frac))
# Out:
# <class 'fraction.Fraction'>

# %%
isinstance(frac, Fraction)
# Out:
# True

# %%
print(frac)

# %%
price = int(300)

# %%
print(type(price))
# Out:
# <class 'int'>

# %%
print(price)
# Out:
# 300

# %% [markdown]
# ### `__str__` magic method

# %%
## nom/den   e.g. 10/2

# %%
frac = Fraction(20, 4)

# %%
print(frac)
# Out:
# 20/4

# %%
price1 = 2300
price2 = 700

# %%
price1 + price2
# Out:
# 3000

# %%
frac1 = Fraction(10, 2)
frac2 = Fraction(20, 4)

# %%
frac1 + frac2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 frac1 + frac2
#
# TypeError: unsupported operand type(s) for +: 'Fraction' and 'Fraction'

# %% [markdown]
# ### `__add__` Magic method

# %%
from fraction import Fraction

# %%
frac1 = Fraction(10, 2)
frac2 = Fraction(20, 10)

# %%
print(frac1 + frac2)
# Out:
# 140/20

# %%
print(frac1 - frac2)
# Out:
# 60/20

# %%
print(frac1 * frac2)
# Out:
# 200/20

# %%
print(frac1/frac2)
# Out:
# 100/40

# %% [markdown]
# ### getter and setter function for nom and den

# %%
from fraction import Fraction

# %%
frac = Fraction(10, 4)

# %%
frac.nom
# Out:
# 10

# %%
frac.den
# Out:
# 4

# %%
frac.nom
# Out:
# 10

# %%
frac.den
# Out:
# 4

# %%
frac.nom = 30

# %%
frac.nom
# Out:
# 30

# %%
frac.den = 3

# %%
frac.den
# Out:
# 3

# %%
frac.nom = "4848"
# Out:
# Nomirator must be an integer

# %%
frac.den = 0
# Out:
# Denominator must not be zero

# %% [markdown]
# ## simplify function for our data type

# %%
from fraction import Fraction

# %%
frac = Fraction(140, 20)

# %%
print(frac.simplify())
# Out:
# 7/1

# %%
print(frac)
# Out:
# 140/20

# %%
simplified_frac = frac.simplify()

# %%
print(type(simplified_frac))
# Out:
# <class 'fraction.Fraction'>

# %%
simplified_frac.nom
# Out:
# 7

# %%
simplified_frac.den
# Out:
# 1

# %%
print(simplified_frac.simplify())
# Out:
# None

# %%
frac.simplified()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 frac.simplified()
#
# NameError: name 'frac' is not defined

# %%
print(frac)
# Out:
# 7/1

# %%
frac.nom
# Out:
# 7

# %%
frac.den
# Out:
# 1

# %%
frac1 = Fraction(30, 5)
frac2 = Fraction(30, 5)

# %%
frac1 == frac2
# Out:
# False

# %%
frac1 > frac2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 frac1 > frac2
#
# TypeError: '>' not supported between instances of 'Fraction' and 'Fraction'

# %%
from fraction import Fraction

# %% [markdown]
# ### Magic methods for comparision

# %%
frac1 = Fraction(30, 3)
frac2 = Fraction(30, 3)

# %%
frac1 == frac2
# Out:
# True

# %%
frac2.simplified()

# %%
print(frac2)
# Out:
# 10/1

# %%
print(frac1)
# Out:
# 30/3

# %%
frac1 == frac2
# Out:
# True

# %%
Fraction(140, 70) == Fraction(2, 1)
# Out:
# True
