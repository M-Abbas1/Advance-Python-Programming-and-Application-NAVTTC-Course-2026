# %%
class User:
    def __init__(self, name, email, addr):
        self.name = name
        self.email = email
        self.address = addr

    def login(self, n, e):
        if self.name == n and self.email == e:    # ahmad == ali and  asmad@gmail.com == ali@gmail.com
            print("arre to phir se agaya!")
        else:
            print("Are you a cheater")


    def logout(self):
        print("Da Allah Pa Aman")

# %%
user1 = User("Asmad", "asmad@gmail.com", "d type")

# %%
user1.logout()
# Out:
# Da Allah Pa Aman

# %%
user1.name
# Out:
# 'Asmad'

# %%
user1.email
# Out:
# 'asmad@gmail.com'

# %%
user1.address
# Out:
# 'd type'

# %%
user1.login('ali', "ali@gmial.com")
# Out:
# Are you a cheater

# %%
user1.login('Asmad', 'asmad@gmail.com')
# Out:
# arre to phir se agaya!

# %%
user2 = User('kashaf', "kashaf@gmail.com", "Corvit")

# %%
user2.name
# Out:
# 'kashaf'

# %%
user1.name
# Out:
# 'Asmad'

# %%
user2.email
# Out:
# 'kashaf@gmail.com'

# %%
user2.address
# Out:
# 'Corvit'

# %%
user2.login('kashaf', 'kashaf@gmail.com')
# Out:
# arre to phir se agaya!

# %%
user2.logout()
# Out:
# Da Allah Pa Aman

# %%
class User:
    def __init__(self, name, email, addr):
        self.name = name
        self.email = email
        self.address = addr

    def login(self, n, e):
        if self.name == n and self.email == e:   
            print("arre to phir se agaya!")
        else:
            print("Are you a cheater")


    def logout(self):                         ## user2.logout() --> User.logout(user2)
        print(self.name)                   ## invoke
        print("Da Allah Pa Aman")

# %%
user1 = User('zeenat', '123@gmail.com', 'kaha se ho')

# %%
print(id(user1))
# Out:
# 2368082008224

# %%
user2 = User('ali', 'ali@gmail.com', 'peshawar')

# %%
print(id(user2))
# Out:
# 2368082010672

# %%
user1.logout()
# Out:
# zeenat
# Da Allah Pa Aman

# %%
print(id(user1))
# Out:
# 2368082008224

# %%
user2.logout()
# Out:
# ali
# Da Allah Pa Aman

# %%
print(id(user2))
# Out:
# 2368082010672

# %%
user1.logout()      ##  User.logout(user1)
# Out:
# zeenat
# Da Allah Pa Aman

# %%
User.logout(user1)
# Out:
# zeenat
# Da Allah Pa Aman

# %%
user1.

# %%
full_name = "Kashaf Noor"

# %%
## object_name = ClassName()

# %%
address = str("ahmad")

# %%
age = int(38)

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
isinstance(age, float)
# Out:
# False

# %%
print(type(user1))
# Out:
# <class '__main__.User'>

# %%
isinstance(user2, User)
# Out:
# True
