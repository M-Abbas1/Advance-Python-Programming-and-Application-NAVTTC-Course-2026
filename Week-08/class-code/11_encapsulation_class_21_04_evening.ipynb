# %%
class Product:
    def __init__(self, name, price, stock):
        self.name = name
        self.price = price
        self.stock = stock

    def update_price(self, new_price):
        self.price = new_price
        print("price updated successfully!")

    def check_availability(self):
        return self.stock

# %%
product1 = Product('laptop', 100000, 10)

# %%
print(product1.name)
print(product1.price)
print(product1.stock)
# Out:
# laptop
# 100000
# 10

# %%
product1.update_price(120000)
# Out:
# price updated successfully!

# %%
product1.price
# Out:
# 120000

# %%
product1.check_availability()
# Out:
# 10

# %%
product2 = Product('mouse', 500, 20)

# %%
print(product2.name)
print(product2.price)
print(product2.stock)
# Out:
# mouse
# 500
# 20

# %%
products = [product1, product2]

# %%
print(type(products))
# Out:
# <class 'list'>

# %%
print(type(products[0]))
# Out:
# <class '__main__.Product'>

# %%
for pro in products:
    print("*"*20)
    print(pro.name)
    print(pro.price)
    print(pro.stock)
# Out:
# ********************
# laptop
# 120000
# 10
# ********************
# mouse
# 500
# 20

# %%
class Product:
    def __init__(self, name, price, stock):
        self.name = name
        self.price = price
        self.stock = stock

    def update_price(self, new_price):
        self.price = new_price
        print("price updated successfully!")

    def check_availability(self):
        return self.stock

# %%
n = input("Etner Product Name : ")
p = float(input("Enter Product Price : "))
s = int(input("Enter Product Stock : "))

p1 = Product(n, p, s)
p2 = Product(n, p, s)

# %%
print(p1.name)
print(p1.price)
print(p1.stock)
# Out:
# laptop
# 100000.0
# 20

# %%
print(p2.name)
print(p2.price)
print(p2.stock)
# Out:
# laptop
# 100000.0
# 20

# %%
products = []

for i in range(1, 6):
    print(f"Creating Product {i}")
    n = input("Etner Product Name : ")
    p = float(input("Enter Product Price : "))
    s = int(input("Enter Product Stock : "))

    product = Product(n, p, s)

    print("Product Created Successfully!")

    products.append(product)

    print("Product appended to products list")

    print("*"*20)
# Out:
# Creating Product 1
# Product Created Successfully!
# Product appended to products list
# ********************
# Creating Product 2
# Product Created Successfully!
# Product appended to products list
# ********************
# Creating Product 3
# Product Created Successfully!
# Product appended to products list
# ********************
# Creating Product 4
# Product Created Successfully!
# Product appended to products list
# ********************
# Creating Product 5
# Product Created Successfully!
# Product appended to products list
# ********************

# %%
print(type(products))
# Out:
# <class 'list'>

# %%
len(products)
# Out:
# 5

# %%
print(type(products[0]))
# Out:
# <class '__main__.Product'>

# %%
print(products[0].name)
print(products[0].price)
print(products[0].stock)
# Out:
# laptop
# 20000.0
# 20

# %%
products[0].check_availability()
# Out:
# 20

# %%
##

# %% [markdown]
# ## Encapsulation

# %% [markdown]
# ### ATM Class

# %%
correct_pin = 3930

# %%
class ATM:
    def __init__(self, atm_id, location, cash_available):
        self.atm_id = atm_id
        self.location = location
        self.cash_available = cash_available

    def verify_pin(self, user_pin):
        if user_pin == correct_pin:
            print("Login Successful!")
            return True
        else:
            return False

    def withdraw_cash(self):
        user_pin = int(input("Enter Pin : "))
        is_successful = self.verify_pin(user_pin)

        if is_successful:
            withdrawal_amount = int(input("Enter Amount : "))
            self.cash_available -= withdrawal_amount
            print("Withdrawal Successfull")
        else:
            print("Invalid Credintials")

# %%
HBL_atm = ATM(1, "Corvit", 1000000)

# %%
print(HBL_atm.atm_id)
print(HBL_atm.location)
print(HBL_atm.cash_available)
# Out:
# 1
# Corvit
# 1000000

# %%
HBL_atm.withdraw_cash()
# Out:
# Invalid Credintials

# %%
HBL_atm.withdraw_cash()
# Out:
# Login Successful!
# Withdrawal Successfull

# %%
HBL_atm.cash_available
# Out:
# 990000

# %%
class ATM:
    def __init__(self, atm_id, location, cash_available):
        self.atm_id = atm_id
        self._location = location                 # protected
        self.__cash_available = cash_available     ## private variable

    def verify_pin(self, user_pin):
        if user_pin == correct_pin:
            print("Login Successful!")
            return True
        else:
            return False

    def withdraw_cash(self):
        user_pin = int(input("Enter Pin : "))
        is_successful = self.verify_pin(user_pin)

        if is_successful:
            withdrawal_amount = int(input("Enter Amount : "))
            self.cash_available -= withdrawal_amount
            print("Withdrawal Successfull")
        else:
            print("Invalid Credintials")

# %%
atm1 = ATM(101, "GC Universitu, faisalabad", 200000)

# %%
atm1.location
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 atm1.location
#
# AttributeError: 'ATM' object has no attribute 'location'

# %%
atm1._location
# Out:
# 'GC Universitu, faisalabad'

# %%
atm1.cash_available
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 atm1.cash_available
#
# AttributeError: 'ATM' object has no attribute 'cash_available'

# %%
atm1.__cash_available
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 atm1.__cash_available
#
# AttributeError: 'ATM' object has no attribute '__cash_available'

# %%
atm1._ATM__cash_available
# Out:
# 200000
