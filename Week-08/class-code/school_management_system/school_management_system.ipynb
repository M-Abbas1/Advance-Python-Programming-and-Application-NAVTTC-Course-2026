# %%
import person_package

# %%
print(person_package.Person)
# Out:
# <class 'person_package.Person'>

# %%
p1 = person_package.Person('ali', 21, '123@')

# %%
import person_package as p

# %%
print(p)
# Out:
# <module 'person_package' from 'd:\\AI\\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\\Advance-Python-Programming-and-Application-NAVTTC-Course-2026\\Week-08\\class-code\\school_management_system\\person_package.py'>

# %%
print(p.Person)
# Out:
# <class 'person_package.Person'>

# %%
p1 = p.Person('name', 21, "122@gmail.com")

# %%
p1

# %%
print(type(p1))
# Out:
# <class 'person_package.Person'>

# %%
from person_package import Person

# %%
print(Person)
# Out:
# <class 'person_package.Person'>

# %%
p1 = Person('Ali', 31, 'ali@gmail.com')

# %%
print(p1.name)
print(p1.age)
print(p1.email)
# Out:
# Ali
# 31
# ali@gmail.com

# %%
p1.get_role()

# %%
print(p1)

# %%
## object_name = class_name()

# %%
l = list([23, 53, 23])

# %%
print(l)
# Out:
# [23, 53, 23]

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
print(type(p1))
# Out:
# <class 'person_package.Person'>

# %%
print(l)
# Out:
# [23, 53, 23]

# %%
print(p1)

# %%
from person_package import Person

# %%
p1 = Person('ali', 21, 'ali123@gmail.com')

# %%
print(p1)
# Out:
# Name: ali, Age: 21

# %%
p2 = Person('ahmad', 43, '123@gmail.com')

# %%
print(p2)
# Out:
# Name: ahmad, Age: 43

# %%
from person_package import Person

# %%
print(Person)
# Out:
# <class 'person_package.Person'>

# %%
p1 = Person('ali', 43, 'akdj@gmail.com')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 p1 = Person('ali', 43, 'akdj@gmail.com')
#
# TypeError: Can't instantiate abstract class Person with abstract method get_role

# %%
p1

# %%
p1.name
# Out:
# 'ali'

# %% [markdown]
# ### Student Class

# %%
from student_module import Student

# %%
print(Student)
# Out:
# <class 'student_module.Student'>

# %%
st1 = Student("stu101")

# %%
print(type(st1))
# Out:
# <class 'student_module.Student'>

# %%
st1.student_id
# Out:
# 'stu101'

# %%
st1.add_grade('python', 100)
# Out:
# Subject Added!

# %%
st1.__grades
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 st1.__grades
#
# AttributeError: 'Student' object has no attribute '__grades'

# %%
st1.show_grades()
# Out:
# {'python': 100}

# %%
grades = {'p':80, 'j':70, 'c':90}

# %%
grades.values()
# Out:
# dict_values([80, 70, 90])

# %%
avg = sum(grades.values())/len(grades.values())

# %%
avg / 25
# Out:
# 3.2

# %%
100/25
# Out:
# 4.0

# %%
from student_module import Student

# %%
st1 = Student("STU101", 'Ahmad faraz', 22, "123@gmail.com")

# %%
print(st1.student_id)
print(st1.name)
print(st1.age)
print(st1.email)
# Out:
# STU101
# Ahmad faraz
# 22
# 123@gmail.com

# %%
st1.get_role()
# Out:
# 'Student'

# %%
st1.gpa()
# Out:
# 0

# %%
st1.add_grade('python', 90)
# Out:
# Subject Added!

# %%
st1.add_grade('c++', 80)
# Out:
# Subject Added!

# %%
st1.gpa()
# Out:
# 3.4

# %%
st1.get_summary()
# Out:
# "Name : Ahmad faraz | ID : STU101 | Email : 123@gmail.com | Grades {'python': 90, 'c++': 80}"

# %%
st1 = Student("STU101", 'ali', 32, '123@gmail.com')
st2 = Student('STU102', "salman", 32, 'salman@gmail.com')

# %%
st1._student_count
# Out:
# 0

# %%
st1._student_count
# Out:
# 0

# %%
st1._student_count = 10

# %%
st1._student_count
# Out:
# 10

# %%
st2._student_count
# Out:
# 0

# %%
from student_module import Student

# %%
st1 = Student("STU101", 'ali', 32, '123@gmail.com')
st2 = Student('STU102', "salman", 32, 'salman@gmail.com')

# %%
st1._student_count
# Out:
# 0

# %%
st2._student_count
# Out:
# 0

# %%
st1._student_count = 1

# %%
st1._student_count
# Out:
# 1

# %%
st2._student_count
# Out:
# 0

# %%
class Student:
    _student_count = 0
    def __init__(self, student_id, name, age, email):
        self.student_id = student_id
        self.name = name
        self.age = age
        self.email = email
        self.__grades = {}
        Student._student_count += 1

    def get_role(self):
        return "Student"

    def add_grade(self, subject, grade):
        self.__grades[subject] = grade
        print("Subject Added!")
    
    def gpa(self):
        if self.__grades:
            avg = sum(self.__grades.values())/len(self.__grades.values())
            return avg/25
        else:
            return 0
        
    def get_summary(self):
        return f"Name : {self.name} | ID : {self.student_id} | Email : {self.email} | Grades {self.__grades}"
    

    def total(cls):
        return cls._student_count

# %%
st1 = Student("STU101", 'ali', 32, '123@gmail.com')

# %%
st1._student_count
# Out:
# 1

# %%
st2 = Student('STU102', "salman", 32, 'salman@gmail.com')

# %%
st2._student_count
# Out:
# 2

# %%
Student._student_count
# Out:
# 2

# %%
st1._student_count
# Out:
# 2

# %%
st1._student_count
# Out:
# 2

# %%
Student._student_count
# Out:
# 2

# %%
Student.get_summary(st1)
# Out:
# 'Name : ali | ID : STU101 | Email : 123@gmail.com | Grades {}'

# %%
st1.total()
# Out:
# 2

# %%
print(st1)

# %%
from student_module import Student

# %%
st1 = Student("STU101", 'ali', 32, '123@gmail.com')
st2 = Student('STU102', "salman", 32, 'salman@gmail.com')

# %%
st1.name
# Out:
# 'ali'

# %%
print(st1)
# Out:
# Name: ali, Age: 32

# %% [markdown]
# ## Teacher class

# %%
from teacher_module import Teacher

# %%
t1 = Teacher('abbas', 30, 'mr.mabbas@gmail.com', "python", 0)

# %%
print(t1.name)
print(t1.age)
print(t1.email)
print(t1.subject)
# Out:
# abbas
# 30
# mr.mabbas@gmail.com
# python

# %%
t1.get_role()
# Out:
# 'Teacher'

# %%
t1.get_summary()
# Out:
# 'Name : abbas | Age : 30 | Email : mr.mabbas@gmail.com | Subject : python'

# %%
t1.salary
# Out:
# kuch print kertha ho
# 0

# %%
t1.salar = 43

# %%
t1.salar
# Out:
# 43

# %%
t1.salary = "djkajdjadsklj"
# Out:
# Provide a valid salary input

# %%
# t1 = Teacher()

# %%
age = 12
