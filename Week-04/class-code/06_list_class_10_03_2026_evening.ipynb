# %%
## name, age, class no, semester, gpa

# %%
student1 = ["awal khan", 39, 21133, 6, 3.22]

# %%
print(student1[0])
print(student1[1])
print(student1[2])
print(student1[3])
print(student1[4])
# Out:
# awal khan
# 39
# 21133
# 6
# 3.22

# %%
for info in student1:
    print(info)
# Out:
# awal khan
# 39
# 21133
# 6
# 3.22

# %%
student1 = ["awal khan", 39, 21133, 6, 3.22]
student2 = ["samandar khan", 35, 21134, 4, 3.38]
student3 = ["badil khan", 30, 21136, 3, 3.60]

# %%
for info in student1:
    print(info)

for info in student2:
    print(info)

for info in student3:
    print(info)
# Out:
# awal khan
# 39
# 21133
# 6
# 3.22
# samandar khan
# 35
# 21134
# 4
# 3.38
# badil khan
# 30
# 21136
# 3
# 3.6

# %%
student_data = [
    ["awal khan", 39, 21133, 6, 3.22],
    ["samandar khan", 35, 21134, 4, 3.38],
    ["badil khan", 30, 21136, 3, 3.60]      
]     

# student_data[1][5][0]

# %%
student_data[1]
# Out:
# ['samandar khan', 35, 21134, 4, 3.38]

# %%
student_data[0]
# Out:
# ['awal khan', 39, 21133, 6, 3.22]

# %%
student_data[0][1]
# Out:
# 39

# %%
## nested loop

# %%
print("Before loop")

for i in range(3):   
    print(f"Entered into outer for loop, i : {i} ")

    for j in range(4):        
        print(f"j : {j}")
    
    print("After Inner loop")
# Out:
# Before loop
# Entered into outer for loop, i : 0
# j : 0
# j : 1
# j : 2
# j : 3
# After Inner loop
# Entered into outer for loop, i : 1
# j : 0
# j : 1
# j : 2
# j : 3
# After Inner loop
# Entered into outer for loop, i : 2
# j : 0
# j : 1
# j : 2
# j : 3
# After Inner loop

# %%
student_data
# Out:
# [['awal khan', 39, 21133, 6, 3.22],
#  ['samandar khan', 35, 21134, 4, 3.38],
#  ['badil khan', 30, 21136, 3, 3.6]]

# %%
for st in student_data:
    for info in st:
        print(info, end=' ')
    print()
# Out:
# awal khan 39 21133 6 3.22
# samandar khan 35 21134 4 3.38
# badil khan 30 21136 3 3.6
