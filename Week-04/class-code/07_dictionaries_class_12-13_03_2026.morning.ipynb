# %%
empty_dic = {}

# %%
type(empty_dic)
# Out:
# dict

# %%
len(empty_dic)
# Out:
# 0

# %%
student_info = {'name':'khalid', 'age':23, 'class_no':1232, 'sem':5}

# %%
student_info
# Out:
# {'name': 'khalid', 'age': 23, 'class_no': 1232, 'sem': 5}

# %%
student_info['name']
# Out:
# 'khalid'

# %%
student_info["age"]
# Out:
# 23

# %%
student_info['class_no']
# Out:
# 1232

# %%
items_dic = {1:220, 2:300, 3:400}

# %%
items_dic[1]
# Out:
# 220

# %%
items_dic[2]
# Out:
# 300

# %%
student_info = {'name':'usman', 'class':8, "section":"A", 'sub_marks':{'physic':50, 'maths':66, 'urdu':70}}

# %%
student_info['name']
# Out:
# 'usman'

# %%
student_info['class']
# Out:
# 8

# %%
student_info['sub_marks']
# Out:
# {'physic': 50, 'maths': 66, 'urdu': 70}

# %%
sub_marks = student_info['sub_marks']
sub_marks
# Out:
# {'physic': 50, 'maths': 66, 'urdu': 70}

# %%
sub_marks['urdu']
# Out:
# 70

# %%
student_info['sub_marks']

# %%
{'physic': 50, 'maths': 66, 'urdu': 70}['maths']
# Out:
# 66

# %%
student_info['sub_marks']['maths']
# Out:
# 66

# %%
shop_items = {"item_names":['lifeboy shampoo', 'rice', 'sugar', 'soup'], 'item_prices':[300, 290, 150, 160]}

# %%
type(shop_items)
# Out:
# dict

# %%
len(shop_items)
# Out:
# 2

# %%
shop_items['item_names']
# Out:
# ['lifeboy shampoo', 'rice', 'sugar', 'soup']

# %%
shop_items['item_prices']
# Out:
# [300, 290, 150, 160]

# %%
type(shop_items['item_names'])
# Out:
# list

# %%
type(shop_items['item_prices'])
# Out:
# list

# %%
print(shop_items['item_names'])
# Out:
# ['lifeboy shampoo', 'rice', 'sugar', 'soup']

# %%
print("Product Name", "\t",  "Product Price")
print("-"*40)

print(shop_items['item_names'][0], "\t", shop_items['item_prices'][0])
print(shop_items['item_names'][1], "\t\t\t", shop_items['item_prices'][1])
print(shop_items['item_names'][2], "\t\t\t", shop_items['item_prices'][2])
print(shop_items['item_names'][3], "\t\t\t", shop_items['item_prices'][3])
# Out:
# Product Name 	 Product Price
# ----------------------------------------
# lifeboy shampoo 	 300
# rice 			 290
# sugar 			 150
# soup 			 160

# %%
shop_items
# Out:
# {'item_names': ['lifeboy shampoo', 'rice', 'sugar', 'soup'],
#  'item_prices': [300, 290, 150, 160]}

# %%
len(shop_items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(shop_items)
#
# NameError: name 'shop_items' is not defined

# %%
shop_items = {"item_names":['lifeboy shampoo', 'rice', 'sugar', 'soup'], 'item_prices':[300, 290, 150, 160]}

# %%
shop_items
# Out:
# {'item_names': ['lifeboy shampoo', 'rice', 'sugar', 'soup'],
#  'item_prices': [300, 290, 150, 160]}

# %%
student_info = {
    'name':'asmat', 'age':23, 'height':5.8 
}

# %%
student_info
# Out:
# {'name': 'asmat', 'age': 23, 'height': 5.8}

# %%
## keys()

# %%
student_info.keys()
# Out:
# dict_keys(['name', 'age', 'height'])

# %%
shop_items.keys()
# Out:
# dict_keys(['item_names', 'item_prices'])

# %%
list(shop_items.keys())
# Out:
# ['item_names', 'item_prices']

# %%
# values

# %%
student_info
# Out:
# {'name': 'asmat', 'age': 23, 'height': 5.8}

# %%
student_info.values()
# Out:
# dict_values(['asmat', 23, 5.8])

# %%
shop_items.values()
# Out:
# dict_values([['lifeboy shampoo', 'rice', 'sugar', 'soup'], [300, 290, 150, 160]])

# %%
shop_items
# Out:
# {'item_names': ['lifeboy shampoo', 'rice', 'sugar', 'soup'],
#  'item_prices': [300, 290, 150, 160]}

# %%
shop_items['item_names']
# Out:
# ['lifeboy shampoo', 'rice', 'sugar', 'soup']

# %%
list(shop_items.values())
# Out:
# [['lifeboy shampoo', 'rice', 'sugar', 'soup'], [300, 290, 150, 160]]

# %%
student_info
# Out:
# {'name': 'asmat', 'age': 23, 'height': 5.8}

# %%
student_info.keys()
# Out:
# dict_keys(['name', 'age', 'height'])

# %%
type(student_info.values())
# Out:
# dict_values

# %%
type(student_info.keys())
# Out:
# dict_keys

# %%
type(student_info)
# Out:
# dict

# %%
list(student_info.values())[0]
# Out:
# 'asmat'

# %%
# items

# %%
student_info.items()
# Out:
# dict_items([('name', 'asmat'), ('age', 23), ('height', 5.8)])

# %%
type(student_info.items())
# Out:
# dict_items

# %%
list(student_info.items())[0]
# Out:
# ('name', 'asmat')

# %%
list(student_info.items())[0][1]
# Out:
# 'asmat'

# %%
student_info['name']
# Out:
# 'asmat'

# %%
## Looping

# %%
print(student_info['name'])
print(student_info['age'])
print(student_info['height'])
# Out:
# asmat
# 23
# 5.8

# %%
for info in student_info:
    print(info)
# Out:
# name
# age
# height

# %%
for info in student_info:
    print(info, "\t", student_info[info])
# Out:
# name 	 asmat
# age 	 23
# height 	 5.8

# %%
shop_items
# Out:
# {'item_names': ['lifeboy shampoo', 'rice', 'sugar', 'soup'],
#  'item_prices': [300, 290, 150, 160]}

# %%
------items in shop------
------------------------------
item Name              item price
lifeboy shampoo          300

# %%
print("lifeboy")
# Out:
# lifeboy

# %%
shop_items
# Out:
# {'item_names': ['lifeboy shampoo', 'rice', 'sugar', 'soup'],
#  'item_prices': [300, 290, 150, 160]}

# %%
for cat in shop_items:
    for item_name in shop_items[cat]:
        print(item_name)
# Out:
# lifeboy shampoo
# rice
# sugar
# soup
# 300
# 290
# 150
# 160

# %%
for key in shop_items.keys():
    print(shop_items[key])
# Out:
# ['lifeboy shampoo', 'rice', 'sugar', 'soup']
# [300, 290, 150, 160]

# %%
for v in shop_items.values():
    for item_name in v:
        print(item_name)
# Out:
# lifeboy shampoo
# rice
# sugar
# soup
# 300
# 290
# 150
# 160

# %%
student_info
# Out:
# {'name': 'asmat', 'age': 23, 'height': 5.8}

# %%
for val in student_info.values():
    print(val)
# Out:
# asmat
# 23
# 5.8

# %%
for key in student_info.keys():
    print(key)
# Out:
# name
# age
# height

# %%
for item in student_info.items():
    print(item)
    print(item[0], "\t", item[1])
# Out:
# ('name', 'asmat')
# name 	 asmat
# ('age', 23)
# age 	 23
# ('height', 5.8)
# height 	 5.8

# %%
student_info.items()  ## JSON
# Out:
# dict_items([('name', 'asmat'), ('age', 23), ('height', 5.8)])

# %%
students = {
    "STU101": {
        "name": "Ali Khan",
        "age": 21,
        "department": "Computer Science",
        "courses": ["Python", "Data Structures", "Database"],
        "grades": {"Python": 88, "Data Structures": 79, "Database": 85},
        "city": "Lahore"
    },

    "STU102": {
        "name": "Sara Ahmed",
        "age": 22,
        "department": "Software Engineering",
        "courses": ["Python", "Web Development", "AI"],
        "grades": {"Python": 91, "Web Development": 87, "AI": 90},
        "city": "Islamabad"
    },

    "STU103": {
        "name": "Usman Tariq",
        "age": 20,
        "department": "Information Technology",
        "courses": ["Networking", "Python", "Cyber Security"],
        "grades": {"Networking": 82, "Python": 75, "Cyber Security": 80},
        "city": "Faisalabad"
    },

    "STU104": {
        "name": "Hina Malik",
        "age": 23,
        "department": "Computer Science",
        "courses": ["Machine Learning", "Python", "Statistics"],
        "grades": {"Machine Learning": 89, "Python": 92, "Statistics": 84},
        "city": "Karachi"
    },

    "STU105": {
        "name": "Bilal Hassan",
        "age": 21,
        "department": "Software Engineering",
        "courses": ["Java", "Python", "Operating Systems"],
        "grades": {"Java": 76, "Python": 81, "Operating Systems": 78},
        "city": "Multan"
    }
}

# %%
students.keys()
# Out:
# dict_keys(['STU101', 'STU102', 'STU103', 'STU104', 'STU105'])

# %%
len(students)
# Out:
# 5

# %%
students['STU101']
# Out:
# {'name': 'Ali Khan',
#  'age': 21,
#  'department': 'Computer Science',
#  'courses': ['Python', 'Data Structures', 'Database'],
#  'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85},
#  'city': 'Lahore'}

# %%
stu101 = {'name': 'Ali Khan',
 'age': 21,
 'department': 'Computer Science',
 'courses': ['Python', 'Data Structures', 'Database'],
 'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85},
 'city': 'Lahore'}

# %%
stu101['name']
# Out:
# 'Ali Khan'

# %%
students['STU101']['name']
# Out:
# 'Ali Khan'

# %%
students['STU101']['courses']
# Out:
# ['Python', 'Data Structures', 'Database']

# %%
students['STU102']['grades']['AI']
# Out:
# 90

# %%
students['STU103']['GRades'.lower()]
# Out:
# {'Networking': 82, 'Python': 75, 'Cyber Security': 80}

# %%
students['STU104']
# Out:
# {'name': 'Hina Malik',
#  'age': 23,
#  'department': 'Computer Science',
#  'courses': ['Machine Learning', 'Python', 'Statistics'],
#  'grades': {'Machine Learning': 89, 'Python': 92, 'Statistics': 84},
#  'city': 'Karachi'}

# %%
students['STU104']['courses'][1]
# Out:
# 'Python'

# %%
students['STU104']['grades']['Machine Learning']
# Out:
# 89

# %%
students['STU102']
# Out:
# {'name': 'Sara Ahmed',
#  'age': 22,
#  'department': 'Software Engineering',
#  'courses': ['Python', 'Web Development', 'AI'],
#  'grades': {'Python': 91, 'Web Development': 87, 'AI': 90},
#  'city': 'Islamabad'}

# %%
students['STU102']['grades'].keys()
# Out:
# dict_keys(['Python', 'Web Development', 'AI'])

# %%
students['STU102']['grades'].values()
# Out:
# dict_values([91, 87, 90])

# %%
students['STU104']['grades']
# Out:
# {'Machine Learning': 89, 'Python': 92, 'Statistics': 84}

# %%
# looping

# %%
for student in students:
    print(student)
# Out:
# STU101
# STU102
# STU103
# STU104
# STU105

# %%
students.keys()
# Out:
# dict_keys(['STU101', 'STU102', 'STU103', 'STU104', 'STU105'])

# %%
for key in students.keys():
    print(key)
# Out:
# STU101
# STU102
# STU103
# STU104
# STU105

# %%
print("Name \t\t Age \t\t Department \t\t City")
for student in students.keys():
    print(students[student])
# Out:
# Name 		 Age 		 Department 		 City
# {'name': 'Ali Khan', 'age': 21, 'department': 'Computer Science', 'courses': ['Python', 'Data Structures', 'Database'], 'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85}, 'city': 'Lahore'}
# {'name': 'Sara Ahmed', 'age': 22, 'department': 'Software Engineering', 'courses': ['Python', 'Web Development', 'AI'], 'grades': {'Python': 91, 'Web Development': 87, 'AI': 90}, 'city': 'Islamabad'}
# {'name': 'Usman Tariq', 'age': 20, 'department': 'Information Technology', 'courses': ['Networking', 'Python', 'Cyber Security'], 'grades': {'Networking': 82, 'Python': 75, 'Cyber Security': 80}, 'city': 'Faisalabad'}
# {'name': 'Hina Malik', 'age': 23, 'department': 'Computer Science', 'courses': ['Machine Learning', 'Python', 'Statistics'], 'grades': {'Machine Learning': 89, 'Python': 92, 'Statistics': 84}, 'city': 'Karachi'}
# ...

# %%
students['STU101']
# Out:
# {'name': 'Ali Khan',
#  'age': 21,
#  'department': 'Computer Science',
#  'courses': ['Python', 'Data Structures', 'Database'],
#  'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85},
#  'city': 'Lahore'}

# %%
print("Name \t\t Age \t\t Department \t\t City")
for student in students.keys():
    print(students[student]['name'])
    break
# Out:
# Name 		 Age 		 Department 		 City
# Ali Khan

# %%
print("Name \t\t Age \t\t Department \t\tCity")
for student in students.keys():
    if student == 'STU103':
        print(students[student]['name'])
# Out:
# Name 		 Age 		 Department 		City
# Usman Tariq

# %%
print("Name \t\tAge \tDepartment \t\tCity")
print("-"*60)
for student in students.keys():
    print(students[student]['name'],  students[student]['age'], students[student]['department'], students[student]['city'], sep='\t')
# Out:
# Name 		Age 	Department 		City
# ------------------------------------------------------------
# Ali Khan	21	Computer Science	Lahore
# Sara Ahmed	22	Software Engineering	Islamabad
# Usman Tariq	20	Information Technology	Faisalabad
# Hina Malik	23	Computer Science	Karachi
# Bilal Hassan	21	Software Engineering	Multan

# %%
# Subject Name  Grades   Subject Name   Grades    Subject Name    Grade         
# python        90       AI             70        Networking       86 
# python        90       AI             70        Networking       86 
# python        90       AI             70        Networking       86 
# python        90       AI             70        Networking       86 
# python        90       AI             70        Networking       86

# %%
students['STU101']
# Out:
# {'name': 'Ali Khan',
#  'age': 21,
#  'department': 'Computer Science',
#  'courses': ['Python', 'Data Structures', 'Database'],
#  'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85},
#  'city': 'Lahore'}

# %%
for id, info in students.items():      # /
    print(info['courses'])
    print(info['grades'])
    print(list(info['grades'].values()))
    print()
# Out:
# ['Python', 'Data Structures', 'Database']
# {'Python': 88, 'Data Structures': 79, 'Database': 85}
# [88, 79, 85]
#
# ['Python', 'Web Development', 'AI']
# {'Python': 91, 'Web Development': 87, 'AI': 90}
# [91, 87, 90]
#
# ['Networking', 'Python', 'Cyber Security']
# {'Networking': 82, 'Python': 75, 'Cyber Security': 80}
# [82, 75, 80]
#
# ['Machine Learning', 'Python', 'Statistics']
# {'Machine Learning': 89, 'Python': 92, 'Statistics': 84}
# [89, 92, 84]
#
# ['Java', 'Python', 'Operating Systems']
# {'Java': 76, 'Python': 81, 'Operating Systems': 78}
# [76, 81, 78]

# %%
# Subject Name  Grades   Subject Name   Grades    Subject Name    Grade         
# python        90       AI             70        Networking       86 
# python        90       AI             70        Networking       86 
# python        90       AI             70        Networking       86 
# python        90       AI             70        Networking       86 
# python        90       AI             70        Networking       86

# %%
for id, info in students.items():      # /
    print(info['courses'][0], end='\t\t')
    print(list(info['grades'].values())[0], end='\t\t')

    print(info['courses'][1], end='\t\t')
    print(list(info['grades'].values())[1], end='\t\t')
    
    print(info['courses'][2], end='\t\t')
    print(list(info['grades'].values())[2])
# Out:
# Python		88		Data Structures		79		Database		85
# Python		91		Web Development		87		AI		90
# Networking		82		Python		75		Cyber Security		80
# Machine Learning		89		Python		92		Statistics		84
# Java		76		Python		81		Operating Systems		78
