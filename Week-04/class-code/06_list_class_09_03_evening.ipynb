# %%
# Modification in list

# %%
ages = [35, 64, 23, 53]
ages[0]
# Out:
# 35

# %%
ages[0] = 40

# %%
ages
# Out:
# [40, 64, 23, 53]

# %%
i want to change the first two elements in the list

# %%
ages[0:2] = [43, 70]

# %%
ages
# Out:
# [43, 70, 23, 53]

# %%
ages
# Out:
# [43, 70, 23, 53]

# %%
type(ages)
# Out:
# list

# %%
id(ages)  #1646128312064
# Out:
# 1646128312064

# %%
len(ages)
# Out:
# 4

# %%
ages.append(20)

# %%
print(ages)
# Out:
# [43, 70, 23, 53, 20]

# %%
id(ages)
# Out:
# 1646128312064

# %%
ages.append(23, 25, 17)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ages.append(23, 25, 17)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
## extend

# %%
ages
# Out:
# [43, 70, 23, 53, 20]

# %%
ages.extend([13, 75, 38])

# %%
ages
# Out:
# [43, 70, 23, 53, 20, 13, 75, 38]

# %%
ages.append(43)

# %%
ages
# Out:
# [43, 70, 23, 53, 20, 13, 75, 38, 43]

# %%
ages.append([23, 25, 17])

# %%
ages
# Out:
# [43, 70, 23, 53, 20, 13, 75, 38, 43, [23, 25, 17]]

# %%
str(True)
# Out:
# 'True'

# %%
bool(12389198.492)
# Out:
# True

# %%
list("python")
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
fruits = ['apple', 'banana', 'mango', 'cherry', 'graps']

# %%
fruits.append('pineapple')

# %%
fruits
# Out:
# ['apple', 'banana', 'mango', 'cherry', 'graps', 'pineapple']

# %%
fruits.extend(['peach'])

# %%
fruits
# Out:
# ['apple', 'banana', 'mango', 'cherry', 'graps', 'pineapple', 'peach']

# %%
fruits.extend('avacado')

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'mango',
#  'cherry',
#  'graps',
#  'pineapple',
#  'peach',
#  'a',
#  'v',
#  'a',
#  'c',
#  'a',
#  'd',
#  'o']

# %%
## insert

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'mango',
#  'cherry',
#  'graps',
#  'pineapple',
#  'peach',
#  'a',
#  'v',
#  'a',
#  'c',
#  'a',
#  'd',
#  'o']

# %%
fruits[-7:] = 'coconut'

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'mango',
#  'cherry',
#  'graps',
#  'pineapple',
#  'peach',
#  'c',
#  'o',
#  'c',
#  'o',
#  'n',
#  'u',
#  't']

# %%
fruits[-7:] = ["coconut"]

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'mango',
#  'cherry',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut']

# %%
len(fruits)
# Out:
# 8

# %%
fruits.insert()

# %%
print("programming", end='   ')
print("programming")
# Out:
# programming   programming

# %%
print("Name","khalid","age",29, sep='--')
# Out:
# Name--khalid--age--29

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'mango',
#  'cherry',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut']

# %%
fruits.insert(4, 'orange')

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'mango',
#  'cherry',
#  'orange',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut']

# %%
fruits.insert(1, 'nothing', 'something')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 fruits.insert(1, 'nothing', 'something')
#
# TypeError: insert expected 2 arguments, got 3

# %%
fruits.insert(2, ['kiwie', 'strawberry'])

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  ['kiwie', 'strawberry'],
#  'mango',
#  'cherry',
#  'orange',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut']

# %%
## Removing elements from list

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  ['kiwie', 'strawberry'],
#  'mango',
#  'cherry',
#  'orange',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut']

# %%
fruits.remove('orange')

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  ['kiwie', 'strawberry'],
#  'mango',
#  'cherry',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut']

# %%
fruits.extend(['orange', 'orange'])

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  ['kiwie', 'strawberry'],
#  'mango',
#  'cherry',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut',
#  'orange',
#  'orange']

# %%
fruits.remove('orange')

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  ['kiwie', 'strawberry'],
#  'mango',
#  'cherry',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut',
#  'orange']

# %%
fruits.insert(5, 'apple')

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  ['kiwie', 'strawberry'],
#  'mango',
#  'cherry',
#  'apple',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut',
#  'orange']

# %%
fruits.remove('apple')

# %%
fruits
# Out:
# ['banana',
#  ['kiwie', 'strawberry'],
#  'mango',
#  'cherry',
#  'apple',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut',
#  'orange']

# %%
# pop

# %%
fruits.pop()
# Out:
# 'orange'

# %%
fruits
# Out:
# ['banana',
#  ['kiwie', 'strawberry'],
#  'mango',
#  'cherry',
#  'apple',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut']

# %%
fruits.pop(1)
# Out:
# ['kiwie', 'strawberry']

# %%
fruits
# Out:
# ['banana',
#  'mango',
#  'cherry',
#  'apple',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut']

# %%
fruits[-1]
# Out:
# 'coconut'

# %%
price = 230

# %%
price
# Out:
# 230

# %%
del price

# %%
price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 price
#
# NameError: name 'price' is not defined

# %%
fruits
# Out:
# ['banana',
#  'mango',
#  'cherry',
#  'apple',
#  'graps',
#  'pineapple',
#  'peach',
#  'coconut']

# %%
del fruits[2]

# %%
fruits
# Out:
# ['banana', 'mango', 'apple', 'graps', 'pineapple', 'peach', 'coconut']

# %%
del fruits[2:5]

# %%
fruits
# Out:
# ['banana', 'mango', 'peach', 'coconut']

# %%
# clear

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %%
del fruits

# %%
fruits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 fruits
#
# NameError: name 'fruits' is not defined

# %%
students_names = []

for i in range(5):
    students_names.append(input(f"Enter {i+1} Name : "))

# %%
students_names
# Out:
# ['khalid', 'kaleem', 'usman', 'salman', 'akram']

# %%
students_names
# Out:
# ['kamran', 'kaleem', 'wahab', 'huzifa', 'karrem']

# %%
students_names.index('wahab')
# Out:
# 2

# %%
students_names.find('wahab')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 students_names.find('wahab')
#
# AttributeError: 'list' object has no attribute 'find'

# %%
students_names.index('abbas')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 students_names.index('abbas')
#
# ValueError: 'abbas' is not in list

# %%
price = [210, 240, 540, 360, 840]

# %%
price
# Out:
# [210, 240, 540, 360, 840]

# %%
price.sort()

# %%
price
# Out:
# [210, 240, 360, 540, 840]

# %%
price.sort(reverse=True)

# %%
price
# Out:
# [840, 540, 360, 240, 210]

# %%
sorted(price)
# Out:
# [210, 240, 360, 540, 840]

# %%
price
# Out:
# [840, 540, 360, 240, 210]

# %%
students_names = ['kmrn', 'kaleem', 'wahab', 'muh huzifa', 'akram', 'karrem']

# %%
students_names
# Out:
# ['kmrn', 'kaleem', 'wahab', 'muh huzifa', 'akram', 'karrem']

# %%
students_names.sort()

# %%
students_names
# Out:
# ['akram', 'kaleem', 'karrem', 'kmrn', 'muh huzifa', 'wahab']

# %%
students_names.count('akram')
# Out:
# 1

# %%
[23, 53, 64, 23, 85, 19, 23].count(23)
# Out:
# 3

# %%
[23, 53, 64, 23, 85, 19, 23].reverse()

# %%
price
# Out:
# [840, 540, 360, 240, 210]

# %%
price.reverse()

# %%
price
# Out:
# [210, 240, 360, 540, 840]

# %%
price[::-1]
# Out:
# [840, 540, 360, 240, 210]

# %%
price
# Out:
# [210, 240, 360, 540, 840]

# %%
l1 = [23, 53, 20, 62]
l2 = l1

# %%
print(l1)
print(l2)
# Out:
# [23, 53, 20, 62]
# [23, 53, 20, 62]

# %%
print(id(l1))
print(id(l2))
# Out:
# 1646135646528
# 1646135646528

# %%
l1
# Out:
# [23, 53, 20, 62]

# %%
l2
# Out:
# [23, 53, 20, 62]

# %%
l2[1:3] = [60, 40]

# %%
l2
# Out:
# [23, 60, 40, 62]

# %%
l1
# Out:
# [23, 60, 40, 62]

# %%
print(l1)
print(l2)
# Out:
# [23, 60, 40, 62]
# [23, 60, 40, 62]

# %%
l3 = l1.copy()

# %%
l3
# Out:
# [23, 60, 40, 62]

# %%
print(id(l1))
print(id(l3))
# Out:
# 1646135646528
# 1646135365504

# %%
l3[:2] = [12, 13]

# %%
l3
# Out:
# [12, 13, 40, 62]

# %%
l1
# Out:
# [23, 60, 40, 62]

# %%
l2
# Out:
# [23, 60, 40, 62]
