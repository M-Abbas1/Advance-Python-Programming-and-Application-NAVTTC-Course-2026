# %%
students = {
    'name' : 'ali',
    'age' : 30,
    'class no' : 211114,
    'department' : 'phychology'
}

# %%
students
# Out:
# {'name': 'ali', 'age': 30, 'class no': 211114, 'department': 'phychology'}

# %%
type(students)
# Out:
# dict

# %%
students['name']
# Out:
# 'ali'

# %%
students['age']
# Out:
# 30

# %%
students['age'] += 5 #  students['age'] = students['age'] + 5

# %%
students
# Out:
# {'name': 'ali', 'age': 35, 'class no': 211114, 'department': 'phychology'}

# %%
students['gpa'] = 3.5

# %%
students
# Out:
# {'name': 'ali',
#  'age': 35,
#  'class no': 211114,
#  'department': 'phychology',
#  'gpa': 3.5}

# %%
students.pop("age")
# Out:
# 35

# %%
students
# Out:
# {'name': 'ali', 'class no': 211114, 'department': 'phychology', 'gpa': 3.5}

# %%
students.keys()
# Out:
# dict_keys(['name', 'class no', 'department', 'gpa'])

# %%
students.values()
# Out:
# dict_values(['ali', 211114, 'phychology', 3.5])

# %%
students.items()
# Out:
# dict_items([('name', 'ali'), ('class no', 211114), ('department', 'phychology'), ('gpa', 3.5)])

# %%
list(students.items())
# Out:
# [('name', 'ali'),
#  ('class no', 211114),
#  ('department', 'phychology'),
#  ('gpa', 3.5)]

# %%
print(list(students.items())[0])
# Out:
# [('name', 'ali'),
#  ('class no', 211114),
#  ('department', 'phychology'),
#  ('gpa', 3.5)]

# %%
len(list(students.items()))
# Out:
# 4

# %%
print(list(students.items())[0])
# Out:
# ('name', 'ali')

# %%
students = {
    'name' : 'ali',
    'age' : 30,
    'class no' : 211114,
    'department' : 'phychology'
}

# %%
for key in students.keys():          # 
    print(key)
# Out:
# name
# class no
# department
# gpa

# %%
l = [32, 564, 23, 534]

for el in l:
    print(el)
# Out:
# 32
# 564
# 23
# 534

# %%
for k in students.keys():
    print(k)
# Out:
# name
# class no
# department
# gpa

# %%
for k in students:
    print(k)
# Out:
# name
# class no
# department
# gpa

# %%
for v in students.values():
    print(v)
# Out:
# ali
# 211114
# phychology
# 3.5

# %%
student_list = [('name', 'ali'),
 ('class no', 211114),
 ('department', 'phychology'),
 ('gpa', 3.5)]

# %%
student_list
# Out:
# [('name', 'ali'),
#  ('class no', 211114),
#  ('department', 'phychology'),
#  ('gpa', 3.5)]

# %%
for info in student_list:
    print(info)
# Out:
# ('name', 'ali')
# ('class no', 211114)
# ('department', 'phychology')
# ('gpa', 3.5)

# %%
a , b = 34, 63

# %%
print(a, b)
# Out:
# 34 63

# %%
c, d = (39, 60)

# %%
print(c, d)
# Out:
# 39 60

# %%
for k, v in student_list:
    print(k, v)
# Out:
# name ali
# class no 211114
# department phychology
# gpa 3.5

# %%
students.items()
# Out:
# dict_items([('name', 'ali'), ('class no', 211114), ('department', 'phychology'), ('gpa', 3.5)])

# %%
for item in students.items():
    print(item)
# Out:
# ('name', 'ali')
# ('class no', 211114)
# ('department', 'phychology')
# ('gpa', 3.5)

# %%
for k, v in students.items():
    print(k, v)
# Out:
# name ali
# class no 211114
# department phychology
# gpa 3.5

# %%
students
# Out:
# {'name': 'ali', 'class no': 211114, 'department': 'phychology', 'gpa': 3.5}

# %%
students.update({'name':'m ali', 'deparmtent':'computer science'})

# %%
students
# Out:
# {'name': 'm ali',
#  'class no': 211114,
#  'department': 'phychology',
#  'gpa': 3.5,
#  'deparmtent': 'computer science'}

# %%
students.pop('deparmtent')
# Out:
# 'computer science'

# %%
students
# Out:
# {'name': 'm ali', 'class no': 211114, 'department': 'phychology', 'gpa': 3.5}

# %%
students.update(name='muhammad ali', gpa=3.8)

# %%
students
# Out:
# {'name': 'muhammad ali',
#  'class no': 211114,
#  'department': 'phychology',
#  'gpa': 3.8}

# %%
students.get('name')
# Out:
# 'muhammad ali'

# %%
students['names']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 students['names']
#
# KeyError: 'names'

# %%
students.get('names')

# %%
keys = ['a', 'b', 'c', 'd', 'e']

values = ['apple', 'banana', 'cat', 'dog', 'elephant']

# %%
list(zip(keys, values))
# Out:
# [('a', 'apple'),
#  ('b', 'banana'),
#  ('c', 'cat'),
#  ('d', 'dog'),
#  ('e', 'elephant')]

# %%
dict(zip(keys, values))
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cat', 'd': 'dog', 'e': 'elephant'}

# %%
zip(keys, values)

# %%
students
# Out:
# {'name': 'muhammad ali',
#  'class no': 211114,
#  'department': 'phychology',
#  'gpa': 3.8}

# %%
students.keys()
# Out:
# dict_keys(['name', 'class no', 'department', 'gpa'])

# %%
students.values()
# Out:
# dict_values(['muhammad ali', 211114, 'phychology', 3.8])

# %%
keys
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
values
# Out:
# ['apple', 'banana', 'cat', 'dog', 'elephant']

# %%
zip = 34

# %%
zip(keys, values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 zip(keys, values)
#
# TypeError: 'int' object is not callable

# %%
marks = 30

status = 'pass' if marks >= 50 else 'fail'

# %%
status
# Out:
# 'fail'

# %%
marks = 90

# %%
grade = 'A' if marks>=90 else 'B' if marks>=80  else 'C'

# %%
grade
# Out:
# 'A'

# %%
squares = []

for i in range(1, 21):
    squares.append(i**2)

# %%
squares
# Out:
# [1,
#  4,
#  9,
#  16,
#  25,
#  36,
#  49,
#  64,
#  81,
#  100,
#  121,
#  144,
#  169,
#  196,
#  225,
#  256,
#  289,
#  324,
#  361,
#  400]

# %%
sq = [i**2 for i in range(1, 21)]

# %%
sq
# Out:
# [1,
#  4,
#  9,
#  16,
#  25,
#  36,
#  49,
#  64,
#  81,
#  100,
#  121,
#  144,
#  169,
#  196,
#  225,
#  256,
#  289,
#  324,
#  361,
#  400]

# %%
values
# Out:
# ['apple', 'banana', 'cat', 'dog', 'elephant']

# %%
for ind, el in enumerate(values):
    print(ind, el)
# Out:
# 0 apple
# 1 banana
# 2 cat
# 3 dog
# 4 elephant

# %%
alphabet = {}

for ind, el in enumerate(values):
    alphabet[ind] = el

# %%
list(enumerate(values))
# Out:
# [(0, 'apple'), (1, 'banana'), (2, 'cat'), (3, 'dog'), (4, 'elephant')]

# %%
for ind, el in enumerate(values):
    print(ind, el)
# Out:
# 0 apple
# 1 banana
# 2 cat
# 3 dog
# 4 elephant

# %%
alphabet = {}

for ind, el in enumerate(values):
    alphabet[ind] = el

# %%
alphabet
# Out:
# {0: 'apple', 1: 'banana', 2: 'cat', 3: 'dog', 4: 'elephant'}

# %%
alphabet[5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 alphabet[5]
#
# KeyError: 5

# %%
al = {ind:el  for ind, el in enumerate(values)}

# %%
al
# Out:
# {0: 'apple', 1: 'banana', 2: 'cat', 3: 'dog', 4: 'elephant'}
