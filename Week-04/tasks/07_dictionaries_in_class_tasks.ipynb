# %% [markdown]
# # Dictionaries - In-Class Tasks
#
# ## Instructions
#
# Complete these tasks during the class session with instructor guidance.
#
# **Guidelines:**
# - Work through tasks in order
# - Test your code thoroughly
# - Ask questions if needed
# - Focus on dictionary operations
#
# ---

# %% [markdown]
# ## Task 1: Create and Display Dictionary
#
# **Difficulty:** ⭐ Easy
#
# Create a dictionary for a book with title, author, year, and price. Display it nicely.
#
# **Requirements:**
# - Create dictionary with 4 keys
# - Display each key-value pair on separate line
#
# **Expected Output:**
# ```
# Book Information:
# Title: Python Programming
# Author: John Doe
# Year: 2024
# Price: $39.99
# ```

# %%
# Write your code here

# %% [markdown]
# ## Task 2: Accessing Dictionary Values
#
# **Difficulty:** ⭐ Easy
#
# Practice accessing dictionary values.
#
# **Requirements:**
# - Given: `person = {"name": "Alice", "age": 25, "city": "Boston", "job": "Engineer"}`
# - Access and print: name, age, city
# - Try to access a non-existent key safely using get()
#
# **Expected Output:**
# ```
# Name: Alice
# Age: 25
# City: Boston
# Country: Not specified
# ```

# %%
# Write your code here

# %% [markdown]
# ## Task 3: Adding and Updating Items
#
# **Difficulty:** ⭐⭐ Medium
#
# Modify a dictionary by adding and updating items.
#
# **Requirements:**
# - Start with: `student = {"name": "Bob", "age": 20}`
# - Add "grade" with value "A"
# - Add "gpa" with value 3.8
# - Update age to 21
# - Display final dictionary
#
# **Expected Output:**
# ```
# Updated Student:
# {'name': 'Bob', 'age': 21, 'grade': 'A', 'gpa': 3.8}
# ```

# %%
# Write your code here

# %% [markdown]
# ## Task 4: Iterating Through Dictionary
#
# **Difficulty:** ⭐⭐ Medium
#
# Practice different iteration methods.
#
# **Requirements:**
# - Given: `scores = {"Alice": 85, "Bob": 92, "Charlie": 78, "Diana": 95}`
# - Print all keys
# - Print all values
# - Print all key-value pairs formatted nicely
#
# **Expected Output:**
# ```
# Students: Alice, Bob, Charlie, Diana
# Scores: 85, 92, 78, 95
#
# Student Scores:
# Alice: 85
# Bob: 92
# Charlie: 78
# Diana: 95
# ```

# %%
# Write your code here

# %% [markdown]
# ## Task 5: Removing Dictionary Items
#
# **Difficulty:** ⭐⭐ Medium
#
# Practice removing items from dictionary.
#
# **Requirements:**
# - Start with: `data = {"a": 1, "b": 2, "c": 3, "d": 4, "e": 5}`
# - Remove "c" using pop() and print removed value
# - Remove "e" using del
# - Display final dictionary
#
# **Expected Output:**
# ```
# Removed value: 3
# Final dictionary: {'a': 1, 'b': 2, 'd': 4}
# ```

# %%
# Write your code here

# %% [markdown]
# ## Task 6: Word Counter
#
# **Difficulty:** ⭐⭐⭐ Hard
#
# Count word occurrences in a sentence.
#
# **Requirements:**
# - Get sentence: "hello world hello python world hello"
# - Split into words
# - Count each word occurrence using dictionary
# - Display word counts
#
# **Expected Output:**
# ```
# Word Counts:
# hello: 3
# world: 2
# python: 1
# ```

# %%
# Write your code here

# %% [markdown]
# ## Task 7: Grade Calculator
#
# **Difficulty:** ⭐⭐⭐ Hard
#
# Calculate statistics from a grade dictionary.
#
# **Requirements:**
# - Given: `grades = {"Alice": 85, "Bob": 92, "Charlie": 78, "Diana": 95, "Eve": 88}`
# - Calculate:
#   * Average grade
#   * Highest grade (with student name)
#   * Lowest grade (with student name)
#   * Count students who passed (>= 80)
#
# **Expected Output:**
# ```
# === Grade Statistics ===
# Average: 87.60
# Highest: Diana (95)
# Lowest: Charlie (78)
# Passed: 4 students
# ```

# %%
# Write your code here

# %% [markdown]
# ## Task 8: Nested Dictionary
#
# **Difficulty:** ⭐⭐⭐ Hard
#
# Work with nested dictionaries.
#
# **Requirements:**
# - Create dictionary for 3 students with name, age, and grade
# - Display all student information
# - Calculate average age
#
# **Expected Output:**
# ```
# === Students ===
# Student 1:
#   Name: Alice
#   Age: 20
#   Grade: A
#
# Student 2:
#   Name: Bob
#   Age: 22
#   Grade: B
#
# Average Age: 21.0
# ```

# %%
# Write your code here

# %% [markdown]
# ## Task 9: Dictionary Comprehension
#
# **Difficulty:** ⭐⭐⭐ Hard
#
# Create dictionaries using comprehension.
#
# **Requirements:**
# - Create dictionary of squares for numbers 1-10
# - Create dictionary of cubes for even numbers 2-10
# - Filter dictionary to keep only values > 50
#
# **Expected Output:**
# ```
# Squares: {1: 1, 2: 4, 3: 9, ..., 10: 100}
# Even Cubes: {2: 8, 4: 64, 6: 216, 8: 512, 10: 1000}
# Large Cubes: {4: 64, 6: 216, 8: 512, 10: 1000}
# ```

# %%
# Write your code here

# %% [markdown]
# ## Task 10: Phonebook Manager
#
# **Difficulty:** ⭐⭐⭐ Hard
#
# Create a simple phonebook system.
#
# **Requirements:**
# - Create phonebook with 3 contacts (name: phone number)
# - Add a new contact
# - Update a phone number
# - Delete a contact
# - Search for a contact
# - Display all contacts
#
# **Expected Output:**
# ```
# === Phonebook ===
# Alice: 555-1234
# Bob: 555-5678
# Charlie: 555-9012
#
# Contact found - Bob: 555-5678
# ```

# %%
# Write your code here

# %% [markdown]
# ---
# ## Bonus Challenge Tasks

# %% [markdown]
# ### Bonus 1: Merge Dictionaries
#
# Merge two dictionaries, adding values for common keys.
#
# **Example:** `{"a": 1, "b": 2}` + `{"b": 3, "c": 4}` = `{"a": 1, "b": 5, "c": 4}`

# %%
# Write your code here

# %% [markdown]
# ### Bonus 2: Invert Dictionary
#
# Swap keys and values in a dictionary.
#
# **Example:** `{"a": 1, "b": 2}` → `{1: "a", 2: "b"}`

# %%
# Write your code here

# %% [markdown]
# ### Bonus 3: Group By Value
#
# Group dictionary keys by their values.
#
# **Example:** `{"a": 1, "b": 2, "c": 1}` → `{1: ["a", "c"], 2: ["b"]}`

# %%
# Write your code here

# %% [markdown]
# ---
# ## Self-Assessment Checklist
#
# After completing these tasks:
#
# - [ ] Create dictionaries with different syntaxes
# - [ ] Access values using [] and get()
# - [ ] Add and update dictionary items
# - [ ] Remove items using pop(), del, clear()
# - [ ] Iterate using keys(), values(), items()
# - [ ] Work with nested dictionaries
# - [ ] Use dictionary comprehensions
# - [ ] Count occurrences with dictionaries
# - [ ] Handle missing keys safely
# - [ ] Apply dictionaries to real problems
#
# **Ask your instructor if you need help!**
