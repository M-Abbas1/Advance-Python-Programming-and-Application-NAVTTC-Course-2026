# %%
import socket

# %%
host = 'google.com'

try:
    ip = socket.gethostbyname(host)
    print("Website is reachable, IP : ", ip)
except:
    print("Website is not reachable")
# Out:
# Website is reachable, IP :  142.250.187.14

# %%
host = 'facebook.com'

try:
    ip = socket.gethostbyname(host)
    print("Website is reachable, IP : ", ip)
except:
    print("Website is not reachable")
