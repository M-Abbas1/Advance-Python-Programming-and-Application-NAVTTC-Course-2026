# %%
class Student:
    def __init__(self):
        self.name = None
        self.class_no = None
        self.age = None
        self.semester = None
        self.department = None
        self.subjects = None
        self.gpa = None

    def show_info(self):
        print("----Student Information----")

# %%
st1 = Student()

# %%
type(st1)
# Out:
# __main__.Student

# %%
isinstance(st1, Student)
# Out:
# True

# %%
print(type(st1))
# Out:
# <class '__main__.Student'>

# %%
isinstance(12, int)
# Out:
# True

# %%
a = int(46)   # (x, y)

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
num = 348437474

# %%
class Student:
    def __init__(self):
        self.name = None
        self.class_no = None
        self.age = None
        self.semester = None
        self.department = None
        self.subjects = None
        self.gpa = None

    def show_info(self):
        print("----Student Information----")

# %%
st1 = Student()

# %%
print(st1.name)
print(st1.age)
print(st1.class_no)
print(st1.semester)
print(st1.department)
print(st1.subjects)
print(st1.gpa)
# Out:
# None
# None
# None
# None
# None
# None
# None

# %%
st1.name = "ali"

# %%
st1.name
# Out:
# 'ali'

# %%
st1.class_no = 122212

# %%
st1.class_no
# Out:
# 122212

# %%
st1.show_info()
# Out:
# ----Student Information----

# %%
class Student:
    def __init__(self):
        self.name = None
        self.class_no = None
        self.age = None
        self.semester = None
        self.department = None
        self.subjects = None
        self.gpa = None

    def store_data(self):
        self.name = input("Enter Student Name : ")
        self.class_no = input("Enter Class No : ")
        self.age = int(input("Enter age : "))
        self.semester = int(input("Enter Semester : "))
        self.subjects = input("Enter subject : ")
        self.department = input("Enter Department : ")
        self.gpa = float(input("Enter gpa : "))

    def show_info(self):
        print("----Student Information----")
        print(f"Name : {self.name}")
        print(f"Age : {self.age}")
        print(f"Class No : {self.class_no}")
        print(f"Semester : {self.semester}")
        print(f"Subject : {self.subjects}")
        print(f"Department : {self.department}")
        print(f"GPA : {self.gpa}")

# %%
stu101 = Student()

# %%
print(type(stu101))
# Out:
# <class '__main__.Student'>

# %%
stu101.show_info()
# Out:
# ----Student Information----
# Name : None
# Age : None
# Class No : None
# Semester : None
# Subject : None
# Department : None
# GPA : None

# %%
stu101.store_data()

# %%
stu101.show_info()
# Out:
# ----Student Information----
# Name : Usman
# Age : 23
# Class No : 211212
# Semester : 4
# Subject : java
# Department : CS
# GPA : 3.45

# %%
stu102 = Student()

# %%
stu102.show_info()
# Out:
# ----Student Information----
# Name : None
# Age : None
# Class No : None
# Semester : None
# Subject : None
# Department : None
# GPA : None

# %%
stu102.store_data()

# %%
stu102.show_info()
# Out:
# ----Student Information----
# Name : shahid
# Age : 20
# Class No : 122121
# Semester : 6
# Subject : maths
# Department : IT
# GPA : 3.99999999

# %%
stu101.show_info()
# Out:
# ----Student Information----
# Name : Usman
# Age : 23
# Class No : 211212
# Semester : 4
# Subject : java
# Department : CS
# GPA : 3.45

# %%
stu101.show_info()

# %%
class Student:
    def __init__(self):
        print("when you create an object of this class, this special function will automatically called")
        self.name = None
        self.class_no = None
        self.age = None
        self.semester = None
        self.department = None
        self.subjects = None
        self.gpa = None
        print(id(self))

    def store_data(self):
        self.name = input("Enter Student Name : ")
        self.class_no = input("Enter Class No : ")
        self.age = int(input("Enter age : "))
        self.semester = int(input("Enter Semester : "))
        self.subjects = input("Enter subject : ")
        self.department = input("Enter Department : ")
        self.gpa = float(input("Enter gpa : "))

    def show_data(self):
        print("----Student Information----")
        print(f"Name : {self.name}")
        print(f"Age : {self.age}")
        print(f"Class No : {self.class_no}")
        print(f"Semester : {self.semester}")
        print(f"Subject : {self.subjects}")
        print(f"Department : {self.department}")
        print(f"GPA : {self.gpa}")

# %%
stu101 = Student()
# Out:
# when you create an object of this class, this special function will automatically called
# 1810040171408

# %%
print(id(stu101))
# Out:
# 1810040171408

# %%
stu101.show_data()
# Out:
# ----Student Information----
# Name : ahmad
# Age : 23
# Class No : 322
# Semester : 6
# Subject : java
# Department : CS
# GPA : 3.4

# %%
stu102 = Student()
# Out:
# when you create an object of this class, this special function will automatically called
# 1810046336016

# %%
print(id(stu102))
# Out:
# 1810046336016

# %%
stu102.show_data()
# Out:
# ----Student Information----
# Name : None
# Age : None
# Class No : None
# Semester : None
# Subject : None
# Department : None
# GPA : None

# %%
stu102.store_data()

# %%
stu102.show_data()
# Out:
# ----Student Information----
# Name : salman
# Age : 34
# Class No : 3232
# Semester : 5
# Subject : C++
# Department : SE
# GPA : 3.5

# %%
id(stu101)
# Out:
# 1810046943184

# %%
id(stu102)
# Out:
# 1810046447440

# %%
name = 'ahmad'

# %%
name
# Out:
# 'ahmad'

# %%
name = "salman"

# %%
name
# Out:
# 'salman'

# %%
ls_student = ['ali', 'ahamd', 'salman']

# %%
ls_student2 = ls_student

# %%
ls_student2
# Out:
# ['ali', 'ahamd', 'salman']

# %%
ls_student2.append('sohail')

# %%
ls_student2
# Out:
# ['ali', 'ahamd', 'salman', 'sohail']

# %%
ls_student
# Out:
# ['ali', 'ahamd', 'salman', 'sohail']

# %%
id(ls_student)
# Out:
# 1810047701632

# %%
id(ls_student2)
# Out:
# 1810047701632

# %%
ls_student3 = ls_student.copy()

# %%
id(ls_student3)
# Out:
# 1810047629056

# %%
id(ls_student)
# Out:
# 1810047701632

# %%
ls_student3.append('asad')

# %%
ls_student3
# Out:
# ['ali', 'ahamd', 'salman', 'sohail', 'asad']

# %%
ls_student
# Out:
# ['ali', 'ahamd', 'salman', 'sohail']
