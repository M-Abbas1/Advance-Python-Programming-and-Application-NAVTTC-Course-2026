# %%
class Employee:
    pass

# %%
emp1 = Employee()

# %%
isinstance(emp1, Employee)
# Out:
# True

# %%
class Employee:
    count = 101
    def __init__(self):
        self.id = Employee.count
        Employee.count += 1
        self.name = None
        self._salary = None        # protected
        self.__username = None    # private 
        self.__password = None

    def emp_login(self):
        self.__username = input("Enter Your Name : ")
        self.__password = input("Enter Password : ")

    def store_data(self, name, sal):
        self.name = name
        self._salary = sal

    def show_details(self):
        print("-------Employee Details------")
        print("ID : ", self.id)
        print("Name : ", self.name)

# %%
emp1 = Employee()

# %%
isinstance(emp1, Employee)
# Out:
# True

# %%
emp1.id
# Out:
# 101

# %%
print(emp1.name)
# Out:
# None

# %%
print(emp1._salary)
# Out:
# None

# %%
print(emp1.__password)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(emp1.__password)
#
# AttributeError: 'Employee' object has no attribute '__password'

# %%
print(emp1._user_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(emp1._user_name)
#
# AttributeError: 'Employee' object has no attribute '_user_name'

# %%
emp1.emp_login()

# %%
emp1.store_data("ali", 100000)

# %%
emp1.show_details()
# Out:
# -------Employee Details------
# ID :  101
# Name :  ali

# %%
emp2 = Employee()

# %%
emp2.id
# Out:
# 102

# %%
emp2.emp_login()

# %%
emp2.store_data("ahmad", 200000)

# %%
emp2.show_details()
# Out:
# -------Employee Details------
# ID :  102
# Name :  ahmad

# %%
emp2._Employee__username
# Out:
# 'ahmad'

# %%
age = int(23)

# %%
age
# Out:
# 23

# %%
isinstance(age, int)
# Out:
# True

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def eat(self):
        print(f"{self.name} is eating!")

    def sleep(self):
        print(f"{self.name} is sleeping")

# %%
a1 = Animal("Cow", 5)

# %%
a1.eat()    ## Animal.eat(a1)
Animal.eat(a1)
# Out:
# Cow is eating!
# Cow is eating!

# %%
a1.sleep()   ##  Animal.sleep(a1)
# Out:
# Cow is sleeping

# %%
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def eat(self):
        print(f"{self.name} is eating!")

    def sleep(self):
        print(f"{self.name} is sleeping")

class Dog(Animal):
    def bark(self):
        print(f"{self.name} says woof!")

# %%
dog1 = Dog("dog", 3)

# %%
dog1.eat()
# Out:
# dog is eating!

# %%
dog1.sleep()
# Out:
# dog is sleeping

# %%
dog1.name
# Out:
# 'dog'

# %%
dog1.age
# Out:
# 3

# %%
dog1.bark()
# Out:
# dog says woof!

# %%
animal1 = Animal('cat', 3)

# %%
animal1.name
# Out:
# 'cat'

# %%
animal1.age
# Out:
# 3

# %%
animal1.eat()
# Out:
# cat is eating!

# %%
animal1.sleep()
# Out:
# cat is sleeping

# %%
animal1.bark()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 animal1.bark()
#
# AttributeError: 'Animal' object has no attribute 'bark'

# %%
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def eat(self):
        print(f"{self.name} is eating!")

    def sleep(self):
        print(f"{self.name} is sleeping")

class Dog(Animal):
    def bark(self):
        print(f"{self.name} says woof!")


class Cat(Animal):
    def meow(self):
        print(f"{self.name} say meow!")

# %%
c1 = Cat('sardar', 2)

# %%
c1.eat()
# Out:
# sardar is eating!

# %%
c1.sleep()
# Out:
# sardar is sleeping

# %%
c1.meow()
# Out:
# sardar say meow!

# %%
## DRY  --> Don't Repeat Yourself

# %%
c1.meow()
# Out:
# sardar say meow!

# %%
marks = 30
print(type(marks))
# Out:
# <class 'int'>

# %%
class INT(int):
    pass

# %%
marks = INT(20)

# %%
marks
# Out:
# 20

# %%
a, b = INT(33), INT(29)

# %%
a + b
# Out:
# 62

# %%
print(list)
# Out:
# <class 'list'>

# %%
class List(list):
    pass

# %%
l = List([12, 543, 23, 64])

# %%
l.remove(12)

# %%
l
# Out:
# [543, 23, 64]

# %%
l1 = List([64, 23,34 , 65])
l2 = List([50, 23, 64])

# %%
l1 + l2
# Out:
# [64, 23, 34, 65, 50, 23, 64]

# %%
class List(list):
    def __add__(self, other):

# %%
l = [23, 53, 23]

# %%
l1
# Out:
# [64, 23, 34, 65]

# %%
l2
# Out:
# [50, 23, 64]

# %%
def list_addition(A, B):

    if len(A) > len(B):
        A, B = B, A

    addition = []

    for i in range(len(A)):
        element_add = A[i] + B[i]
        addition.append(element_add)

    print(i)

    addition.extend(B[i+1:])

    return addition

# %%
list_addition(l2, l1)
# Out:
# 2
# [114, 46, 98, 65]

# %%
l1 = [53, 34, 23, 675, 23]
l2 = [23, 53]

# %%
list_addition(l1, l2)
# Out:
# 1
# [76, 87, 23, 675, 23]

# %%
list_addition(l2, l1)
# Out:
# 1
# [76, 87, 23, 675, 23]

# %%
class List(list):
    def __add__(self, other):

        print("verification")
        A = self
        B = other

        if len(A) > len(B):
            A, B = B, A

        addition = []

        for i in range(len(A)):
            element_add = A[i] + B[i]
            addition.append(element_add)

        addition.extend(B[i+1:])

        return addition

# %%
A = List([12, 54, 23, 30])
B = List([38, 49])

# %%
A + B
# Out:
# verification
# [50, 103, 23, 30]

# %%
first_names = List(['Ahmad', 'kamran', 'Babar', 'Salman'])
last_names = List(['Danial', 'akmal', 'azam', 'but'])

# %%
first_names + last_names
# Out:
# verification
# ['AhmadDanial', 'kamranakmal', 'Babarazam', 'Salmanbut']

# %%
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def speek(self):
        print(f"{self.name} make a sound")

    def eat(self):
        print(f"{self.name} is eating!")

    def sleep(self):
        print(f"{self.name} is sleeping")

class Dog(Animal):

    def speek(self):
        print(f"{self.name} says woof!")


class Cat(Animal):
    def speek(self):
        print(f"{self.name} say meow!")

# %%
d1 = Dog('dog', 10)

# %%
d1.speek()
# Out:
# dog says woof!

# %%
c1 = Cat('cat', 4)

# %%
c1.speek()
# Out:
# cat say meow!

# %%
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def speek(self):
        print(f"{self.name} make a sound")

    def eat(self):
        print(f"{self.name} is eating!")

    def sleep(self):
        print(f"{self.name} is sleeping")

    def describe(self):
        print(f"A {self.name} with {self.age} years life!")

class Dog(Animal):
    def __init__(self, name, age, breed):
        super().__init__(name, age)
        self.breed = breed

    def speek(self):
        print(f"{self.name} says woof!")

    def describe(self):
        super().describe()
        print(f" from {self.breed} family")


# class Cat(Animal):
#     def speek(self):
#         print(f"{self.name} say meow!")

# %%
d1 = Dog('dog', 3, 'german')

# %%
d1.name
# Out:
# 'dog'

# %%
d1.age
# Out:
# 3

# %%
d1.breed
# Out:
# 'german'

# %%
d1.describe()
# Out:
# A dog with 3 years life!
#  from german family

# %%
n = 0

while n>0:
    print("while executed")
    n +=1

# %%
for i in range(3):
    print(i)
    i += 3030
# Out:
# 0
# 1
# 2

# %%
print(i)
# Out:
# 2

# %%
count = 1
while count <= 10:
    if count % 3 == 0:
        count += 2
        continue
    print(count, end=" ")
    count += 1
# Out:
# 1 2 5 8

# %%
for i in range(4):
    for j in range(i):   ## i = 3
        print(i + j, end=" ")
# Out:
# 1 2 3 3 4 5

# %%
count = 0
while count < 5:
    print(count, end=" ")
    if count == 2:
        break
    count += 1
# Out:
# 0 1 2

# %%
for i in range(1, 10, 2):
    print(i, end=" ")

# %%
num = 10
while num > 0:
    if num % 2 == 0:
        num -= 1
    else:
        num += 1
    print(num, end=" ")

# %%
my_sum = 10
for i in range(1, 5):  # [1, 2, 3, 4]
    my_sum += i

print(i)

# %%
x = 10
while x in range(10, 5, -2):        ## [10, 8, 6]
    print("Kookie", end = " ")
    x -= 2
# Out:
# Kookie Kookie Kookie

# %%
# Practical MRO example with a diamond problem
#
#        Base
#       /    \
#      A      B
#       \    /
#         C

class Base:
    def hello(self):
        print("Hello from Base")

class A(Base):
    def hello(self):
        print("Hello from A")
        super().hello()

class B(Base):
    def hello(self):
        print("Hello from B")
        super().hello()

class C(A, B):         # inherits from both A and B
    def hello(self):
        print("Hello from C")
        super().hello()


c = C()
c.hello()
print()
print("MRO:", [cls.__name__ for cls in C.__mro__])
# Python ensures Base.hello is called ONLY ONCE despite A and B both calling super()
# Out:
# Hello from C
# Hello from A
# Hello from B
# Hello from Base
#
# MRO: ['C', 'A', 'B', 'Base', 'object']

# %%
count = 1 
while count <= 10: 
    if count % 3 == 0: 
        count += 2 
        continue 
    print(count, end=" ") 
    count += 1

# %% [markdown]
# # Advantages of OOP (Object-Oriented Programming)
#
# ## 1. Encapsulation
# Encapsulation refers to bundling the data (attributes) and methods (functions) that operate on the data within a single unit or class.
# It protects data by restricting access to certain components and allows for modularity in code.
#
# **Example:**
# Access to a bank account's balance may be controlled using getter and setter methods, ensuring data consistency and security.
#
# ---
#
# ## 2. Reusability Through Inheritance
# Inheritance enables classes to inherit attributes and methods from other classes, reducing code redundancy.
# This supports a hierarchical structure in design, making the system extensible.
#
# **Example:**
# In a transportation application, a base class `Vehicle` can provide common properties for subclasses like `Car`, `Truck`, and `Bike`.
#
# ---
#
# ## 3. Polymorphism
# Polymorphism allows methods to perform differently based on the object invoking them.
# It facilitates method overloading and overriding, improving code flexibility.
#
# **Example:**
# A method `calculateArea()` could behave differently for objects of `Circle` and `Rectangle` classes.
#
# ---
#
# ## 4. Modularity
# OOP enables developers to divide complex problems into smaller, manageable objects or classes.
# Modular design makes debugging and maintenance easier, as changes in one module don’t affect others.
#
# **Example:**
# In a library system, separate classes like `Book`, `Member`, and `Librarian` can be created to handle specific functionalities.
#
# ---
#
# ## 5. Improved Code Maintenance
# OOP promotes clean and organized code by separating concerns through well-defined interfaces.
# Encapsulation and abstraction simplify the addition of new features or modification of existing ones without impacting other parts of the system.
#
# ---
#
# ## 6. Ease of Scalability
# The object-oriented approach makes scaling applications easier by allowing the addition of new classes without rewriting existing code.
# Projects designed with OOP are better equipped to handle growth and complexity.
#
# ---
#
# ## 7. Real-World Modeling
# OOP closely mirrors real-world systems, making it intuitive for developers.
# Objects represent real-world entities, their behaviors, and interactions.
#
# ---
#
# ## 8. Robust Security
# By encapsulating data and providing controlled access, OOP enhances the security of applications.
# Sensitive information can be hidden using private or protected access modifiers.
