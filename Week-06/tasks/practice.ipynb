# %%
import math

# %%
math.ceil(4.3)
# Out:
# 5

# %%
math.floor(43.5)
# Out:
# 43

# %%
math.factorial(2)
# Out:
# 2

# %%
math.tan(3)
# Out:
# -0.1425465430742778

# %%
math.isqrt(20)
# Out:
# 4

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type(math)
# Out:
# module

# %%
import datetime

# %%
type(datetime)
# Out:
# module

# %%
import datetime as dt

# %%
dt.date(2002, 4, 2)
# Out:
# datetime.date(2002, 4, 2)

# %%
from datetime import date, datetime, timedelta

# %%
date.today()
# Out:
# datetime.date(2026, 4, 23)

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 4, 23, 0, 38, 14, 692124)

# %%
type(date.today())
# Out:
# datetime.date

# %%
today = date.today()

# %%
today.day
# Out:
# 23

# %%
today.year
# Out:
# 2026

# %%
today.month
# Out:
# 4

# %%
today.today()
# Out:
# datetime.date(2026, 4, 23)

# %%
today
# Out:
# datetime.date(2026, 4, 23)

# %%
today.isocalendar()
# Out:
# datetime.IsoCalendarDate(year=2026, week=17, weekday=4)

# %%
today.isoweekday()
# Out:
# 4

# %%
today.max
# Out:
# datetime.date(9999, 12, 31)

# %%
today.min
# Out:
# datetime.date(1, 1, 1)

# %%
today.toordinal()
# Out:
# 739729

# %%
date.ctime(today)
# Out:
# 'Thu Apr 23 00:00:00 2026'

# %%
date.isoformat(today)
# Out:
# '2026-04-23'

# %%
date.timetuple(today)
# Out:
# time.struct_time(tm_year=2026, tm_mon=4, tm_mday=23, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=113, tm_isdst=-1)

# %%
import random

# %%
random.randint(1, 10)
# Out:
# 4

# %%
random.sample(range(10), 2)
# Out:
# [7, 5]

# %%
random.randrange(1, 30, 2)
# Out:
# 1

# %%
random.seed(40)

# %%
random.choice(['apple', 'banana', 'orange'])
# Out:
# 'banana'

# %%
random.seed(40)
print(random.randint(1, 10))  # same result every time
# Out:
# 8
