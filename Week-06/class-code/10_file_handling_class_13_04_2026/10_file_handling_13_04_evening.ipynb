# %%
## file handling

# %%
#text = open(path, mode)

# %%
text_file = open(r"C:\Users\Abbas\Desktop\temp\temp.txt", 'r')

# %%
print(r"D:\AI\Users\Abbas\Desktop\tmep\temp.txt")
# Out:
# D:\AI\Users\Abbas\Desktop\tmep\temp.txt

# %%
text_file
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Abbas\\Desktop\\temp\\temp.txt' mode='r' encoding='utf-8'>

# %%
text = text_file.read()

# %%
text
# Out:
# 'the first line in the file\nthe second line in the file\nthe third line in the file'

# %%
print(text_file.read())

# %%
text_file.close()

# %%
text_file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 text_file.read()
#
# ValueError: I/O operation on closed file.

# %%
path = r"files\temp.txt"

# %%
text_file = open(path, 'r')

# %%
text = text_file.readlines()

# %%
text
# Out:
# ['the first line in the file\n',
#  'the second line in the file\n',
#  'the third line in the file']

# %%
type(text[2])
# Out:
# str

# %%
text[0]
# Out:
# 'the first line in the file\n'

# %%
text[1]
# Out:
# 'the second line in the file\n'

# %%
text[2]
# Out:
# 'line 3'

# %%
text_file.close()

# %%
text_file.close()

# %%
## with statement

# %%
with open(r"files\temp.txt", 'r') as f:
    text = f.read()

    print(text)
# Out:
# the first line in the file
# the second line in the file
# the third line in the file

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
with open(r"files\temp.txt", 'r') as f:
    lines_list = f.readlines()

# %%
f.readlines()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 f.readlines()
#
# ValueError: I/O operation on closed file.

# %%
lines_list
# Out:
# ['the first line in the file\n',
#  'the second line in the file\n',
#  'the third line in the file']

# %%
lines_list[0]
# Out:
# 'the first line in the file\n'

# %%
for line in lines_list:
    print(line)
# Out:
# the first line in the file
#
# the second line in the file
#
# the third line in the file

# %%
with open(r'files\temp.txt', 'r') as file:
    for line in file.readlines():
        print(line)
# Out:
# the first line in the file
#
# the second line in the file
#
# the third line in the file

# %%
with open(r"files\temp.txt") as f:
    for line in f:
        print(line)
# Out:
# the first line in the file
#
# the second line in the file
#
# the third line in the file

# %%
with open(r"files\temp.txt", 'r') as f:
    line1 = f.readline()
    line2 = f.readline()
    line3 = f.readline()

# %%
line3
# Out:
# 'the third line in the file'

# %%
with open("file_handling.py", 'r') as python_file:
    python_code = python_file.read()

# %%
python_code
# Out:
# '\ntext_file = open(r\'files\\temp.txt\', \'r\')\n\ntext = text_file.read()\n\nprint("TYPE OF TEXT VARIABLE : ", type(text))\n\nprint(text)\n\ntext_file.close()\n\n\n'

# %%
print(python_code)
# Out:
# text_file = open(r'files\temp.txt', 'r')
#
# text = text_file.read()
#
# print("TYPE OF TEXT VARIABLE : ", type(text))
#
# print(text)
#
# text_file.close()

# %%
type(python_code)
# Out:
# str

# %%
with open("code_in_text_file.txt", 'w') as file:
    file.write(python_code)

# %%
with open('writing_file.txt', 'w') as file:
    file.write("""We presented MambaDiff, the first integration of 
selective state space models with diffusion-based temporal 
action segmentation. Our approach replaces windowed attention""")

# %%
with open('writing_file.txt', 'w') as file:
    file.write("We presented MambaDiff, the first integration of\nselective state space models with diffusion-based temporal action segmentation. \nOur approach replaces windowed attention")

# %%
with open(r'files\temp.txt', 'r') as f:
    f.write("the fourth line")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[62], line 2
#       1 with open(r'files\temp.txt', 'r') as f:
# ----> 2     f.write("the fourth line")
#
# UnsupportedOperation: not writable

# %%
with open('writing_file.txt', 'a') as file:
    file.write("We presented MambaDiff, the first integration of\nselective state space models with diffusion-based temporal action segmentation. \nOur approach replaces windowed attention")

# %%
with open(r'files\temp.txt', 'a') as file:

    text = input("Enter text you want to add to a file : ")
    file.write("\n"+text)

# %%
l = ['this is a new line\n', 'this is a new line\n', 'this is a new line']

# %%
with open(r'files\temp.txt', 'a+') as file:
    file.writelines(l)
