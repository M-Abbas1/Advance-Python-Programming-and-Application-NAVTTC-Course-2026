# %%
print("hello", 35, 5.34, False, [4, 5,55], (4, 32), {4, 534})
# Out:
# hello 35 5.34 False [4, 5, 55] (4, 32) {4, 534}

# %%
name = "ali"
age = 34

print("name  age")
# Out:
# name  age

# %%
print(name)
# Out:
# ali

# %%
print(age)
# Out:
# 34

# %%
print(f"the name of student is {name} and his age is {age} ")
# Out:
# the name of student is ali and his age is 34

# %%
print(f"the of student will be {age + 5} after 5 years")
# Out:
# the of student will be 39 after 5 years

# %%
print(f"name : {print(name)} ")
# Out:
# ali
# name : None

# %%
escape sequences

# %%
print("the first line \n the second")
# Out:
# the first line
#  the second

# %%
s = "the first line \nThe second line"

# %%
print(s)
# Out:
# the first line
# The second line

# %%
print(f"name\t{name}")
# Out:
# name	ali

# %%
print("hello\b")
# Out:
# hell

# %%
s = "usman\b"

# %%
s
# Out:
# 'usman\x08'

# %%
print(s)
# Out:
# usma

# %%
len(s)
# Out:
# 6

# %%
s[5]
# Out:
# '\x08'

# %%
print("\"the quatation\"")
# Out:
# "the quatation"

# %%
pritn(""the qutation"")
# Out:
#   Cell In[25], line 1
#     pritn(""the qutation"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('salman\'s hours')
# Out:
# salman's hours

# %%
print("hello", end='\t')
print("world")
# Out:
# hello	world

# %%
print("apple", 'banana', 'orange', sep='\n')
# Out:
# apple
# banana
# orange

# %%
string1 = "string in double qutation"
string2 = 'string in double single'
string3 = """string in double thriple"""

# %%
print(string1)
print(string2)
print(string3)
# Out:
# string in double qutation
# string in double single
# string in double thriple

# %%
positive_no = 453434
negative_no = -534

# %%
f = 423.64

# %%
f
# Out:
# 423.64

# %%
b = True

# %%
b = False

# %%
b
# Out:
# False

# %%
str(43)
# Out:
# '43'

# %%
str(3.6656)
# Out:
# '3.6656'

# %%
str(True)
# Out:
# 'True'

# %%
str([43, 53, 23])
# Out:
# '[43, 53, 23]'

# %%
str((4, 2, 3))
# Out:
# '(4, 2, 3)'

# %%
# conversion into integer datatype

# %%
int('4353')
# Out:
# 4353

# %%
int("RS1000")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 int("RS1000")
#
# ValueError: invalid literal for int() with base 10: 'RS1000'

# %%
int('53.654')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 int('53.654')
#
# ValueError: invalid literal for int() with base 10: '53.654'

# %%
int(5.3563)
# Out:
# 5

# %%
int(453213.4)
# Out:
# 453213

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int([43, 54, 34])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 int([43, 54, 34])
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
float(34343)
# Out:
# 34343.0

# %%
float("234")
# Out:
# 234.0

# %%
float("34.5")
# Out:
# 34.5

# %%
float('Rs12.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 float('Rs12.5')
#
# ValueError: could not convert string to float: 'Rs12.5'

# %%
bool(" ")
# Out:
# True

# %%
bool("k")
# Out:
# True

# %%
bool('ali')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(2)
# Out:
# True

# %%
bool(43443)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(0.0000000001)
# Out:
# True

# %%
bool(23355353.50)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(0.00000000)
# Out:
# False

# %%
## addition  +
## subtraction -
## multiplication *
## division /
## floor division  //
## power  **
## modulas  %   operand

# %%
a = 534
b = 4

# %%
a+b
# Out:
# 538

# %%
a-b
# Out:
# 530

# %%
a*b
# Out:
# 2136

# %%
a/b
# Out:
# 133.5

# %%
30/6
# Out:
# 5.0

# %%
int(30/6)
# Out:
# 5

# %%
21/4
# Out:
# 5.25

# %%
21//4
# Out:
# 5

# %%
a
# Out:
# 534

# %%
b
# Out:
# 4

# %%
a/2
# Out:
# 267.0

# %%
type(a/2)
# Out:
# float

# %%
type(a//2)
# Out:
# int

# %%
type(a//b)
# Out:
# int

# %%
a//b
# Out:
# 133

# %%
a/b
# Out:
# 133.5

# %%
2**2
# Out:
# 4

# %%
2**3
# Out:
# 8

# %%
a
# Out:
# 534

# %%
b
# Out:
# 4

# %%
a**b
# Out:
# 81313944336

# %%
a*a*a*a
# Out:
# 81313944336

# %%
22%5
# Out:
# 2

# %%
# comparision operators

# %%
## ==

33 ==  33
# Out:
# True

# %%
33 == 34
# Out:
# False

# %%
"ali" == "Ali"
# Out:
# False

# %%
34.0 == 23.0
# Out:
# False

# %%
34.34 == 34.35
# Out:
# False

# %%
True == True
# Out:
# True

# %%
True == False
# Out:
# False

# %%
[23, 23]  == [23, 23]
# Out:
# True

# %%
23 != 50
# Out:
# True

# %%
23 != 23
# Out:
# False

# %%
23 > 0
# Out:
# True

# %%
23.453 >234.54
# Out:
# False

# %%
34 < 35
# Out:
# True

# %%
34 < 21
# Out:
# False

# %%
100 >= 101
# Out:
# False

# %%
100 >= 100
# Out:
# True

# %%
100 >= 90
# Out:
# True

# %%
3465 <= 342
# Out:
# False

# %%
3.3 <= 3.3
# Out:
# True

# %%
0 < 5 < 10
# Out:
# True

# %%
## logical operators

# %%
# and 
# or 
# not

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
3==3 and 5<10
# Out:
# True

# %%
True and True
# Out:
# True

# %%
4<9  and 23>10 and "ali"=='Ali'
# Out:
# False

# %%
True and True and False
# Out:
# False

# %%
bool(5) and bool('')
# Out:
# False

# %%
20/4 + 2*1

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
20 != 20   or   3.5 == 3.8   or 'Ali' == "ali"
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not ""
# Out:
# True

# %%
not "a"
# Out:
# False

# %%
l = [34, 5,32, 3 , 5, 434]

# %%
32 in l
# Out:
# True

# %%
100 in l
# Out:
# False

# %%
"i" in "something"
# Out:
# True

# %%
s = "nism with adaptive directional fusion, our encoder provides"

# %%
"with" in s
# Out:
# True

# %%
2 in (5, 6, 2, 7, 8)
# Out:
# True

# %%
9 in (5, 6, 2, 7, 8)
# Out:
# False

# %%
7 in {5, 7, 2, 8}
# Out:
# True

# %%
l
# Out:
# [34, 5, 32, 3, 5, 434]

# %%
100 not in l
# Out:
# True

# %%
# identity operators

# %%
# is, is not

# %%
50 is 50
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Abbas\AppData\Local\Temp\ipykernel_24320\4077015830.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   50 is 50
# True

# %%
a = 10
b = 20

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
name1 = 'usman'
name2 = "usman khan"

# %%
name1 is name2
# Out:
# False

# %%
name1 is not name2
# Out:
# True

# %%
name1 == name2
# Out:
# False

# %%
name1 != name2
# Out:
# True

# %%
name1
# Out:
# 'usman'

# %%
name2
# Out:
# 'usman khan'

# %%
"usman" == 'usman khan'
# Out:
# False

# %%
id(name1)
# Out:
# 2134250524400

# %%
id(name2)
# Out:
# 2134250535216

# %%
name1 is name2
# Out:
# False

# %%
a = 10
b = 10

# %%
print(id(a))
print(id(b))
# Out:
# 140707947729992
# 140707947729992

# %%
a is b
# Out:
# True

# %%
n1 = 4783748374

# %%
n2 = 4783748374

# %%
print(id(n1))
print(id(n2))
# Out:
# 2134251110768
# 2134251110704

# %%
n1 is n2
# Out:
# False

# %%
n1 == n2
# Out:
# True

# %%
age = 23

# %%
age = age + 5

# %%
age
# Out:
# 28

# %%
age += 5     # age = age + 5

# %%
age
# Out:
# 33

# %%
age -= 9

# %%
age
# Out:
# 24

# %%
age *= 2

# %%
age
# Out:
# 48

# %%
age /= 2

# %%
age
# Out:
# 24.0

# %%
age **= 2  # age = age**2

# %%
age
# Out:
# 576.0

# %%
5 & 4
# Out:
# 4

# %%
10 | 12
# Out:
# 14

# %%
3 ^ 5
# Out:
# 6

# %%
marks = 39

if marks >= 90:
    print("A")
elif marks >= 80:
    print("B")
elif marks >= 70:
    print("C")
elif marks >= 60:
    print("D")
elif marks >= 50:
    print("E")
else:
    print("F")
# Out:
# F

# %%
# Nested if-else

actual_username = 'khan123'
username = 'khan123'

if username == actual_username:
    print("Successfuly login")
    
    if 'user' in username:
        print("yes he is developer")
# Out:
# Successfuly login

# %%
age = 23
licence = True

if age >= 18:
    print("yes age is greater than 18")

    if licence == True:
        print("you can drive")
# Out:
# yes age is greater than 18
# you can drive

# %%
print("\"quate\"")
# Out:
# "quate"

# %%
print("hello\" world")
# Out:
# hello" world

# %%
s = '''string in 3 quatation '''

# %%
s
# Out:
# 'string in 3 quatation '

# %%
company = 'khan\'s company'

# %%
company
# Out:
# "khan's company"

# %%
print('khan"s company')
# Out:
# khan"s company

# %%
print('"quatation"')
# Out:
# "quatation"

# %%
//

# %%
22//4
# Out:
# 5

# %%
print("ten\\twenty")
# Out:
# ten\twenty

# %%
ten\twenty
