# %%
# syntax

# %%
## def identified():
###    code block

# %%
def greet():
    print("hello")
    print("Welcome to python functions!")

# %%
greet()
# Out:
# hello
# Welcome to python functions!

# %%
greet()
# Out:
# hello
# Welcome to python functions!

# %%
greet()
greet()
greet()
greet()
greet()
# Out:
# hello
# Welcome to python functions!
# hello
# Welcome to python functions!
# hello
# Welcome to python functions!
# hello
# Welcome to python functions!
# hello
# Welcome to python functions!

# %%
def greet_with_name():
    name = 'khan'
    print("Welcome to python functions ", name)

# %%
greet_with_name()
greet_with_name()
greet_with_name()
# Out:
# Welcome to python functions  khan
# Welcome to python functions  khan
# Welcome to python functions  khan

# %%
dict = {'name': 'ali', 'age': 20,'city':'fsd'}

# %%
dict['age'] = 22

# %%
dict
# Out:
# {'name': 'ali', 'age': 22, 'city': 'fsd'}

# %%
dict.update({'name': 'usman', 'height': 5.10})

# %%
dict
# Out:
# {'name': 'usman', 'age': 22, 'city': 'fsd', 'height': 5.1}

# %%
dict.pop('city')
# Out:
# 'fsd'

# %%
dict.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dict.pop()
#
# TypeError: pop expected at least 1 argument, got 0
