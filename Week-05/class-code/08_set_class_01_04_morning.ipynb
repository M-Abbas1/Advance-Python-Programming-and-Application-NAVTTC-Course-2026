# %%
s = {1, 2, 3}

# %%
type(s)
# Out:
# set

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
empty_set = set()

# %%
empty_set
# Out:
# set()

# %%
type(empty_set)
# Out:
# set

# %%
uset = {1, 2, 3, 4, 4, 5, 5, 6}

# %%
print(uset)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
hset = {'hello', 3.5, 23, True}

# %%
hset
# Out:
# {23, 3.5, True, 'hello'}

# %%
l = [6, 2, 64, 23, 64, 75, 23]

# %%
set(l)
# Out:
# {2, 6, 23, 64, 75}

# %%
t = (53, 23, 53, 23, 876, 45)

# %%
set(t)
# Out:
# {23, 45, 53, 876}

# %%
d = {'name':'khan', 'age':23}
d
# Out:
# {'name': 'khan', 'age': 23}

# %%
set(d)
# Out:
# {'age', 'name'}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
for k in d:
    print(k)
# Out:
# name
# age

# %%
set(d.values())
# Out:
# {23, 'khan'}

# %%
s1 = set([4, 6, 2, 6])

# %%
s1
# Out:
# {2, 4, 6}

# %%
s
# Out:
# {1, 2, 3}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1
# Out:
# {2, 4, 6}

# %%
s1 = {6, 23, 67, 24, 78, 57, 43}

# %%
s1
# Out:
# {6, 23, 24, 43, 57, 67, 78}

# %%
type(s1)
# Out:
# set

# %%
s1.add(30)

# %%
s1
# Out:
# {6, 23, 24, 30, 43, 57, 67, 78}

# %%
s1.add(6)

# %%
s1
# Out:
# {6, 23, 24, 30, 43, 57, 67, 78}

# %%
## for more than one values

s1.update()

# %%
s1.update([66, 100, 33])

# %%
s1
# Out:
# {6, 23, 24, 30, 33, 43, 57, 66, 67, 78, 100}

# %%
d
# Out:
# {'name': 'khan', 'age': 23}

# %%
type(d)
# Out:
# dict

# %%
d['city'] = 'hangu'

# %%
d
# Out:
# {'name': 'khan', 'age': 23, 'city': 'hangu'}

# %%
d.update({'gpa':3.29, 'grade':'A'})

# %%
d
# Out:
# {'name': 'khan', 'age': 23, 'city': 'hangu', 'gpa': 3.29, 'grade': 'A'}

# %%
d.update({'name':'ali', 'age':40})

# %%
d
# Out:
# {'name': 'ali', 'age': 40, 'city': 'hangu', 'gpa': 3.29, 'grade': 'A'}

# %%
d['name']
# Out:
# 'ali'

# %%
s1
# Out:
# {6, 23, 24, 30, 33, 43, 57, 66, 67, 78, 100}

# %%
id(s1)
# Out:
# 3102838810304

# %%
s1.add(55)

# %%
s1
# Out:
# {6, 23, 24, 30, 33, 43, 55, 57, 66, 67, 78, 100}

# %%
id(s1)    #3102838810304
# Out:
# 3102838810304

# %%
s1
# Out:
# {6, 23, 24, 30, 33, 43, 55, 57, 66, 67, 78, 100}

# %%
s1
# Out:
# {6, 23, 24, 30, 33, 43, 55, 57, 66, 67, 78, 100}

# %%
s1.add([12, 42])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 s1.add([12, 42])
#
# TypeError: unhashable type: 'list'

# %%
s2 = {5, 23, 75, [8, 6]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 s2 = {5, 23, 75, [8, 6]}
#
# TypeError: unhashable type: 'list'

# %%
s3 = {5, 2, 8, 23, (3, 5)}

# %%
s3
# Out:
# {(3, 5), 2, 23, 5, 8}

# %%
s4 = {6, 3, 5, 3, {6, 2, 7}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 s4 = {6, 3, 5, 3, {6, 2, 7}}
#
# TypeError: unhashable type: 'set'

# %%
s4 = {'salman', 'kamran'}

# %%
s4
# Out:
# {'kamran', 'salman'}

# %%
name = 'muhammad salman'

# %%
name[0] = 'M'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 name[0] = 'M'
#
# TypeError: 'str' object does not support item assignment

# %%
s1
# Out:
# {6, 23, 24, 30, 33, 43, 55, 57, 66, 67, 78, 100}

# %%
for el in tuple(s1):
    print(el)
# Out:
# 66
# 67
# 6
# 78
# 23
# 24
# 30
# 33
# 100
# 43
# 55
# 57

# %%
dict(s1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 dict(s1)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
for el in s1:
    print(el)
# Out:
# 66
# 67
# 6
# 78
# 23
# 24
# 30
# 33
# 100
# 43
# 55
# 57

# %%
type(s1)
# Out:
# set

# %%
s1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1 = {1, 2, 3, 4, 5}
s2 = {3, 4, 5, 6, 7, 8, 9}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1.intersection(s2)
# Out:
# {3, 4, 5}

# %%
s1 & s2
# Out:
# {3, 4, 5}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {3, 4, 5, 6, 7, 8, 9}

# %%
s1 - s2
# Out:
# {1, 2}

# %%
s2 - s1
# Out:
# {6, 7, 8, 9}

# %%
s2.difference(s1)
# Out:
# {6, 7, 8, 9}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 6, 7, 8, 9}

# %%
print(s1 - s2)
print(s2 - s1)
# Out:
# {1, 2}
# {8, 9, 6, 7}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {3, 4, 5, 6, 7, 8, 9}

# %%
s1.issubset(s2)
# Out:
# False

# %%
sset = {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1.issubset(sset)
# Out:
# True

# %%
s1.difference(sset)
# Out:
# set()

# %%
sset.issubset(s1)
# Out:
# False

# %%
sset.issubset(sset)
# Out:
# True

# %%
sset.issuperset(sset)
# Out:
# True

# %%
sset
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
sset.issuperset(s1)
# Out:
# True

# %%
sset.issuperset(s2)
# Out:
# True

# %%
s1.issuperset(sset)
# Out:
# False

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.remove(2)

# %%
s1
# Out:
# {1, 3, 4, 5}

# %%
s1.pop()
# Out:
# 1

# %%
s1
# Out:
# {3, 4, 5}

# %%
s1.pop()
# Out:
# 3

# %%
s1.pop(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 s1.pop(0)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
sset
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
sset.dis

# %%
s1
# Out:
# {4, 5}

# %%
del s1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 del s1[0]
#
# TypeError: 'set' object doesn't support item deletion

# %%
del s1

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
sset.discard(1)

# %%
sset
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}

# %%
sset.remove(11)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 sset.remove(11)
#
# KeyError: 11

# %%
sset.discard(11)

# %%
sset
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}

# %%
s2
# Out:
# {3, 4, 5, 6, 7, 8, 9}

# %%
s2.clear()

# %%
s2
# Out:
# set()

# %%
fset = frozenset([1, 2, 4, 7, 23])

# %%
fset
# Out:
# frozenset({1, 2, 4, 7, 23})

# %%
type(fset)
# Out:
# frozenset

# %%
fset.add(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 fset.add(4)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
fset.update([53, 23])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 fset.update([53, 23])
#
# AttributeError: 'frozenset' object has no attribute 'update'

# %%
fset.remove(53)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 fset.remove(53)
#
# AttributeError: 'frozenset' object has no attribute 'remove'

# %%
l = []

for i in range(1, 11):
    l.append(i**2)

# %%
l
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
empty_set = set()

for i in range(1, 11):
    empty_set.add(i**2)

# %%
empty_set
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64, 81, 100}

# %%
squares = {i**2      for i in range(1, 11)}

# %%
squares
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64, 81, 100}

# %%
empty_set = set()

for i in range(1, 11):
    if i%2 != 0:
        empty_set.add(i**2)

# %%
empty_set
# Out:
# {1, 9, 25, 49, 81}

# %%
even_squares = {i**2  for i in range(1, 11) if i%2==0}

# %%
even_squares
# Out:
# {4, 16, 36, 64, 100}

# %%
l = [53, 23, 65, 3, 23, 64, 34, 53]

l2 = []

for item in l:                  
    if item not in l2:
        l2.append(item)

# %%
list(set(l))
# Out:
# [64, 65, 34, 3, 53, 23]

# %%
name = 'ali'
age = 30

print(f"Name : {name}")
# Out:
# Name : ali

# %%
print(f"{30 + 45}")
# Out:
# 75

# %%
set('hello')
# Out:
# {'e', 'h', 'l', 'o'}

# %%
print(set)
# Out:
# <class 'set'>

# %%
set = {1, 2, 3}

# %%
set
# Out:
# {1, 2, 3}

# %%
type(set)
# Out:
# set

# %%
set('hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 set('hello')
#
# TypeError: 'set' object is not callable

# %%
print('hello world')
# Out:
# hello world

# %%
print = 'message'

# %%
print
# Out:
# 'message'

# %%
print('heelo ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print('heelo ')
#
# TypeError: 'str' object is not callable

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
s = {5, 23, 53, 73}

# %%
s.remove(5)

# %%
s
# Out:
# {23, 53, 73}

# %%
s.discard(2)

# %%
s
# Out:
# {23, 53, 73}

# %%
s.discard(73)

# %%
s
# Out:
# {23, 53}

# %%
print()
print()
print()
