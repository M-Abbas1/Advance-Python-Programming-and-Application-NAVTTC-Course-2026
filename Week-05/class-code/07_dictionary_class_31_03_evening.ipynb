# %%
empty_dic = {}

# %%
type(empty_dic)
# Out:
# dict

# %%
student = {'name':'usman', "age":23, 'address':'peshawar'}

# %%
student
# Out:
# {'name': 'usman', 'age': 23, 'address': 'peshawar'}

# %%
len(student)
# Out:
# 3

# %%
top_students = {1:'sidra', 2:'salman', 3:'wakeel', 4:'ahmad'}

# %%
len(top_students)
# Out:
# 4

# %%
top_students = {1:'sidra', 2:'salman', 3:'wakeel', 4:'ahmad', 4:'ali'}

# %%
top_students
# Out:
# {1: 'sidra', 2: 'salman', 3: 'wakeel', 4: 'ali'}

# %%
cricketers = {1:{'name':'waseem akram', 'age':70}, 2:{'name':'shaoib akhtar', 'age':80}}

# %%
students = {'name':'ali', 'subjects':['python', 'java', 'c++'], 'marks':[23, 53, 23]}

# %%
students
# Out:
# {'name': 'ali', 'subjects': ['python', 'java', 'c++'], 'marks': [23, 53, 23]}

# %%
type(students)
# Out:
# dict

# %%
## accessing elements

# %%
cricketers
# Out:
# {1: {'name': 'waseem akram', 'age': 70},
#  2: {'name': 'shaoib akhtar', 'age': 80}}

# %%
len(cricketers)
# Out:
# 2

# %%
top_students
# Out:
# {1: 'sidra', 2: 'salman', 3: 'wakeel', 4: 'ali'}

# %%
len(top_students)
# Out:
# 4

# %%
top_students[1]
# Out:
# 'sidra'

# %%
top_students[4]
# Out:
# 'ali'

# %%
student
# Out:
# {'name': 'usman', 'age': 23, 'address': 'peshawar'}

# %%
student['name']
# Out:
# 'usman'

# %%
cricketers
# Out:
# {1: {'name': 'waseem akram', 'age': 70},
#  2: {'name': 'shaoib akhtar', 'age': 80}}

# %%
cricketers[2]
# Out:
# {'name': 'shaoib akhtar', 'age': 80}

# %%
type(cricketers[2])
# Out:
# dict

# %%
cricketers[2]['age']
# Out:
# 80

# %%
students
# Out:
# {'name': 'ali', 'subjects': ['python', 'java', 'c++'], 'marks': [23, 53, 23]}

# %%
students.keys()
# Out:
# dict_keys(['name', 'subjects', 'marks'])

# %%
cricketers.keys()
# Out:
# dict_keys([1, 2])

# %%
cricketers
# Out:
# {1: {'name': 'waseem akram', 'age': 70},
#  2: {'name': 'shaoib akhtar', 'age': 80}}

# %%
cricketers[1].keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student.values()
# Out:
# dict_values(['usman', 23, 'peshawar'])

# %%
student
# Out:
# {'name': 'usman', 'age': 23, 'address': 'peshawar'}

# %%
students.items()
# Out:
# dict_items([('name', 'ali'), ('subjects', ['python', 'java', 'c++']), ('marks', [23, 53, 23])])

# %%
student
# Out:
# {'name': 'usman', 'age': 23, 'address': 'peshawar'}

# %%
student[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 student[0]
#
# KeyError: 0

# %%
student.keys()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 student.keys()[0]
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
list(student.keys())[0]
# Out:
# 'name'

# %%
student.items()
# Out:
# dict_items([('name', 'usman'), ('age', 23), ('address', 'peshawar')])

# %%
list(student.items())
# Out:
# [('name', 'usman'), ('age', 23), ('address', 'peshawar')]

# %%
len(list(student.items()))
# Out:
# 3

# %%
type(list(student.items())[0])
# Out:
# tuple

# %%
students = {
    "STU101": {
        "name": "Ali Khan",
        "age": 21,
        "department": "Computer Science",
        "courses": ["Python", "Data Structures", "Database"],
        "grades": {"Python": 88, "Data Structures": 79, "Database": 85},
        "city": "Lahore"
    },

    "STU102": {
        "name": "Sara Ahmed",
        "age": 22,
        "department": "Software Engineering",
        "courses": ["Python", "Web Development", "AI"],
        "grades": {"Python": 91, "Web Development": 87, "AI": 90},
        "city": "Islamabad"
    },

    "STU103": {
        "name": "Usman Tariq",
        "age": 20,
        "department": "Information Technology",
        "courses": ["Networking", "Python", "Cyber Security"],
        "grades": {"Networking": 82, "Python": 75, "Cyber Security": 80},
        "city": "Faisalabad"
    },

    "STU104": {
        "name": "Hina Malik",
        "age": 23,
        "department": "Computer Science",
        "courses": ["Machine Learning", "Python", "Statistics"],
        "grades": {"Machine Learning": 89, "Python": 92, "Statistics": 84},
        "city": "Karachi"
    },

    "STU105": {
        "name": "Bilal Hassan",
        "age": 21,
        "department": "Software Engineering",
        "courses": ["Java", "Python", "Operating Systems"],
        "grades": {"Java": 76, "Python": 81, "Operating Systems": 78},
        "city": "Multan"
    }
}

# %%
students.keys()
# Out:
# dict_keys(['STU101', 'STU102', 'STU103', 'STU104', 'STU105'])

# %%
list(students.keys())[0]
# Out:
# 'STU101'

# %%
students.values()
# Out:
# dict_values([{'name': 'Ali Khan', 'age': 21, 'department': 'Computer Science', 'courses': ['Python', 'Data Structures', 'Database'], 'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85}, 'city': 'Lahore'}, {'name': 'Sara Ahmed', 'age': 22, 'department': 'Software Engineering', 'courses': ['Python', 'Web Development', 'AI'], 'grades': {'Python': 91, 'Web Development': 87, 'AI': 90}, 'city': 'Islamabad'}, {'name': 'Usman Tariq', 'age': 20, 'department': 'Information Technology', 'courses': ['Networking', 'Python', 'Cyber Security'], 'grades': {'Networking': 82, 'Python': 75, 'Cyber Security': 80}, 'city': 'Faisalabad'}, {'name': 'Hina Malik', 'age': 23, 'department': 'Computer Science', 'courses': ['Machine Learning', 'Python', 'Statistics'], 'grades': {'Machine Learning': 89, 'Python': 92, 'Statistics': 84}, 'city': 'Karachi'}, {'name': 'Bilal Hassan', 'age': 21, 'department': 'Software Engineering', 'courses': ['Java', 'Python', 'Operating Systems'], 'grades': {'Java': 76,
# ...

# %%
list(students.values())
# Out:
# [{'name': 'Ali Khan',
#   'age': 21,
#   'department': 'Computer Science',
#   'courses': ['Python', 'Data Structures', 'Database'],
#   'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85},
#   'city': 'Lahore'},
#  {'name': 'Sara Ahmed',
#   'age': 22,
#   'department': 'Software Engineering',
#   'courses': ['Python', 'Web Development', 'AI'],
#   'grades': {'Python': 91, 'Web Development': 87, 'AI': 90},
#   'city': 'Islamabad'},
#  {'name': 'Usman Tariq',
#   'age': 20,
#   'department': 'Information Technology',
#   'courses': ['Networking', 'Python', 'Cyber Security'],
#   'grades': {'Networking': 82, 'Python': 75, 'Cyber Security': 80},
#   'city': 'Faisalabad'},
#  {'name': 'Hina Malik',
#   'age': 23,
#   'department': 'Computer Science',
#   'courses': ['Machine Learning', 'Python', 'Statistics'],
#   'grades': {'Machine Learning': 89, 'Python': 92, 'Statistics': 84},
#   'city': 'Karachi'},
#  {'name': 'Bilal Hassan',
#   'age': 21,
# ...

# %%
students
# Out:
# {'STU101': {'name': 'Ali Khan',
#   'age': 21,
#   'department': 'Computer Science',
#   'courses': ['Python', 'Data Structures', 'Database'],
#   'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85},
#   'city': 'Lahore'},
#  'STU102': {'name': 'Sara Ahmed',
#   'age': 22,
#   'department': 'Software Engineering',
#   'courses': ['Python', 'Web Development', 'AI'],
#   'grades': {'Python': 91, 'Web Development': 87, 'AI': 90},
#   'city': 'Islamabad'},
#  'STU103': {'name': 'Usman Tariq',
#   'age': 20,
#   'department': 'Information Technology',
#   'courses': ['Networking', 'Python', 'Cyber Security'],
#   'grades': {'Networking': 82, 'Python': 75, 'Cyber Security': 80},
#   'city': 'Faisalabad'},
#  'STU104': {'name': 'Hina Malik',
#   'age': 23,
#   'department': 'Computer Science',
#   'courses': ['Machine Learning', 'Python', 'Statistics'],
#   'grades': {'Machine Learning': 89, 'Python': 92, 'Statistics': 84},
#   'city': 'Karachi'},
# ...

# %%
print(students['STU101'])
print(students['STU102'])
print(students['STU103'])
print(students['STU104'])
print(students['STU105'])
# Out:
# {'name': 'Ali Khan', 'age': 21, 'department': 'Computer Science', 'courses': ['Python', 'Data Structures', 'Database'], 'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85}, 'city': 'Lahore'}
# {'name': 'Sara Ahmed', 'age': 22, 'department': 'Software Engineering', 'courses': ['Python', 'Web Development', 'AI'], 'grades': {'Python': 91, 'Web Development': 87, 'AI': 90}, 'city': 'Islamabad'}
# {'name': 'Usman Tariq', 'age': 20, 'department': 'Information Technology', 'courses': ['Networking', 'Python', 'Cyber Security'], 'grades': {'Networking': 82, 'Python': 75, 'Cyber Security': 80}, 'city': 'Faisalabad'}
# {'name': 'Hina Malik', 'age': 23, 'department': 'Computer Science', 'courses': ['Machine Learning', 'Python', 'Statistics'], 'grades': {'Machine Learning': 89, 'Python': 92, 'Statistics': 84}, 'city': 'Karachi'}
# ...

# %%
students['STU101']
# Out:
# {'name': 'Ali Khan',
#  'age': 21,
#  'department': 'Computer Science',
#  'courses': ['Python', 'Data Structures', 'Database'],
#  'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85},
#  'city': 'Lahore'}

# %%
st1 = students['STU101']

# %%
st1['name']
# Out:
# 'Ali Khan'

# %%
students['STU101']['name']
# Out:
# 'Ali Khan'

# %%
students['STU101']['age']
# Out:
# 21

# %%
students['STU101']['grades']
# Out:
# {'Python': 88, 'Data Structures': 79, 'Database': 85}

# %%
students['STU104']['courses'][2]
# Out:
# 'Statistics'

# %%
students['STU103']['grades']['Python']
# Out:
# 75

# %%
print(students['STU101']['name'],   students['STU101']['age']) 
print(students['STU102']['name'],   students['STU102']['age'])
print(students['STU103']['name'],   students['STU103']['age'])
print(students['STU104']['name'],   students['STU104']['age'])
print(students['STU105']['name'],   students['STU105']['age'])
# Out:
# Ali Khan 21
# Sara Ahmed 22
# Usman Tariq 20
# Hina Malik 23
# Bilal Hassan 21

# %%
student
# Out:
# {'name': 'usman', 'age': 23, 'address': 'peshawar'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'address'])

# %%
for key in student.keys():
    print(key)
# Out:
# name
# age
# address

# %%
for v in student.values():
    print(v)
# Out:
# usman
# 23
# peshawar

# %%
for key in student.keys():               ## dict_keys(['name', 'age', 'address'])
    print(student[key])
# Out:
# usman
# 23
# peshawar

# %%
key = 'name'

# %%
key
# Out:
# 'name'

# %%
student
# Out:
# {'name': 'usman', 'age': 23, 'address': 'peshawar'}

# %%
student['name']                   ## key = 'name',, key --> 'name'
# Out:
# 'usman'

# %%
key
# Out:
# 'name'

# %%
print(students['STU101']['name'],   students['STU101']['age']) 
print(students['STU102']['name'],   students['STU102']['age'])
print(students['STU103']['name'],   students['STU103']['age'])
print(students['STU104']['name'],   students['STU104']['age'])
print(students['STU105']['name'],   students['STU105']['age'])

# %%
for key in students:                         # key --> 'STU101',,, students['STU101']['name']
    print(students[key]['name'])
# Out:
# Ali Khan
# Sara Ahmed
# Usman Tariq
# Hina Malik
# Bilal Hassan

# %%
for val in students.values():
    print(val['name'],  val['age'], val['city'], val['department'], sep='\t\t')
# Out:
# Ali Khan		21		Lahore		Computer Science
# Sara Ahmed		22		Islamabad		Software Engineering
# Usman Tariq		20		Faisalabad		Information Technology
# Hina Malik		23		Karachi		Computer Science
# Bilal Hassan		21		Multan		Software Engineering

# %%
products = {'name':'laptop', 'price':30000, 'batary time':4, 'quantity':10}

# %%
len(products)
# Out:
# 4

# %%
products['price']
# Out:
# 30000

# %%
products['quantity'] = 20

# %%
products
# Out:
# {'name': 'laptop', 'price': 30000, 'batary time': 4, 'quantity': 20}

# %%
products.keys()
# Out:
# dict_keys(['name', 'price', 'batary time', 'quantity'])

# %%
products.values()
# Out:
# dict_values(['laptop', 30000, 4, 20])

# %%
products.items()
# Out:
# dict_items([('name', 'laptop'), ('price', 30000), ('batary time', 4), ('quantity', 20)])

# %%
for v in products.values():
    print(v)
# Out:
# laptop
# 30000
# 4
# 20

# %%
for k in products.keys():
    print(k)
# Out:
# name
# price
# batary time
# quantity

# %%
for k in products.keys():
    print(products[k])
# Out:
# laptop
# 30000
# 4
# 20

# %%
for k in products:
    print(k)
# Out:
# name
# price
# batary time
# quantity

# %%
products
# Out:
# {'name': 'laptop', 'price': 30000, 'batary time': 4, 'quantity': 20}

# %%
products.get('name')
# Out:
# 'laptop'

# %%
products['color']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 products['color']
#
# KeyError: 'color'

# %%
products.get('color')

# %%
products
# Out:
# {'name': 'laptop', 'price': 30000, 'batary time': 4, 'quantity': 20}

# %%
products.update({'price':20000, 'batary time':5})

# %%
products
# Out:
# {'name': 'laptop', 'price': 20000, 'batary time': 5, 'quantity': 20}

# %%
products.update({'color':'silver', 'size':[12, 18]})

# %%
products
# Out:
# {'name': 'laptop',
#  'price': 20000,
#  'batary time': 5,
#  'quantity': 20,
#  'color': 'silver',
#  'size': [12, 18]}

# %%
products.update({'price':25000, 'generation':7})

# %%
products
# Out:
# {'name': 'laptop',
#  'price': 25000,
#  'batary time': 5,
#  'quantity': 20,
#  'color': 'silver',
#  'size': [12, 18],
#  'generation': 7}

# %%
students = {
    "STU101": {
        "name": "Ali Khan",
        "age": 21,
        "department": "Computer Science",
        "courses": ["Python", "Data Structures", "Database"],
        "grades": {"Python": 88, "Data Structures": 79, "Database": 85},
        "city": "Lahore"
    },

    "STU102": {
        "name": "Sara Ahmed",
        "age": 22,
        "department": "Software Engineering",
        "courses": ["Python", "Web Development", "AI"],
        "grades": {"Python": 91, "Web Development": 87, "AI": 90},
        "city": "Islamabad"
    },

    "STU103": {
        "name": "Usman Tariq",
        "age": 20,
        "department": "Information Technology",
        "courses": ["Networking", "Python", "Cyber Security"],
        "grades": {"Networking": 82, "Python": 75, "Cyber Security": 80},
        "city": "Faisalabad"
    },

    "STU104": {
        "name": "Hina Malik",
        "age": 23,
        "department": "Computer Science",
        "courses": ["Machine Learning", "Python", "Statistics"],
        "grades": {"Machine Learning": 89, "Python": 92, "Statistics": 84},
        "city": "Karachi"
    },

    "STU105": {
        "name": "Bilal Hassan",
        "age": 21,
        "department": "Software Engineering",
        "courses": ["Java", "Python", "Operating Systems"],
        "grades": {"Java": 76, "Python": 81, "Operating Systems": 78},
        "city": "Multan"
    }
}

# %%
## name      age    department    city         subject1   sub1 marks   subject2     subject3
## bilal     20       CS           faisalabad    python      80            java          c++

# %%
print("Name\t\t", "Age\t", "Department\t\t", "city")


for val in students.values():
    print(val['name'], val['age'], val['department'], val['city'], sep='\t')
# Out:
# Name		 Age	 Department		 city
# Ali Khan	21	Computer Science	Lahore
# Sara Ahmed	22	Software Engineering	Islamabad
# Usman Tariq	20	Information Technology	Faisalabad
# Hina Malik	23	Computer Science	Karachi
# Bilal Hassan	21	Software Engineering	Multan

# %%
students['STU101']['courses'][0]
# Out:
# 'Python'

# %%
students['STU102']['grades']
# Out:
# {'Python': 91, 'Web Development': 87, 'AI': 90}

# %%
print("Name\t\t", "Age\t", "Department\t\t", "city\t\t", "Subject1")


for val in students.values():
    print(val['name'], val['age'], val['department'], val['city'], sep='\t', end=' ')

    print("     ", val['courses'][0], val['grades'], val['courses'][1], val['courses'][2], sep='\t\t', end=' ')

    print()
# Out:
# Name		 Age	 Department		 city		 Subject1
# Ali Khan	21	Computer Science	Lahore      		Python		Data Structures		Database
# Sara Ahmed	22	Software Engineering	Islamabad      		Python		Web Development		AI
# Usman Tariq	20	Information Technology	Faisalabad      		Networking		Python		Cyber Security
# Hina Malik	23	Computer Science	Karachi      		Machine Learning		Python		Statistics
# Bilal Hassan	21	Software Engineering	Multan      		Java		Python		Operating Systems

# %%
students['STU101']['grades']['Python']
# Out:
# 88
