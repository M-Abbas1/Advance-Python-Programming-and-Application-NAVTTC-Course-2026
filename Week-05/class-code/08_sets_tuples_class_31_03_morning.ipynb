# %%
# Tuple

# %%
# syntax

# %%
t1 = (23, 53, 23, 56, 63)

# %%
t1
# Out:
# (23, 53, 23, 56, 63)

# %%
type(t1)
# Out:
# tuple

# %%
empty_tuple = ()

# %%
type(empty_tuple)
# Out:
# tuple

# %%
one_el_tuple = (438)

# %%
type(one_el_tuple)
# Out:
# int

# %%
one_el_tuple = (230,)

# %%
type(one_el_tuple)
# Out:
# tuple

# %%
hatr_tuple = ("hello", 3.14, 24, True)

# %%
hatr_tuple
# Out:
# ('hello', 3.14, 24, True)

# %%
str(32)
# Out:
# '32'

# %%
empty = tuple()

# %%
empty
# Out:
# ()

# %%
t = tuple([23,45, 64, 23])

# %%
t
# Out:
# (23, 45, 64, 23)

# %%
a, b = 20, 40

# %%
print(a)
print(b)
# Out:
# 20
# 40

# %%
t2 = 64, 23, 76, 86

# %%
t2
# Out:
# (64, 23, 76, 86)

# %%
type(t2)
# Out:
# tuple

# %%
## accessing elements from tuple

# %%
t1
# Out:
# (23, 53, 23, 56, 63)

# %%
t1[2]
# Out:
# 23

# %%
t1[-2]
# Out:
# 56

# %%
len(t1)
# Out:
# 5

# %%
t1
# Out:
# (23, 53, 23, 56, 63)

# %%
t1[start:end:steps]

# %%
t1[1:4]
# Out:
# (53, 23, 56)

# %%
t1[1::2]
# Out:
# (53, 56)

# %%
t1
# Out:
# (23, 53, 23, 56, 63)

# %%
t1[-5::2]
# Out:
# (23, 23, 63)

# %%
t1[4:2:-1]
# Out:
# (63, 56)

# %%
t1
# Out:
# (23, 53, 23, 56, 63)

# %%
t1[-2:-5:-2]
# Out:
# (56, 53)

# %%
t1[3:0:-2]
# Out:
# (56, 53)

# %%
t1
# Out:
# (23, 53, 23, 56, 63)

# %%
t[0] = 40
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 t[0] = 40
#
# TypeError: 'tuple' object does not support item assignment

# %%
## creation
## accessing
## editing (not possible because tuple is immutable)
## deletion

# %%
t1.remove(53)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 t1.remove(53)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
l = [53, 53]

# %%
del l[0]

# %%
l
# Out:
# [53]

# %%
t1
# Out:
# (23, 53, 23, 56, 63)

# %%
del t1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
del t1

# %%
t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 t1
#
# NameError: name 't1' is not defined

# %%
t2
# Out:
# (64, 23, 76, 86)

# %%
t2.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 t2.clear()
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %%
products = ('laptop', 'mobile', 'mouse', 'keyboard', 'screen')

# %%
products
# Out:
# ('laptop', 'mobile', 'mouse', 'keyboard', 'screen')

# %%
len(products)
# Out:
# 5

# %%
i = 0

while i<len(products):
    print(products[i])        ## i = 

    i += 1
# Out:
# laptop
# mobile
# mouse
# keyboard
# screen

# %%
for p in products:
    print(p)
# Out:
# laptop
# mobile
# mouse
# keyboard
# screen

# %%
for i in range(len(products)):
    print(products[i])
# Out:
# laptop
# mobile
# mouse
# keyboard
# screen

# %%
## operations on tuple

# %%
l1 = [10, 20, 30, 40]
l2 = [40, 30, 20, 10]

# %%
l1 + l2
# Out:
# [10, 20, 30, 40, 40, 30, 20, 10]

# %%
'kamran' + " " + 'akmal'
# Out:
# 'kamran akmal'

# %%
# concatenation

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
l2 = [20, 'string', False, 43.4]

# %%
l1 + l2
# Out:
# [10, 20, 30, 40, 20, 'string', False, 43.4]

# %%
20 + 'string'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 20 + 'string'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
30 + True
# Out:
# 31

# %%
products
# Out:
# ('laptop', 'mobile', 'mouse', 'keyboard', 'screen')

# %%
products.index('mobile')
# Out:
# 1

# %%
products.index('joy stick')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 products.index('joy stick')
#
# ValueError: tuple.index(x): x not in tuple

# %%
products.index('mouse')
# Out:
# 2

# %%
products.count('mouse')
# Out:
# 1

# %%
products.count('usb')
# Out:
# 0

# %%
t2
# Out:
# (64, 23, 76, 86)

# %%
min(t2)
# Out:
# 23

# %%
max(t2)
# Out:
# 86

# %%
sum(t2)
# Out:
# 249

# %%
t2
# Out:
# (64, 23, 76, 86)

# %%
sum(t2)
# Out:
# 249

# %%
sorted(t2)
# Out:
# [23, 64, 76, 86]

# %%
sorted(t2, reverse=True)
# Out:
# [86, 76, 64, 23]

# %%
t2
# Out:
# (64, 23, 76, 86)

# %%
t2
# Out:
# (64, 23, 76, 86)

# %%
sorted(t2)
# Out:
# [23, 64, 76, 86]

# %%
t2
# Out:
# (64, 23, 76, 86)

# %%
products
# Out:
# ('laptop', 'mobile', 'mouse', 'keyboard', 'screen')

# %%
min(products)
# Out:
# 'keyboard'

# %%
max(products)
# Out:
# 'screen'

# %%
sorted(products)
# Out:
# ['keyboard', 'laptop', 'mobile', 'mouse', 'screen']

# %%
l2
# Out:
# [20, 'string', False, 43.4]

# %%
t1 = tuple(l2)

# %%
t1
# Out:
# (20, 'string', False, 43.4)

# %%
sorted(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 sorted(t1)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
min(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 min(t1)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
t3 = (20, 30, 'string', False, 43.4)

# %%
sorted(t3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 sorted(t3)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
products
# Out:
# ('laptop', 'mobile', 'mouse', 'keyboard', 'screen')

# %%
products
# Out:
# ('laptop', 'mobile', 'mouse', 'keyboard', 'screen')

# %%
sum(products)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 sum(products)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
t2
# Out:
# (64, 23, 76, 86)

# %%
tuple([el+5 for el in t2])
# Out:
# (69, 28, 81, 91)

# %%
subject = ('urdu', (30, 50, 20), 'english', (30, 50, 20))

# %%
subject[1][2]
# Out:
# 20

# %%
subject[1][1:]
# Out:
# (50, 20)

# %%
d = {'name': 'khan', 'age':23}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
d.values()
# Out:
# dict_values(['khan', 23])

# %%
d.items()
# Out:
# dict_items([('name', 'khan'), ('age', 23)])

# %%
d
# Out:
# {'name': 'khan', 'age': 23}

# %%
d.items()
# Out:
# dict_items([('name', 'khan'), ('age', 23)])

# %%
list(d.items())
# Out:
# [('name', 'khan'), ('age', 23)]

# %%
list(d.items())[0]
# Out:
# ('name', 'khan')

# %%
key, val = list(d.items())[0]

# %%
key
# Out:
# 'name'

# %%
val
# Out:
# 'khan'

# %%
for k, v in d.items():
    print(k, v)
# Out:
# name khan
# age 23

# %%
students = {
    "STU101": {
        "name": "Ali Khan",
        "age": 21,
        "department": "Computer Science",
        "courses": ["Python", "Data Structures", "Database"],
        "grades": {"Python": 88, "Data Structures": 79, "Database": 85},
        "city": "Lahore"
    },

    "STU102": {
        "name": "Sara Ahmed",
        "age": 22,
        "department": "Software Engineering",
        "courses": ["Python", "Web Development", "AI"],
        "grades": {"Python": 91, "Web Development": 87, "AI": 90},
        "city": "Islamabad"
    },

    "STU103": {
        "name": "Usman Tariq",
        "age": 20,
        "department": "Information Technology",
        "courses": ["Networking", "Python", "Cyber Security"],
        "grades": {"Networking": 82, "Python": 75, "Cyber Security": 80},
        "city": "Faisalabad"
    },

    "STU104": {
        "name": "Hina Malik",
        "age": 23,
        "department": "Computer Science",
        "courses": ["Machine Learning", "Python", "Statistics"],
        "grades": {"Machine Learning": 89, "Python": 92, "Statistics": 84},
        "city": "Karachi"
    },

    "STU105": {
        "name": "Bilal Hassan",
        "age": 21,
        "department": "Software Engineering",
        "courses": ["Java", "Python", "Operating Systems"],
        "grades": {"Java": 76, "Python": 81, "Operating Systems": 78},
        "city": "Multan"
    }
}

# %%
students.keys()
# Out:
# dict_keys(['STU101', 'STU102', 'STU103', 'STU104', 'STU105'])

# %%
students['STU101']
# Out:
# {'name': 'Ali Khan',
#  'age': 21,
#  'department': 'Computer Science',
#  'courses': ['Python', 'Data Structures', 'Database'],
#  'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85},
#  'city': 'Lahore'}

# %%
type(students['STU101'])
# Out:
# dict

# %%
print(students['STU101']['name'])
print(students['STU102']['name'])
print(students['STU103']['name'])
print(students['STU104']['name'])
print(students['STU105']['name'])
# Out:
# Ali Khan
# Sara Ahmed
# Usman Tariq
# Hina Malik
# Bilal Hassan

# %%
students['STU103']['courses'][0]
students['STU103']['courses'][1]
students['STU103']['courses'][2]
# Out:
# 'Cyber Security'

# %%
print(students['STU101']['name'])
print(students['STU102']['name'])
print(students['STU103']['name'])
print(students['STU104']['name'])
print(students['STU105']['name'])
# Out:
# Ali Khan
# Sara Ahmed
# Usman Tariq
# Hina Malik
# Bilal Hassan

# %%
students[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 students[0]
#
# KeyError: 0

# %%
for student in students.keys():
    print(student)
# Out:
# STU101
# STU102
# STU103
# STU104
# STU105

# %%
students['STU102']
# Out:
# {'name': 'Sara Ahmed',
#  'age': 22,
#  'department': 'Software Engineering',
#  'courses': ['Python', 'Web Development', 'AI'],
#  'grades': {'Python': 91, 'Web Development': 87, 'AI': 90},
#  'city': 'Islamabad'}

# %%
for key in students.keys():
    print(students[key])     # students['STU103']
# Out:
# {'name': 'Ali Khan', 'age': 21, 'department': 'Computer Science', 'courses': ['Python', 'Data Structures', 'Database'], 'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85}, 'city': 'Lahore'}
# {'name': 'Sara Ahmed', 'age': 22, 'department': 'Software Engineering', 'courses': ['Python', 'Web Development', 'AI'], 'grades': {'Python': 91, 'Web Development': 87, 'AI': 90}, 'city': 'Islamabad'}
# {'name': 'Usman Tariq', 'age': 20, 'department': 'Information Technology', 'courses': ['Networking', 'Python', 'Cyber Security'], 'grades': {'Networking': 82, 'Python': 75, 'Cyber Security': 80}, 'city': 'Faisalabad'}
# {'name': 'Hina Malik', 'age': 23, 'department': 'Computer Science', 'courses': ['Machine Learning', 'Python', 'Statistics'], 'grades': {'Machine Learning': 89, 'Python': 92, 'Statistics': 84}, 'city': 'Karachi'}
# ...

# %%
print(students['STU101'])
print(students['STU102'])
print(students['STU103'])
print(students['STU104'])
print(students['STU105'])
# Out:
# {'name': 'Ali Khan', 'age': 21, 'department': 'Computer Science', 'courses': ['Python', 'Data Structures', 'Database'], 'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85}, 'city': 'Lahore'}
# {'name': 'Sara Ahmed', 'age': 22, 'department': 'Software Engineering', 'courses': ['Python', 'Web Development', 'AI'], 'grades': {'Python': 91, 'Web Development': 87, 'AI': 90}, 'city': 'Islamabad'}
# {'name': 'Usman Tariq', 'age': 20, 'department': 'Information Technology', 'courses': ['Networking', 'Python', 'Cyber Security'], 'grades': {'Networking': 82, 'Python': 75, 'Cyber Security': 80}, 'city': 'Faisalabad'}
# {'name': 'Hina Malik', 'age': 23, 'department': 'Computer Science', 'courses': ['Machine Learning', 'Python', 'Statistics'], 'grades': {'Machine Learning': 89, 'Python': 92, 'Statistics': 84}, 'city': 'Karachi'}
# ...

# %%
st1 = list(students.keys())[0]

# %%
st1
# Out:
# 'STU101'

# %%
students[st1]
# Out:
# {'name': 'Ali Khan',
#  'age': 21,
#  'department': 'Computer Science',
#  'courses': ['Python', 'Data Structures', 'Database'],
#  'grades': {'Python': 88, 'Data Structures': 79, 'Database': 85},
#  'city': 'Lahore'}

# %%
print(students['STU101']['name'])
print(students['STU102']['name'])
print(students['STU103']['name'])
print(students['STU104']['name'])
print(students['STU105']['name'])
# Out:
# Ali Khan
# Sara Ahmed
# Usman Tariq
# Hina Malik
# Bilal Hassan

# %%
for student in students.keys():
    print(students[student]['name']['age'])
# Out:
# Ali Khan 21
# Sara Ahmed 22
# Usman Tariq 20
# Hina Malik 23
# Bilal Hassan 21

# %%
st1 = students['STU101']

# %%
st1['age']
# Out:
# 21

# %%
for student in students.keys():
    print(students[student]['name'], students[student]['age'], students[student]['department'], students[student]['city'], sep='\t')
# Out:
# Ali Khan	21	Computer Science	Lahore
# Sara Ahmed	22	Software Engineering	Islamabad
# Usman Tariq	20	Information Technology	Faisalabad
# Hina Malik	23	Computer Science	Karachi
# Bilal Hassan	21	Software Engineering	Multan

# %%
print('hello', 23, '3.14', sep='\t')
# Out:
# hello	23	3.14

# %%
for key in students.keys():
    student = students[key]
    print(student['name'], student['age'], student['city'])
# Out:
# Ali Khan 21 Lahore
# Sara Ahmed 22 Islamabad
# Usman Tariq 20 Faisalabad
# Hina Malik 23 Karachi
# Bilal Hassan 21 Multan

# %%
alp = ['a', 'b', 'c', 'd', 'e', 'f']

for i in range(6):
    print(alp)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']
# ['a', 'b', 'c', 'd', 'e', 'f']
# ['a', 'b', 'c', 'd', 'e', 'f']
# ['a', 'b', 'c', 'd', 'e', 'f']
# ['a', 'b', 'c', 'd', 'e', 'f']
# ['a', 'b', 'c', 'd', 'e', 'f']
