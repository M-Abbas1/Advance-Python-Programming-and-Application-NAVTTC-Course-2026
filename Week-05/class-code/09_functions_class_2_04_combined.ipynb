# %%
## syntax

# %%
## def function_name():
###     block of code

# %%
def greet():
    print('welcome to python functions!')

# %%
greet()
# Out:
# welcome to python functions!

# %%
greet()
greet()
greet()
greet()
greet()
greet()
greet()
# Out:
# welcome to python functions!
# welcome to python functions!
# welcome to python functions!
# welcome to python functions!
# welcome to python functions!
# welcome to python functions!
# welcome to python functions!

# %%
def greet_with_name():
    print("Welcome to python functions! asmad")

# %%
greet_with_name()
# Out:
# Welcome to python functions! asmad

# %%
greet_with_name()
greet_with_name()
greet_with_name()
greet_with_name()
# Out:
# Welcome to python functions! asmad
# Welcome to python functions! asmad
# Welcome to python functions! asmad
# Welcome to python functions! asmad

# %%
def greet_with_name(name):
    print("welcome to python functions", name)

# %%
greet_with_name('ali')
# Out:
# welcome to python functions ali

# %%
n = 'sohail'

# %%
greet_with_name(n)
# Out:
# welcome to python functions sohail

# %%
greet_with_name('ahmad')
greet_with_name('kamil')
greet_with_name('muhammad')
greet_with_name('salman')
greet_with_name('sami')
# Out:
# welcome to python functions ahmad
# welcome to python functions kamil
# welcome to python functions muhammad
# welcome to python functions salman
# welcome to python functions sami

# %%
print('string1', 'string2', 43, 4.53)
# Out:
# string1 string2 43 4.53

# %%
l = [43, 64, 23]

# %%
l.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 l.index()
#
# TypeError: index expected at least 1 argument, got 0

# %%
l.index(43)
# Out:
# 0

# %%
def power():
    a, b = 2, 4
    print(f"{a} power {b}  : {a**b}")

# %%
power()
power()
power()
power()
power()
# Out:
# 2 power 4  : 16
# 2 power 4  : 16
# 2 power 4  : 16
# 2 power 4  : 16
# 2 power 4  : 16

# %%
def power(a, b):
    print(f"{a} power {b} : {a**b}")

# %%
power(2, 3)
# Out:
# 2 power 3 : 8

# %%
power(2, 2)
# Out:
# 2 power 2 : 4

# %%
power(8, 2)
# Out:
# 8 power 2 : 64

# %%
def power(a, b):
    p = a**b
    print(p)

# %%
print(power(3,3))
# Out:
# 27

# %%
power()

# %%
l
# Out:
# [43, 64, 23]

# %%
val_poped = l.pop()

# %%
val_poped
# Out:
# 23

# %%
print(power(1, 9))
# Out:
# 1
# None

# %%
m = print('string')
# Out:
# string

# %%
print(m)
# Out:
# None

# %%
greet()
# Out:
# welcome to python functions!

# %%
print(greet())
# Out:
# welcome to python functions!
# None

# %%
def power(a, b):
    p = a**b
    
    return print(p)
    

num1 = 3
num2 = 4

result = power(num1, num2)
print(result)
# Out:
# 81
# None

# %%
def power(a, b):
    print(type(a))
    print(type(b))
    p = a**b
    return p

# %%
print(power(2, 5))
# Out:
# <class 'int'>
# <class 'int'>
# 32

# %%
print(power('34', 'dkld'))
# Out:
# <class 'str'>
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 print(power('34', 'dkld'))
#
# Cell In[52], line 4, in power(a, b)
#       2 print(type(a))
#       3 print(type(b))
# ----> 4 p = a**b
#       5 return p
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'str'

# %%
def power(a, b):
    if type(a) == int and type(b) == int:
        p = a**b
        return p

# %%
power(2, 3)
# Out:
# 8

# %%
print(power(3.2, 3))   # abstraction
# Out:
# None

# %%
def greet():
    print('first line in greet function')
    return "return to the point from where you have been called"
    print('statement after return ')

# %%
print(greet())
# Out:
# first line in greet function
# return to the point from where you have been called

# %%
def greet():
    print("welcome to python functions")

# %%
greet()
# Out:
# welcome to python functions

# %%
greet()
greet()
greet()
greet()
greet()
greet()
greet()
# Out:
# welcome to python functions
# welcome to python functions
# welcome to python functions
# welcome to python functions
# welcome to python functions
# welcome to python functions
# welcome to python functions

# %%
def greet_with_name():
    name = 'mahnoor'
    print("Welcome to python functions ", name)

# %%
greet_with_name()
greet_with_name()
greet_with_name()
greet_with_name()
# Out:
# Welcome to python functions  mahnoor
# Welcome to python functions  mahnoor
# Welcome to python functions  mahnoor
# Welcome to python functions  mahnoor

# %%
def greet_with_name(n):
    name = n
    print("welcome to python functions", name)

# %%
greet_with_name('ali')
# Out:
# welcome to python functions ali

# %%
greet_with_name('salman')
# Out:
# welcome to python functions salman

# %%
greet_with_name('fiza')
# Out:
# welcome to python functions fiza

# %%
def power(a, b):
    p = a**b
    print(p)

# %%
power(1, 2)
# Out:
# 1

# %%
power(2, 2)
# Out:
# 4

# %%
power(3, 4)
# Out:
# 81

# %%
num1 = 3
num2 = 2

power(num1, num2)
# Out:
# 9

# %%
print(power(num1, num2))
# Out:
# 9
# None

# %%
l = [4, 5, 2, 6]

# %%
print(None)
# Out:
# None

# %%
print(print('string'))
# Out:
# string
# None

# %%
def power(num1, num2):
    p = num1 ** num2
    print(p)
    return p

n1 = 90
n2 = 1

res = power(3, 5)
# Out:
# 243

# %%
greet()
# Out:
# welcome to python functions

# %%
print(greet())
# Out:
# welcome to python functions
# None

# %%
def cal(n1, n2):
    add = n1 + n2
    sub = n1 - n2
    return n1, n2

# %%
print(cal(23, 23))
# Out:
# (23, 23)

# %%
a, b, c = (4, 5, 2)

# %%
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 2

# %%
print(cal(2, 5))
# Out:
# (2, 5)

# %%
result = cal(4, 5)

# %%
result
# Out:
# (4, 5)

# %%
type(result)
# Out:
# tuple

# %%
add, sub = cal(6, 64)

# %%
print(add)
print(sub)
# Out:
# 6
# 64

# %%
def greet():
    print('first line in greet function')
    return "string"
    print('statements after return')
    print('statements after return')
    print('statements after return')

# %%
print(greet())
# Out:
# first line in greet function
# string

# %%
def greet():
    print('first line in greet function')
    return "string"
    print('statements after return')
    print('statements after return')
    print('statements after return')

# %%
greet()
# Out:
# first line in greet function
# 'string'

# %%
def power(a, b):
    if type(a) in (int, float) and type(b) in (int, float):
        p = a**b
        return p
    else:
        print("please provide valid input")

# %%
power('3', 5)
# Out:
# please provide valid input

# %%
power(3,'sdk')
# Out:
# please provide valid input

# %%
power(3.5, 3)
# Out:
# 42.875

# %%
power(3, 4)
# Out:
# 81

# %%
power(3, 4.4)
# Out:
# 125.69949148714419

# %%
power(3.3, 3.3)
# Out:
# 51.415729444066585

# %%
power('s', 'p')
# Out:
# please provide valid input

# %%
power('p', 4)
# Out:
# please provide valid input

# %%
def pow(a, b):
    p = a**b
    return p


pow(3, 3)
# Out:
# 27

# %%
pow('sd', 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 pow('sd', 4)
#
# Cell In[138], line 2, in pow(a, b)
#       1 def pow(a, b):
# ----> 2     p = a**b
#       3     return p
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'
