# %% [markdown]
# # Functions - In-Class Tasks
#
# Complete these tasks with instructor guidance.
#
# ---

# %% [markdown]
# ## Task 1: Simple Greeting Function
#
# **Difficulty:** ⭐ Easy
#
# Create function that greets a person.
#
# **Requirements:**
# - Function: `greet(name)`
# - Print greeting message

# %%
# Write your code here

# %% [markdown]
# ## Task 2: Calculator Functions
#
# **Difficulty:** ⭐ Easy
#
# Create four calculator functions.
#
# **Requirements:**
# - `add(a, b)` - return sum
# - `subtract(a, b)` - return difference
# - `multiply(a, b)` - return product
# - `divide(a, b)` - return quotient (handle division by zero)

# %%
# Write your code here

# %% [markdown]
# ## Task 3: Temperature Converter
#
# **Difficulty:** ⭐⭐ Medium
#
# Convert between Celsius and Fahrenheit.
#
# **Requirements:**
# - `celsius_to_fahrenheit(celsius)`
# - `fahrenheit_to_celsius(fahrenheit)`
# - Return converted value

# %%
# Write your code here

# %% [markdown]
# ## Task 4: Even or Odd Checker
#
# **Difficulty:** ⭐ Easy
#
# Check if number is even or odd.
#
# **Requirements:**
# - `is_even(number)` - return True/False
# - `is_odd(number)` - return True/False

# %%
# Write your code here

# %% [markdown]
# ## Task 5: Find Maximum
#
# **Difficulty:** ⭐⭐ Medium
#
# Find maximum of three numbers.
#
# **Requirements:**
# - `find_max(a, b, c)` - return largest
# - Don't use built-in max()

# %%
# Write your code here

# %% [markdown]
# ## Task 6: List Statistics
#
# **Difficulty:** ⭐⭐ Medium
#
# Calculate list statistics.
#
# **Requirements:**
# - `calculate_average(numbers)` - return average
# - `find_range(numbers)` - return max - min
# - Test with sample list

# %%
# Write your code here

# %% [markdown]
# ## Task 7: Default Parameters
#
# **Difficulty:** ⭐⭐ Medium
#
# Function with default parameters.
#
# **Requirements:**
# - `greet_with_time(name, time="morning")`
# - Print "Good {time}, {name}!"
# - Test with and without time parameter

# %%
# Write your code here

# %% [markdown]
# ## Task 8: Multiple Return Values
#
# **Difficulty:** ⭐⭐⭐ Hard
#
# Function returning multiple values.
#
# **Requirements:**
# - `analyze_list(numbers)`
# - Return: sum, average, min, max
# - Unpack and display all values

# %%
# Write your code here

# %% [markdown]
# ## Task 9: Variable Arguments
#
# **Difficulty:** ⭐⭐⭐ Hard
#
# Function accepting variable arguments.
#
# **Requirements:**
# - `multiply_all(*numbers)` - multiply all arguments
# - Test with different number of arguments

# %%
# Write your code here

# %% [markdown]
# ## Task 10: Lambda Function
#
# **Difficulty:** ⭐⭐⭐ Hard
#
# Create and use lambda functions.
#
# **Requirements:**
# - Lambda to square a number
# - Lambda to check if number > 10
# - Use with list of numbers

# %%
# Write your code here

# %% [markdown]
# ---
# ## Bonus Challenges

# %% [markdown]
# ### Bonus 1: Recursive Function
#
# Create `factorial(n)` using recursion.

# %%
# Write your code here

# %% [markdown]
# ### Bonus 2: Fibonacci Function
#
# Generate first n Fibonacci numbers.

# %%
# Write your code here

# %% [markdown]
# ---
# ## Self-Assessment
#
# - [ ] Define functions with def
# - [ ] Use parameters and arguments
# - [ ] Return values from functions
# - [ ] Use default parameters
# - [ ] Understand scope
# - [ ] Use *args and **kwargs
# - [ ] Create lambda functions
# - [ ] Write docstrings
# - [ ] Call functions correctly
# - [ ] Understand return vs print
