# %%
full_date = "16 May 2006"

# %%
first_space = full_date.find(' ')
second_space = full_date.find(' ', 3)

# %%
print(first_space)
print(second_space)
# Out:
# 2
# 6

# %%
date = int(full_date[:first_space])
month = full_date[first_space+1:second_space]
year = int(full_date[second_space+1:])
print(date)
print(month)
print(year)
type(year)
# Out:
# 16
# May
# 2006
# int

# %%
date
# Out:
# '16'

# %%
full_name = input("enter your full name: ")

# %%
full_name
# Out:
# '   muhammad,  kamil, khan  '

# %%
"khalid".strip(',')
# Out:
# 'khalid'

# %%
sen = "the first word of word programming"

# %%
sen.replace('word', 'time')
# Out:
# 'the first time of time programming'

# %%
len(sen)
# Out:
# 34

# %%
sen.count('first')
# Out:
# 1

# %%
"the sentence".title()
# Out:
# 'The Sentence'

# %%
"first time in corvit".split()
# Out:
# ['firs', ' ', 'ime in corvi', '']

# %%
is_sunny  = False

# %%
print(is_sunny)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
user_name = input("Enter your name: ")

# %%
user_name
# Out:
# 'abbas'

# %%
type(user_name)
# Out:
# str

# %%
age = int(input("enter your age: "))

# %%
type(age)
# Out:
# int

# %%
type(age)
# Out:
# str

# %%
age = '38' * 2  # '3838'
print(age)
type(age)
# Out:
# 3838
# str

# %%
age = int(age)
print(age)
type(age)
# Out:
# 3838
# int

# %%
name = ''

bool(name)
# Out:
# False

# %%
user_name = input("enter your name: ");

print(user_name);
print(bool(user_name))

if bool(user_name):
    print("continue")
# Out:
# khan
# True
# continue

# %%
price = 30.5

# %%
str(price)
# Out:
# '30.5'

# %%
int(price)
# Out:
# 30

# %%
bool(2.6)
# Out:
# True

# %%
a = b = c = 48

# %%
print(a, b, c)
# Out:
# 48 48 48

# %%
full_name = "muhammad hasseb khan"

# %%
print(full_name[8::-1])
# Out:
#  dammahum

# %%
print(full_name[0], end='')
print(full_name[-1], end='')
print(full_name[-2], end='')
print(full_name[-3], end='')
print(full_name[-4], end='')
print(full_name[-5], end='')
print(full_name[-6], end='')
print(full_name[-7], end='')
# Out:
# mnahk be

# %%
full_name = "muhammad hasseb khan"

# %%
len(full_name)
# Out:
# 20

# %%
full_name[-5:-12:-1]
# Out:
# ' bessah'
