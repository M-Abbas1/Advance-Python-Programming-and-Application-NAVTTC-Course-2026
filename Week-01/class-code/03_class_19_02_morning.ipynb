# %% [markdown]
# ## arithematic operators
# ## comparison operators
# ## logical operators
# ## bitwise operators
# ## member operators
# ## identity operators

# %%
# logical operators

# %%
age = 27;
voting_age = 18;

print(f"Age == voting age : {age==voting_age}")
print(f"Age == voting age : {type(age==voting_age)}")
# Out:
# Age == voting age : False
# Age == voting age : <class 'bool'>

# %%
27 == 18
# Out:
# False

# %%
### !=

print(f"age is {age!=voting_age} equal to voting age")
# Out:
# age is True equal to voting age

# %%
## >
print(f"age is greater than voting age: {age>voting_age}")
# Out:
# age is greater than voting age: True

# %%
## <
print(f"age is less than voting age: {age<voting_age}")
# Out:
# age is less than voting age: False

# %%
# >=

print(f"age is greater than or equal to voting age: {age>=voting_age}")
# Out:
# age is greater than or equal to voting age: True

# %%
age = 18
voting_age = 18
print(f"age is greater than or equal to voting age: {age>=voting_age}")
# Out:
# age is greater than or equal to voting age: True

# %%
# <=
print(f"age is less than or equal to voting age: {age<=voting_age}")
# Out:
# age is less than or equal to voting age: True

# %%
5.5 == 5
# Out:
# False

# %%
"ant" > "ants"
# Out:
# False

# %%
# logical operators
# and

# %%
has_ticket = False
has_id = False

print(has_ticket and has_id)
# Out:
# False

# %%
has_ticket = True
has_id = True

print(not has_ticket or  not has_id)
# Out:
# False

# %%
not has_id
# Out:
# True

# %%
# bitwise operators

# %%
## &
## |
## ^
## <<
## >>

# %%
9 ^ 7
# Out:
# 14

# %%
bin(5)
# Out:
# '0b101'

# %%
10 >> 4
# Out:
# 0

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(2)
# Out:
# '0b10'

# %%
10 * 2**2
# Out:
# 40

# %%
2 << 20
# Out:
# 2097152

# %%
2 * 2**20
# Out:
# 2097152

# %%
2 / (2**2)
# Out:
# 0.5

# %%
2 >> 2
# Out:
# 0

# %%
int(0.5)
# Out:
# 0

# %%
sen = "first ramdan_ul mubarak"

# %%
'_' in sen
# Out:
# True

# %%
'the' not in sen
# Out:
# True

# %%
a = 10
b = 10
print(a is b)
# Out:
# True

# %%
id(a)
# Out:
# 140706470941768

# %%
id(b)
# Out:
# 140706470941768

# %%
big_number1 = 533984
big_number2 = 533984
big_number1 is big_number2
# Out:
# False

# %%
id(big_number1)
# Out:
# 1706087190160

# %%
id(big_number2)
# Out:
# 1706087190416

# %%
user_org_id = 420399848
user_id = 420399848

if user_org_id == user_id:
    print("can enter")
# Out:
# can enter

# %%
a =  38

# %%
-a
# Out:
# -38

# %%
age = 37

# %%
age = age + 5

# %%
age *= 5
print(age)
# Out:
# 42.0

# %%
print(b := 39)
# Out:
# 39

# %%
age = 30

# %%
b
# Out:
# 39

# %%
"muhammad abbas khan".split()
# Out:
# ['muhammad', 'abbas', 'khan']

# %%
f"the programming knowledge".split()
# Out:
# ['the', 'programming', 'knowledge']

# %%
print(f"programming knowledge",  sep='\n')
# Out:
# programming,knowledge

# %%
(x := 30)
# Out:
# 30

# %%
bin(40)
# Out:
# '0b101000'

# %%
0o33443
# Out:
# 14115
