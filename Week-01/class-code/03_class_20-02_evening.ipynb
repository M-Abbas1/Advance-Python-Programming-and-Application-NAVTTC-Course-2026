# %%
# Arithmetic operatos

# (1) -> +  addition
# (2) -> -  subtraction
# (3) -> *  multiplication
# (4) -> /  Division
# (5) -> // Floor division
# (6) -> ** Power
# (7) -> %  Modulus

# %%
# comaprison operators

# (1) == equal to (a==b) True or False
# (2) != not equal to (boolean)
# (3) >   greater than
# (4) <  leas than
# (5) >=  greater than or equal to
# (6) <=  less than or equal to

# %%
a = 10;
b = 5;

print(f"a == b : {a==b}")
print(f"a != b : {a!=b}")
print(f"a > b : {a>b}")
print(f"a < b : {a<b}")
print(f"a >= b : {a>=b}")
print(f"a <= b : {a<=b}")
# Out:
# a == b : False
# a != b : True
# a > b : True
# a < b : False
# a >= b : True
# a <= b : False

# %%
if a==b:
    print("a is equal to b")
    print("yes it true")
print('hi')
# Out:
# hi

# %%
'Muhammad' != 'muhammad'
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
user_name = input("enter your name: ")

bool(user_name)
# Out:
# True

# %%
actual_name = "waleed"

name = input("enter your name : ")

print(f"Yes, this user is the actual user : {actual_name==name}")
# Out:
# Yes, this user is the actual user : False

# %% [markdown]
# # logical operators

# %% [markdown]
# # and operators

# %%
print(f"{True} and {True} : {True and True}")
print(f"{True} and {False} : {True and False}")
print(f"{False} and {True} : {False and True}")
print(f"{False} and {False} : {False and False}")
# Out:
# True and True : True
# True and False : False
# False and True : False
# False and False : False

# %%
actual_user_name = 'wajahat'
actual_password = 'secret132'

user_name = input("enter name : ")
password = input("enter password : ")

actual_user_name == user_name and actual_password == password
# Out:
# False

# %% [markdown]
# ## or operator

# %%
print(f"{True} or {True} : {True or True}")
print(f"{True} or {False} : {True or False}")
print(f"{False} or {True} : {False or True}")
print(f"{False} or {False} : {False or False}")
# Out:
# True or True : True
# True or False : True
# False or True : True
# False or False : False

# %%
10 == 34 or 20 == 40
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
sen = "the worth of mathematics is seen with AI"

# %%
'the worth' in  sen
# Out:
# True

# %%
email = input("Enter your email : ")

'@' in email
# Out:
# True

# %% [markdown]
# ### identity operators

# %%
a = 234
b = 234
a != b
# Out:
# False

# %%
a is not b
# Out:
# False

# %%
print(id(a))
print(id(b))
# Out:
# 140706960699464
# 140706960699464

# %% [markdown]
# # Bitwise Operators

# %%
478 & 837
# Out:
# 324

# %%
bin(478)
# Out:
# '0b111011110'

# %%
bin(837)
# Out:
# '0b1101000101'

# %%
0111011110
1101000101
---------
0101000100

# %%
temp = 0b101000100 
temp
# Out:
# 324

# %%
# Bitwise OR |

# %%
12 | 3
# Out:
# 15

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(3)
# Out:
# '0b11'

# %%
1100
0011
---------
1111

# %%
0b1111
# Out:
# 15

# %%
# XOR ^

# %%
12 ^ 8
# Out:
# 4

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(8)
# Out:
# '0b1000'

# %%
0b1100
0b1000
--------
0b0100
# Out:
#   Cell In[34], line 1
#     0b1010'
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
## left shift <<

# %%
12 << 3
# Out:
# 96

# %%
12 * 2**3
# Out:
# 96

# %%
bin(12)
# Out:
# '0b1100'

# %%
0b1100000
# Out:
# 96

# %%
## right shift

# %%
13 >> 2
# Out:
# 3

# %%
bin(13)
# Out:
# '0b1101'

# %%
0b0011
# Out:
# 3

# %%
13/4
# Out:
# 3.25

# %%
## compound assignment

# %%
age = 30

# %%
age = age + 5

# %%
age += 5

# %%
age -= 5
age
# Out:
# 35

# %%
price = 20
print(price)
price *= 2
print(price)
# Out:
# 20
# 40

# %%
price /= 2
price
# Out:
# 20.0

# %%
price //= 3

# %%
price
# Out:
# 6.0

# %%
# Palindrome check

# %%
num = int(input("Enter a number : "))

str_num = str(num)   

rev_str_num = str_num[::-1]

rev_num = int(rev_str_num)


print(f"the {num} is palinrome : {num==rev_num}")
# Out:
# the 454 is palinrome : True

# %%
2034 // 10
# Out:
# 203

# %%
2034 / 10
# Out:
# 203.4

# %%
bin(4)
# Out:
# '0b100'

# %%
bin(5)
# Out:
# '0b101'

# %%
4 & 5
# Out:
# 4

# %%
100
101
----
100  -> 4

# %%
0b100
# Out:
# 4

# %%
False & False
# Out:
# False

# %%
7 | 6
# Out:
# 7

# %%
print(bin(7))
print(bin(6))
# Out:
# 0b111
# 0b110

# %%
11 ^ 9
# Out:
# 2

# %%
print(bin(11))
print(bin(9))
# Out:
# 0b1011
# 0b1001

# %%
0b0010
# Out:
# 2

# %%
## left shift <<

# %%
print(bin(7))
# Out:
# 0b111

# %%
7 << 2
# Out:
# 28

# %%
0b11100
# Out:
# 28

# %%
print(bin(9))
# Out:
# 0b1001

# %%
9 >> 3
# Out:
# 1

# %%
0b0001
# Out:
# 1

# %%
num  = int(input("enter a number "))  # 2023

rev_num = str(num%10)     # '3'
num = num // 10            #  202

rev_num = rev_num + str(num%10)    # '32'
num = num // 10                    # 20

rev_num = rev_num + str(num%10)    # '320'
num = num // 10                    # 2

rev_num = rev_num + str(num%10)    # '320' + '2' --> 3202


print(rev_num)
# Out:
# 4302
