# %%
print('hello world')
print("Hello world")
print("""This is the beginnning
of you python""")
# Out:
# hello world
# Hello world
# This is the beginnning
# of you python

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("banana", "apple", "mango")
# Out:
# banana apple mango

# %%
print("int ", 5345, "float : ", 5.33, "boolean : ", True)
# Out:
# int  5345 float :  5.33 boolean :  True

# %%
print("apple", "banana", "mango")
# Out:
# apple banana mango

# %%
print("apple", "banana", sep='\n')
# Out:
# apple
# banana

# %%
print("hello world", end='-')
print("hello world")
# Out:
# hello world-hello world

# %%
print("apple", "banana", "mango", sep="-", end="Fruits")
# Out:
# apple-banana-mangoFruits

# %%
print("hello \n world")
# Out:
# hello
#  world

# %%
print("Hello\tworld")
# Out:
# Hello	world

# %%
print("I am 37 tear old")
# Out:
# I am 37 tear old

# %%
print("hello world\b")
# Out:
# hello worl

# %%
print("the\b end\b")
# Out:
# th en

# %%
x = "muhammad adnan khan"
print("apple", "banana", '\b')
# Out:
# apple banana

# %%
print('your\'s')
# Out:
# your's

# %%
print("hello \rwor")
# Out:
# worlo

# %%
x = "hello \rworld"

print(x)
# Out:
# world

# %%
len(x)
# Out:
# 12

# %%
res =  print("the is a call to print function")
# Out:
# the is a call to print function

# %%
print(res)
# Out:
# None

# %%
print("D:\AI\ndvance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\Week-01")
# Out:
# D:\AI
# dvance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\Week-01

# %%
print(r"D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\Week-01")
# Out:
# D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\Week-01

# %% [markdown]
# ## String Concatenation

# %%
print("the is the best"+"practice to ")
# Out:
# the is the bestpractice to

# %%
print("hello"+str(46))
# Out:
# hello46

# %% [markdown]
# ### Straing Formating

# %% [markdown]
# - this is a bullet point

# %%
name  = "khalid";
age = 23;

# %%
print("Name : ", name)
print("Age : ", age)
# Out:
# Name :  khalid
# Age :  23

# %%
print(f"Name : {name}")
# Out:
# Name : khalid

# %%
print("name : {0}".format(name))
# Out:
# name : khalid

# %%
print("my name is {a}. i am {b} years old".format(a=name, b=age))
# Out:
# my name is khalid. i am 23 years old

# %%
name = "khalid";
age = 24;
account_number = 245224525;



print("nameof \t:", name)
print("age \t:", age)
print("account number \t:", account_number)
# Out:
# nameofu 	: khalid
# age 	: 24
# account number 	: 245224525

# %%
pi = 3.141559359739

# %%
print("PI : ", pi)
# Out:
# PI :  3.141559359739

# %%
print(f"PI: {pi:.3f}")
# Out:
# PI: 3.142

# %%
print(f"PI: {pi:.3e}")
# Out:
# PI: 3.142e+00

# %%
account_number = 432984727347289;

# %%
print(f"Account Number : {account_number:,}")
# Out:
# Account Number : 432,984,727,347,289

# %%
"account nubmer".upper()
# Out:
# 'ACCOUNT NUBMER'

# %%
"ACCOUNT NUMBER".lower()
# Out:
# 'account number'

# %%
len("account number")
# Out:
# 14

# %%
print(f"{'python':^15}")
# Out:
#     python

# %%
print(f"{'python':^1}")
# Out:
# python

# %%
print("*"*40)
# Out:
# ****************************************
