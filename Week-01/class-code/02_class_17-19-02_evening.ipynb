# %%
age = 24 
print(age)
# Out:
# 24

# %%
type(4784784)
# Out:
# int

# %%
price = 50.5

# %%
type(price)
# Out:
# float

# %%
user_name = "wakeel"

# %%
type(user_name)
# Out:
# str

# %%
is_married = True

# %%
type(is_married)
# Out:
# bool

# %%
# Pascal case

FirstUserEmail = "dhfklasdklf@gmail.com"

# %%
type(UserEmail)
# Out:
# str

# %%
firstUserEmail = "djfhldh@gmail.com"

# %%
print(userEmail)
# Out:
# djfhldh@gmail.com

# %%
# PascalCase
# camelCase
# snake_case
# Snake_Case

# %%
price = 500
type(price)
# Out:
# int

# %%
print(price)
# Out:
# 500

# %%
price = 1000

# %%
print(price)
# Out:
# 1000

# %%
price = 500.5

# %%
type(price)
# Out:
# float

# %%
price = "5000 PKR"

# %%
type(price)
# Out:
# str

# %%
price = 1000

# %%
type(price)
# Out:
# int

# %%
price = price + 50

# %%
price
# Out:
# 1050

# %% [markdown]
# ## Integer

# %%
positive_no = 37643
negative_no = -378

# %%
print("Positive Number : ", positive_no)
print("Negative Number : ", negative_no)
# Out:
# Positive Number :  37643
# Negative Number :  -378

# %%
price = 10000000000000000000000000000

# %%
print(price)
# Out:
# 10000000000000000000000000000

# %%
length = 20
width = 30

# %%
print(f"the addition of length and width : {length + width}")
# Out:
# the addition of length and width : 50

# %%
print(f"the subtraction of length and width : {length - width}")
# Out:
# the subtraction of length and width : -10

# %%
print(f"total area is  : {length * width} feet")
# Out:
# total area is  : 600 feet

# %%
print(f"the addition of length and width : {length / width:.2f}")
# Out:
# the addition of length and width : 0.67

# %%
div = length/width

# %%
type(div)
# Out:
# float

# %%
type(20/4)
# Out:
# float

# %%
20/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 20/0
#
# ZeroDivisionError: division by zero

# %%
length = 104
width = 20

# %%
print(f"the floor division of length and width is : {length // width}")
# Out:
# the floor division of length and width is : 5

# %%
104/20
# Out:
# 5.2

# %%
floor_div = length//width

# %%
type(floor_div)
# Out:
# int

# %%
length%width
# Out:
# 4

# %%
104.4%20.0
# Out:
# 4.400000000000006

# %%
104.4/20
# Out:
# 5.220000000000001

# %%
## FLoat

# %%
price = 30.5

# %%
print(price)
# Out:
# 30.5

# %%
type(price)
# Out:
# float

# %%
height = 6.2
length = 4.6

# %%
print(f"Addition of {height} and {length} is {height + length}")
# Out:
# Addition of 6.2 and 4.6 is 10.8

# %%
print(f"Subtraction of {height} and {length} is {height - length:.2f}")
# Out:
# Subtraction of 6.2 and 4.6 is 1.60

# %%
print(f"Multiplication of {height} and {length} is {height * length}")
# Out:
# Multiplication of 6.2 and 4.6 is 28.52

# %%
print(f"Floor division of {height} and {length} is {height // length}")
# Out:
# Floor division of 6.2 and 4.6 is 1.0

# %%
print(f"division of {height} and {length} is {height / length}")
# Out:
# division of 6.2 and 4.6 is 1.347826086956522

# %%
2.5**2
# Out:
# 6.25

# %%
# string

# %%
age = '30'

# %%
user_name = "usman khan"

# %%
type(user_name)
# Out:
# str

# %%
type = "underfined"

# %%
type
# Out:
# 'underfined'

# %%
print = 67

# %%
print('hi')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 print('hi')
#
# TypeError: 'int' object is not callable

# %%
length
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 length
#
# NameError: name 'length' is not defined

# %%
# indexing

# %%
full_name = "muhammad khushal khan"

# %%
len(full_name)
# Out:
# 21

# %%
full_name[21]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 full_name[21]
#
# IndexError: string index out of range

# %%
full_name = "muhammad khushal khan"

# %%
first_name  = full_name[9:16]

# %%
print(first_name)
# Out:
# khushal

# %%
full_name[::-1]
# Out:
# 'nahk lahsuhk dammahum'

# %%
full_name = "muhammad khushal khan"

# %%
full_name[0:10:-1]
# Out:
# ''

# %%
full_name = "muhammad kamil khan"

# %%
print(full_name)
full_name
# Out:
# muhammad kamil khan
# 'muhammad kamil khan'

# %%
39 + 10
# Out:
# 49

# %%
# methods of strings

# %%
sen = "the FIRST day of ramdan ul mubarak"

# %%
lower_case = sen.lower()

# %%
print(lower_case)
# Out:
# the first day of ramdan ul mubarak

# %%
print("sentence in upper case : ", sen.upper())
# Out:
# sentence in upper case :  THE FIRST DAY OF RAMDAN UL MUBARAK

# %%
print("senetence in title form : ", sen.title())
# Out:
# senetence in title form :  The First Day Of Ramdan Ul Mubarak

# %%
print("sentence in capitalized form : ", sen.capitalize())
# Out:
# sentence in capitalized form :  The first day of ramdan ul mubarak

# %%
print(sen)
# Out:
# the FIRST day of ramdan ul mubarak

# %%
print("the location of day in sentence is : ", sen.find('day'))
# Out:
# the location of day in sentence is :  10

# %%
full_date = "26 may 2026"

# %%
print(full_date)
# Out:
# 26 may 2026

# %%
space = full_date.find(' ')

# %%
print(space)
# Out:
# 2

# %%
full_date = "26 may 2026"

first_space = full_date.find(' ')
second_space = full_date.find(' ', first_space+1)

print(first_space)
print(second_space)

date = full_date[0:first_space]
month = full_date[first_space+1:second_space]
year = full_date[second_space+1 : ]

print("The date is : ", date)
print("The month is : ", month)
print("The year si : ", year)
# Out:
# 2
# 6
# The date is :  26
# The month is :  may
# The year si :  2026

# %%
full_date.find('may')
# Out:
# 3

# %%
sen
# Out:
# 'the FIRST day of ramdan ul mubarak'

# %%
print(sen.replace('FIRST', "LAST"))
# Out:
# the LAST day of ramdan ul mubarak

# %%
full_date
# Out:
# '26 may 2026'

# %%
new_date = full_date.replace('may', "Aug")

# %%
print(new_date)
# Out:
# 26 Aug 2026

# %%
full_name = "ttttmuhammad khalidttt"

# %%
full_name = full_name.strip('t')
print(full_name)
# Out:
# muhammad khalid

# %%
full_name
# Out:
# 'muhammad khalid'

# %%
full_name = "  muhammad khalid   "

# %%
temp  = full_name.lstrip()

# %%
len(temp)
# Out:
# 18

# %%
temp
# Out:
# 'muhammad khalid   '

# %%
full_name.rstrip()
# Out:
# '  muhammad khalid'

# %%
full_name.strip()

# %%
## count

sen
# Out:
# 'the FIRST day of ramdan ul mubarak'

# %%
sen.count('d') + sen.count('m')
# Out:
# 4

# %%
first_name = "imran"
second_name = "khan"

# %%
full_name = first_name + ' ' + second_name

# %%
print(full_name)
# Out:
# imran khan

# %%
laugh = 'Ha' * 5
print(laugh)
# Out:
# HaHaHaHaHa

# %%
full_name.index(' ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 full_name.index('w')
#
# ValueError: substring not found

# %%
full_name.find('w')
# Out:
# -1

# %%
email = "student123@gmail.com"

# %%
indix_location = email.find('@')
indix_location
# Out:
# 10

# %%
replacemnt_str = email[3:indix_location]

# %%
email.replace(replacemnt_str, '*'*len(replacemnt_str))
# Out:
# 'stu*******@gmail.com'

# %%
email = "student123@gmail.com"
print(email)
# Out:
# student123@gmail.com

# %%
l = email.find('@')  # 10

rep_str = email[3:l]

email.replace(rep_str, '*'*len(rep_str))
# Out:
# 'stu*******@gmail.com'

# %%
email.replace(email[3:email.find('@')], '*****')
# Out:
# 7

# %%
'*'*7
# Out:
# '*******'

# %%
'ha'*20
# Out:
# 'hahahahahahahahahahahahahahahahahahahaha'

# %%
# split

# %%
full_name = "muhammad,adnan,khan"

# %%
first_name, middle_name, last_name = full_name.split(',')

# %%
print(first_name)
print(middle_name)
print(last_name)
# Out:
# muhammad
# adnan
# khan

# %%
# compound assignment

a = 90
b = 78
c = 53

print("a : ",a, " b : ", b, " c : ", c)
# Out:
# a :  90  b :  78  c :  53

# %%
a, b, c = 900, 947, 759

print("a : ",a, " b : ", b, " c : ", c)
# Out:
# a :  900  b :  947  c :  759

# %%
a = b = c = 400

print("a : ",a, " b : ", b, " c : ", c)
# Out:
# a :  400  b :  400  c :  400

# %%
## boolean datatype

# %%
True #1 On
False #0 off
# Out:
# False

# %% [markdown]
# ### type conversion or type casting

# %%
age = int(input("Enter your age: "))

# %%
type(age)
# Out:
# int

# %%
user_name = input("Enter your name : ")

# %%
print(user_name)
# Out:
# hggghjgj

# %%
s = str(100)

# %%
type(s)
# Out:
# str

# %%
int(s) + 2
# Out:
# 102

# %%
price = '100.5'

# %%
type(price)
# Out:
# str

# %%
float(price) * 2
# Out:
# 201.0

# %%
shirt_price = '100 PKR'
print(int(shirt_price))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 2
#       1 shirt_price = '100 PKR'
# ----> 2 print(int(shirt_price))
#
# ValueError: invalid literal for int() with base 10: '100 PKR'

# %%
price_value, currency = shirt_price.split()
price_value = int(price_value) + 50
new_price_value = str(price_value)+ " " + currency;
print(new_price_value)
print(type(new_price_value))
# Out:
# 150 PKR
# <class 'str'>

# %%
## boolean conversion

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(39834)
# Out:
# True

# %%
bool(-2)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool(0.044)
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool(' ')
# Out:
# True

# %%
bool('kahn')
# Out:
# True

# %%
bool('@##%')
# Out:
# True

# %%
x = 20
y = 49


# x = 40
# y = 20
