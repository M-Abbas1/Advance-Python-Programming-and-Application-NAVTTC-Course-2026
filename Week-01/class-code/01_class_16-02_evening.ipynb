# %%
#

# %% [markdown]
# # Print Function
#
# - print is used to dispaly output to console

# %%
print("Hello this is your first program in python")
# Out:
# Hello this is your first program in python

# %%
print(43)
# Out:
# 43

# %%
print(3.66556)
# Out:
# 3.66556

# %%
print(True)
# Out:
# True

# %%
print("apple", "banana', "oragne")
# Out:
#   Cell In[6], line 1
#     print("apple", "banana', "oragne")
#                                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('hellow world')
# Out:
# hellow world

# %%
print("hello world")
# Out:
# hello world

# %%
print("""this is the first class of 
read codding """)
# Out:
# this is the first class of
# read codding

# %%
print("Integer: ", 4532, "Float: ", 4.66, "Boolean : ", False)
# Out:
# Integer:  4532 Float:  4.66 Boolean :  False

# %% [markdown]
# # Separator sep parameter

# %%
print("Hello", "world")
# Out:
# Hello world

# %%
print("apple", "banana", "orange", sep='\n')
# Out:
# apple
# banana
# orange

# %% [markdown]
# ### end parameter

# %%
print("Hello World", end='----')
print("Hello world")
# Out:
# Hello World----Hello world

# %%
print("apple", "banana", "orange", sep="|", end=" Fruits")
# Out:
# apple|banana|orange Fruits

# %% [markdown]
# ## Escape sequences

# %%
print("Hello \n world")
# Out:
# Hello
#  world

# %% [markdown]
# this is your first class

# %%
print("this", end=" ")
print("is", end=" ")
print("your", end=" ")
print("first", end=" ")
print("class", end=" ")
# Out:
# this is your first class

# %%
print("Hello122\tWorld")
# Out:
# Hello122	World

# %%
print("hello\b")
# Out:
# hell

# %%
print("Hello \rWor")
# Out:
# Worlo

# %%
print("Hello\\bird")
# Out:
# Hello\bird

# %%
print("D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\\neek-01")
# Out:
# D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\neek-01

# %%
print('your\'s companay')
# Out:
# your's companay

# %%
print("your\"s company")
# Out:
# your"s company

# %%
print("banana", "apple", "mango", sep="***")
# Out:
# banana***apple***mango

# %%
print("hello\tworld")
# Out:
# hello	world

# %%
print("Hello\rWor")
# Out:
# Worlo

# %%
print("D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\\neek-01")
# Out:
# D:\AI\Advance-Python-Programming-and-Application-NAVTTC-Faisalabad-Course\neek-01

# %% [markdown]
# your's mobile

# %%
print('your"s mobile')
# Out:
# your"s mobile

# %%
name = "khalid"
age = 34

print(f"my name is {name}. and i am {age} year old")
# Out:
# my name is khalid. and i am 34 year old

# %% [markdown]
# # format() function for sting formating

# %%
name = "Ali"
age = 26

# %%
print(f"my name is {name} and i am {age} year old")
# Out:
# my name is Ali and i am 26 year old

# %%
print("my name is {0} and i am {1} year old".format(name, age))
# Out:
# my name is Ali and i am 26 year old

# %%
path = "D:\AI\Computer_Vision\nomputer_vision_slides;"

# %%
print(path)
# Out:
# D:\AI\Computer_Vision
# omputer_vision_slides;

# %%
path = r"D:\AI\Computer_Vision\nomputer_vision_slides"

# %%
print(path)
# Out:
# D:\AI\Computer_Vision\nomputer_vision_slides

# %%
price = 100000000000000000000

# %%
print(f"Number : {price:,}")
# Out:
# Number : 100,000,000,000,000,000,000

# %%
pi = 3.141513535335234

# %%
print(f"PI : {pi:.4f}")
# Out:
# PI : 3.1415

# %%
print(f"{'User information':^30}")
print(f"{'Name ':<10}", end=" ")
print(f"{'age':>10}")
# Out:
#        User information
# Name              age

# %%
print("hello", end='      ')
print("hello")
# Out:
# hello      hello
