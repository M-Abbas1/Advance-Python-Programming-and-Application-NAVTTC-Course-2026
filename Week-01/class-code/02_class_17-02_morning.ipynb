# %%
age = 24
print("age", age)
# Out:
# age 24

# %%
type(age)
# Out:
# int

# %%
price = 44.5
type(price)
# Out:
# float

# %%
user_email = "dhgkldj@gmailc.com"

# %%
print(user_email)
# Out:
# dhgkldj@gmailc.com

# %%
type(user_email)
# Out:
# str

# %%
user_name = 'usman'

# %%
userName = "wakeel"
UserName = "huzifa"

# %%
user-123 = "khan"
# Out:
#   Cell In[9], line 1
#     user-123 = "khan"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
for = 434
# Out:
#   Cell In[10], line 1
#     for = 434
#         ^
# SyntaxError: invalid syntax

# %%
positive_no = 236876
negative_no = -56
print("Positive Number : ",positive_no)
print("Negative Number : ", negative_no)
# Out:
# Positive Number :  236876
# Negative Number :  -56

# %%
big_no = 1000000000000000000000000000000000000

# %%
print(big_no)
# Out:
# 1000000000000000000000000000000000000

# %%
print(f" {big_no:,}")
# Out:
#  1,000,000,000,000,000,000,000,000,000,000,000,000

# %%
# interger operations

# %%
a = 230;
b = 20;

# %%
print(f"the addition is : {a+b}")
# Out:
# the addition is : 250

# %%
print(f"a -b : {a-b}")
# Out:
# a -b : 210

# %%
a * b
# Out:
# 4600

# %%
print("a / b : ", a/b)
# Out:
# a / b :  11.5

# %%
div = a/b

# %%
type(div)
# Out:
# float

# %%
print(f"the floor division of a and b is : {a//b}")
# Out:
# the floor division of a and b is : 11

# %%
floor_div = a//b

# %%
type(floor_div)
# Out:
# int

# %%
print(f"reminder from a/b  is : {a%b}")
# Out:
# reminder from a/b  is : 10

# %%
230/20
# Out:
# 11.5

# %%
# FLoat

# %%
temperature = 37.7
price = 3240.5


print(temperature)
print(price)
# Out:
# 37.7
# 3240.5

# %%
24235-244
# Out:
# 23991

# %%
tem_pri = temperature//price

# %%
tem_pri
# Out:
# 0.0

# %%
type(tem_pri)
# Out:
# float

# %%
20.5//4
# Out:
# 5.0

# %%
20.5/4
# Out:
# 5.125

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 floor(33.8)
#
# NameError: name 'floor' is not defined

# %%
a = 40;
b = 0

a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[55], line 4
#       1 a = 40;
#       2 b = 0
# ----> 4 a/b
#
# ZeroDivisionError: division by zero

# %%
quoate = 'she sai, "Hello"'

# %%
first_name = "usman"
last_name = "Khan"

full_name = first_name + " " + last_name

# %%
print(full_name)
# Out:
# usman Khan

# %%
program = "Python is the easiest program i ever write"

print(f"the length of {program}  is {len(program)}")
# Out:
# the length of Python is the easiest program i ever write  is 42

# %%
program = "Python is the easiest program i ever writ"e
# Out:
# ' '

# %%
program[0:6:3]
# Out:
# 'Ph'

# %%
program[0:50:-1]
# Out:
# ''

# %%
sentence = "  the programming knowledge  "

# %%
sentence[2:-2]
# Out:
# 'the programming knowledge'

# %%
sentence.strip()
# Out:
# 'the programming knowledge'

# %%
user_name = "    huzifa  "

# %%
user_name.lstrip()
# Out:
# 'huzifa  '

# %%
user_name = "    huzifa   "
user_name.rstrip().lstrip()
# Out:
# 'huzifa'

# %%
sen = "the programming language you better understand"

# %%
sen[sen.find('you'):]
# Out:
# 'you better understand'

# %%
# Out:
# 'you better understan'

# %%
"19 May 2008".find(' ', 3)
# Out:
# 6
