# %% [markdown]
# ## Part 3: Homework Tasks
#
# Complete these tasks at home to reinforce your learning. Take your time and try different approaches!

# %% [markdown]
# ### Homework Task 1: Personal Information Card
# Create a personal information card with the following details (use your own information):
# - Name
# - Age
# - City
# - Favorite Hobby
#
# Format it nicely with separators and proper spacing. Example output:
# ```
# ========================
#   PERSONAL INFO CARD
# ========================
# Name    : John Doe
# Age     : 25
# City    : New York
# Hobby   : Reading
# ========================
# ```

# %%
# write your code hear

# %% [markdown]
# ### Homework Task 2: Shopping List
# Create a shopping list with at least 4 items. Print each item on a new line with a number before it.
#
# Example output:
# ```
# SHOPPING LIST
# -------------
# 1. Milk
# 2. Eggs
# 3. Bread
# 4. Butter
# ```

# %%
# write your code here

# %% [markdown]
# ### Homework Task 3: Price Calculator
# Create three variables for item prices (use decimals). Calculate the total and print a formatted bill.
#
# Example output:
# ```
# Item 1: $12.50
# Item 2: $8.99
# Item 3: $15.75
# --------------
# Total : $37.24
# ```
#
# Use f-strings and format numbers to 2 decimal places.

# %%
# write your code here

# %% [markdown]
# ### Homework Task 4: Triangle Pattern
# Print a simple triangle pattern using asterisks.
#
# Expected output:
# ```
# *
# **
# ***
# ****
# *****
# ```
#
# Hint: Use 5 separate print statements.

# %%
# write your code here

# %% [markdown]
# ### Homework Task 5: Math Results
# Create two variables with numbers of your choice. Print the following calculations with proper labels:
# - Addition
# - Subtraction
# - Multiplication
# - Division (format to 2 decimal places)
#
# Example output:
# ```
# Number 1: 15
# Number 2: 4
# ------------
# 15 + 4 = 19
# 15 - 4 = 11
# 15 * 4 = 60
# 15 / 4 = 3.75
# ```

# %%
# write your code here

# %% [markdown]
# ### Homework Task 6: Quote Display
# Print your favorite quote with the author's name. Use escape sequences to include quotation marks.
#
# Example output:
# ```
# "The only way to do great work is to love what you do."
#                                         - Steve Jobs
# ```
#
# Try to align the author name to the right.

# %%
# write your code here

# %% [markdown]
# ### Homework Task 7: "Student Grade Report"
# Create a simple grade report for a student with 3 subjects. Calculate and display the average.
#
# Example output:
# ```
# GRADE REPORT
# ============
# Student: John Smith
# ------------
# Math    : 85
# Science : 92
# English : 88
# ------------
# Average : 88.33
# ```
#
# Format the average to 2 decimal places.

# %%
# write your code here

# %% [markdown]
# ### Homework Task 8: Creative Challenge
# Create your own creative print output! It could be:
# - A simple ASCII art (like a house, car, or face)
# - A formatted schedule
# - A menu for a restaurant
# - Anything creative you can think of!
#
# Use various print features you learned: separators, escape sequences, formatting, etc.

# %%
# Write your code here - Be Creative!
