# %%
## How Pakistan Can Enter into the Simi Final of T20 World Cup  2026

# %%
## pakistan
## 

runs_scored_pk = 150
runs_scored_sl = 150

for i in range(50):
    runs_scored_pk += 1
    runs_scored = 164 + runs_scored_pk
    overs_faced = 20 + 20
    runs_conceded = 166 + runs_scored_sl
    overs_bowled = (19 + 1/6) + 20

    pnrr = (runs_scored/overs_faced) - (runs_conceded/overs_bowled)

    print(f"If Pakistan win by {runs_scored_pk - runs_scored_sl} : NRR {pnrr:.3f}")
# Out:
# If Pakistan win by 1 : NRR -0.193
# If Pakistan win by 2 : NRR -0.168
# If Pakistan win by 3 : NRR -0.143
# If Pakistan win by 4 : NRR -0.118
# If Pakistan win by 5 : NRR -0.093
# If Pakistan win by 6 : NRR -0.068
# If Pakistan win by 7 : NRR -0.043
# If Pakistan win by 8 : NRR -0.018
# If Pakistan win by 9 : NRR 0.007
# If Pakistan win by 10 : NRR 0.032
# If Pakistan win by 11 : NRR 0.057
# If Pakistan win by 12 : NRR 0.082
# If Pakistan win by 13 : NRR 0.107
# If Pakistan win by 14 : NRR 0.132
# If Pakistan win by 15 : NRR 0.157
# If Pakistan win by 16 : NRR 0.182
# If Pakistan win by 17 : NRR 0.207
# If Pakistan win by 18 : NRR 0.232
# If Pakistan win by 19 : NRR 0.257
# If Pakistan win by 20 : NRR 0.282
# If Pakistan win by 21 : NRR 0.307
# If Pakistan win by 22 : NRR 0.332
# If Pakistan win by 23 : NRR 0.357
# If Pakistan win by 24 : NRR 0.382
# If Pakistan win by 25 : NRR 0.407
# If Pakistan win by 26 : NRR 0.432
# If Pakistan win by 27 : NRR 0.457
# ...

# %%
## New zeland

runs_scored_nz = 150
runs_scored_eng = 151

for i in range(50):
    runs_scored = 168 + runs_scored_nz
    overs_faced = 20 + 20
    runs_conceded = 107 + runs_scored_eng
    overs_bowled = 20 + 20

    nnrr = (runs_scored/overs_faced) - (runs_conceded/overs_bowled)

    print(f"If New Zealand Loss by {runs_scored_eng - runs_scored_nz} : NRR {nnrr:.3f}")

    runs_scored_eng += 1
# Out:
# If New Zealand Loss by 1 : NRR 1.500
# If New Zealand Loss by 2 : NRR 1.475
# If New Zealand Loss by 3 : NRR 1.450
# If New Zealand Loss by 4 : NRR 1.425
# If New Zealand Loss by 5 : NRR 1.400
# If New Zealand Loss by 6 : NRR 1.375
# If New Zealand Loss by 7 : NRR 1.350
# If New Zealand Loss by 8 : NRR 1.325
# If New Zealand Loss by 9 : NRR 1.300
# If New Zealand Loss by 10 : NRR 1.275
# If New Zealand Loss by 11 : NRR 1.250
# If New Zealand Loss by 12 : NRR 1.225
# If New Zealand Loss by 13 : NRR 1.200
# If New Zealand Loss by 14 : NRR 1.175
# If New Zealand Loss by 15 : NRR 1.150
# If New Zealand Loss by 16 : NRR 1.125
# If New Zealand Loss by 17 : NRR 1.100
# If New Zealand Loss by 18 : NRR 1.075
# If New Zealand Loss by 19 : NRR 1.050
# If New Zealand Loss by 20 : NRR 1.025
# If New Zealand Loss by 21 : NRR 1.000
# If New Zealand Loss by 22 : NRR 0.975
# If New Zealand Loss by 23 : NRR 0.950
# If New Zealand Loss by 24 : NRR 0.925
# If New Zealand Loss by 25 : NRR 0.900
# ...

# %%
## New zeland vs pakistan NRR comparison

runs_scored_nz = 150
runs_scored_eng = 151

for i in range(50):
    #New Zealand
    nz_total_runs_scored = 168 + runs_scored_nz
    nz_total_overs_faced = 20 + 20
    nz_total_runs_conceded = 107 + runs_scored_eng
    nz_total_overs_bowled = 20 + 20
    nnrr = (nz_total_runs_scored/nz_total_overs_faced) - (nz_total_runs_conceded/nz_total_overs_bowled)


    #Pakistan
    pnrr = -0.46086956521739175
    runs_scored_pk = 150
    runs_scored_sl = 150

    while nnrr > pnrr:
        runs_scored_pk += 1
        pk_total_runs_scored = 164 + runs_scored_pk
        pk_total_overs_faced = 20 + 20
        pk_total_runs_conceded = 166 + runs_scored_sl
        pk_total_overs_bowled = (19 + 1/6) + 20
        pnrr = (pk_total_runs_scored/pk_total_overs_faced) - (pk_total_runs_conceded/pk_total_overs_bowled)

    print(f"New Zealand Loss by {runs_scored_eng - runs_scored_nz} runs, NRR {nnrr:.3f}. Pakistan Should Win by {runs_scored_pk - runs_scored_sl} runs NRR {pnrr:.3f}.")
    
    runs_scored_eng += 1
# Out:
# New Zealand Loss by 1 runs, NRR 1.500. Pakistan Should Win by 69 runs NRR 1.507.
# New Zealand Loss by 2 runs, NRR 1.475. Pakistan Should Win by 68 runs NRR 1.482.
# New Zealand Loss by 3 runs, NRR 1.450. Pakistan Should Win by 67 runs NRR 1.457.
# New Zealand Loss by 4 runs, NRR 1.425. Pakistan Should Win by 66 runs NRR 1.432.
# New Zealand Loss by 5 runs, NRR 1.400. Pakistan Should Win by 65 runs NRR 1.407.
# New Zealand Loss by 6 runs, NRR 1.375. Pakistan Should Win by 64 runs NRR 1.382.
# New Zealand Loss by 7 runs, NRR 1.350. Pakistan Should Win by 63 runs NRR 1.357.
# New Zealand Loss by 8 runs, NRR 1.325. Pakistan Should Win by 62 runs NRR 1.332.
# New Zealand Loss by 9 runs, NRR 1.300. Pakistan Should Win by 61 runs NRR 1.307.
# New Zealand Loss by 10 runs, NRR 1.275. Pakistan Should Win by 60 runs NRR 1.282.
# New Zealand Loss by 11 runs, NRR 1.250. Pakistan Should Win by 59 runs NRR 1.257.
# New Zealand Loss by 12 runs, NRR 1.225. Pakistan Should Win by 58 runs NRR 1.232.
# ...

# %%
def logger(func):
    def wrapper(*args, **kwargs):
        print("Function started")
        result = func(*args, **kwargs)
        print("Function finished")
        return result
    return wrapper

@logger
def add(a, b):
    return a + b

print(add(5, 3))
# Out:
# Function started
# Function finished
# 8
